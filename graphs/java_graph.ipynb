# %%
import pandas as pd
import networkx as nx
import community

import operator

# %%
df = pd.read_csv('../tags_with_wiki_relationship.csv')
df
# Out:
#                source           target  weight
# 0                  c#          decimal    3081
# 1                  c#           double    2895
# 2                  c#   floating-point    1946
# 3                  c#  type-conversion    4426
# 4             decimal           double     790
# ...               ...              ...     ...
# 936601       database       parcelable       3
# 936602     web-config  windows-phone-7       4
# 936603  drag-and-drop              lag      12
# 936604      animation           markup      14
# 936605       assembly    factorization       1
#
# [936606 rows x 3 columns]

# %%
df_wiki = pd.read_csv('../tags_with_wiki_and_category.csv', lineterminator='\n')
df_wiki
# Out:
#                       TagName  \
# 0                        java
# 1                       regex
# 2                         xml
# 3                       mysql
# 4                        nant
# ...                       ...
# 41778            minimal-apis
# 41779                  ix.net
# 41780        amazon-memory-db
# 41781           decomposition
# 41782  dasync.asyncenumerator
#
#                                                     Body      root
# 0      java is a high-level object oriented programmi...  language
# 1      Regular expressions provide a declarative lang...       NaN
# 2      xml (extensible markup language) is a structur...    format
# 3      mysql is a free open source relational databas...    system
# 4      nant is a build tool for .net aiming to suppor...      tool
# ...                                                  ...       ...
# 41778  Minimal APIs were introduced in ASP.NET Core 6...       NaN
# 41779  the interactive extensions (ix) is a .net libr...   library
# 41780  memorydb for redis is an in-memory database se...   service
# 41781  Decomposition might refer to Time Series Decom...       NaN
# 41782  dasync.asyncenumerator is a c# library that pr...   library
#
# [41783 rows x 3 columns]

# %%
node_attr = df_wiki.set_index('TagName').to_dict('index')

# %%
Graphtype = nx.Graph()
G = nx.from_pandas_edgelist(df, edge_attr='weight', create_using=Graphtype)
nx.set_node_attributes(G, node_attr)

# %%
G.nodes['java']
# Out:
# {'Body': 'java is a high-level object oriented programming language.',
#  'root': 'language'}

# %%
G['java']
# Out:
# AtlasView({'csv': {'weight': 10614}, 'data-conversion': {'weight': 405}, 'xml': {'weight': 88196}, 'oop': {'weight': 25140}, 'php': {'weight': 18711}, 'theory': {'weight': 260}, 'casting': {'weight': 8825}, 'generics': {'weight': 41926}, 'type-safety': {'weight': 410}, 'warnings': {'weight': 934}, 'c#': {'weight': 21277}, 'int': {'weight': 6223}, 'integer': {'weight': 5897}, 'code-coverage': {'weight': 1508}, 'coldfusion': {'weight': 1441}, 'testing': {'weight': 13632}, 'jbutton': {'weight': 11672}, 'swing': {'weight': 196876}, 'jxta': {'weight': 124}, 'p2p': {'weight': 624}, 'parsing': {'weight': 20785}, 'string': {'weight': 77271}, 'c++': {'weight': 20297}, 'unix': {'weight': 3787}, 'windows': {'weight': 17525}, 'exception': {'weight': 30023}, 'illegalargumentexception': {'weight': 1126}, 'nullpointerexception': {'weight': 22768}, 'static-analysis': {'weight': 873}, 'file': {'weight': 33441}, 'file-io': {'weight': 12346}, 'autoboxing': {'weight': 944}, 'java-native-interface': {'weight': 13331}, 'java-web-start': {'weight': 4180}, 'primitive': {'weight': 1218}, 'http': {'weight': 18948}, 'servlets': {'weight': 58557}, 'mocking': {'weight': 5632}, 'try-catch': {'weight': 5276}, 'j#': {'weight': 39}, 'build-automation': {'weight': 434}, 'jnlp': {'weight': 3033}, 'rcp': {'weight': 2145}, 'eclipse': {'weight': 146805}, 'eclipse-3.4': {'weight': 133}, 'ganymede': {'weight': 84}, 'linux': {'weight': 21872}, 'timezone': {'weight': 3901}, 'configuration': {'weight': 5912}, 'plot': {'weight': 573}, 'loading': {'weight': 696}, 'junit': {'weight': 41060}, 'testng': {'weight': 10422}, 'sql-server': {'weight': 9780}, 'search': {'weight': 6757}, 'applet': {'weight': 18080}, 'bigdecimal': {'weight': 3065}, 'math': {'weight': 11266}, 'architecture': {'weight': 3664}, 'google-maps': {'weight': 9389}, 'mapping': {'weight': 3381}, 'wgs84': {'weight': 44}, 'encoding': {'weight': 7178}, 'serialization': {'weight': 17743}, 'executable': {'weight': 942}, 'software-distribution': {'weight': 151}, 'swt': {'weight': 12164}, 'myeclipse': {'weight': 513}, 'enterprise': {'weight': 286}, 'jboss': {'weight': 18346}, 'security': {'weight': 15185}, 'aop': {'weight': 4146}, 'jakarta-ee': {'weight': 44074}, 'spring': {'weight': 267775}, 'java-me': {'weight': 5144}, 'mobile': {'weight': 3883}, 'workflow': {'weight': 591}, 'ajax': {'weight': 11610}, 'icefaces': {'weight': 620}, 'jsf': {'weight': 20076}, 'data-structures': {'weight': 14236}, 'linked-list': {'weight': 11406}, 'db2': {'weight': 2620}, 'db2-luw': {'weight': 120}, 'dbunit': {'weight': 810}, 'stax': {'weight': 1350}, '.net': {'weight': 6045}, 'gnu-classpath': {'weight': 10}, 'ikvm': {'weight': 345}, 'byte': {'weight': 4743}, 'signed': {'weight': 281}, 'unsigned': {'weight': 422}, 'image-scanner': {'weight': 63}, 'twain': {'weight': 95}, 'pdf': {'weight': 13134}, 'webobjects': {'weight': 68}, 'axis': {'weight': 2029}, 'cxf': {'weight': 7168}, 'web-services': {'weight': 36979}, 'ip': {'weight': 1628}, 'router': {'weight': 200}, 'sockets': {'weight': 35093}, 'obfuscation': {'weight': 1342}, 'configuration-files': {'weight': 586}, 'cross-platform': {'weight': 1160}, 'json': {'weight': 87355}, 'jsp': {'weight': 69361}, 'tomcat': {'weight': 57691}, 'macos': {'weight': 13816}, 'oracle': {'weight': 25322}, 'profiling': {'weight': 2199}, 'internationalization': {'weight': 3131}, 'struts': {'weight': 5489}, 'osgi': {'weight': 7247}, 'svn': {'weight': 2939}, 'ftp': {'weight': 3866}, 'sftp': {'weight': 1688}, 'ejb-3.0': {'weight': 3257}, 'inheritance': {'weight': 19855}, 'ant': {'weight': 15965}, 'automake': {'weight': 1}, 'makefile': {'weight': 815}, 'convention': {'weight': 115}, 'label': {'weight': 1236}, 'design-patterns': {'weight': 16828}, 'ide': {'weight': 4003}, 'performance': {'weight': 26829}, 'text-processing': {'weight': 232}, 'stripes': {'weight': 576}, 'validation': {'weight': 11595}, 'xsd': {'weight': 6622}, 'refactoring': {'weight': 3471}, 'xquery': {'weight': 499}, 'database': {'weight': 33905}, ...

# %%
# Find modularity
part_1 = community.best_partition(G, random_state = 27)
mod_1 = community.modularity(part_1,G)

# %%
part_1['java']
# Out:
# 7

# %%
number_of_comm_1 = max(part_1.items(), key=operator.itemgetter(1))[1] + 1
number_of_comm_1
# Out:
# 20

# %%
list_of_comm_1 = []
for i in range(number_of_comm_1):
    list_of_comm_1.append([k for k,v in part_1.items() if v == i])
    
list_of_comm_1[part_1['java']]
# Out:
# ['aptana',
#  'eclipse',
#  'xml',
#  'java',
#  'xsd',
#  'logging',
#  'media',
#  'sqlite',
#  'continuous-integration',
#  'testing',
#  'deployment',
#  'embedded-database',
#  'xslt',
#  'exception',
#  'exception-handling',
#  'try-catch',
#  'web-applications',
#  'collections',
#  'filelock',
#  'audio',
#  'build-process',
#  'orm',
#  'error-handling',
#  'rest',
#  'xfdl',
#  'latitude-longitude',
#  'mapping',
#  'maps',
#  'user-interface',
#  'code-coverage',
#  'jbutton',
#  'swing',
#  'build-automation',
#  'obfuscation',
#  'ide',
#  'google-maps',
#  'google-maps-api-3',
#  'midi',
#  'service',
#  'integration',
#  'storage',
#  'line-numbers',
#  'illegalargumentexception',
#  'nullpointerexception',
#  'ant',
#  'ear',
#  'jakarta-ee',
#  'websphere',
#  'configuration',
#  'activemq',
#  'messaging',
#  'autoboxing',
#  'sms',
#  'dsl',
#  'modem',
#  'java-native-interface',
#  'java-web-start',
#  'cluster-computing',
#  'code-completion',
#  'xml-signature',
#  'jaas',
#  'grails',
#  'groovy',
#  'servlets',
#  'gwt',
#  'lifecycle',
#  'sgml',
#  'jnlp',
#  'rcp',
#  'yahoo-maps',
#  'eclipse-3.4',
#  'ganymede',
#  'rule-engine',
#  'junit',
#  'testng',
#  'icons',
#  'stringbuilder',
#  'defensive-programming',
#  'lazy-initialization',
#  'mp3',
#  'caucho',
#  'resin',
#  'applet',
#  'selenium',
#  'pylot',
#  'stress-testing',
#  'webapplicationstresstool',
#  'bigdecimal',
#  'wgs84',
#  'swt',
#  'myeclipse',
#  'graphics',
#  'instrumentation',
#  'connection-pooling',
#  'jboss',
#  'aop',
#  'spring',
#  'java-me',
#  'xpath',
#  'unhandled',
#  'device',
#  'emulation',
#  'dependencies',
#  'icefaces',
#  'jsf',
#  'listener',
#  'wap',
#  'wml',
#  'gps',
#  'dbunit',
#  'ivr',
#  'telephony',
#  'voice',
#  'voip',
#  'dynamic-binding',
#  'static-binding',
#  'stax',
#  'rpc',
#  'integration-testing',
#  'gnu-classpath',
#  'xml-parsing',
#  'webobjects',
#  'automation',
#  'axis',
#  'cxf',
#  'persistence',
#  'rss',
#  'failover',
#  'session-replication',
#  'webautomation',
#  'atom-feed',
#  'tibco',
#  'msxml',
#  'listview',
#  'xmlnode',
#  'xmlnodelist',
#  'location',
#  'zipcode',
#  'jsp',
#  'tomcat',
#  'struts',
#  'distributed',
#  'qa',
#  'automated-tests',
#  'bitmap',
#  'osgi',
#  'ejb-3.0',
#  'speech-recognition',
#  'layout',
#  'build',
#  'out-of-memory',
#  'garbage-collection',
#  'stripes',
#  'well-formed',
#  'dtd',
#  'message',
#  'xquery',
#  'feed',
#  'street-address',
#  'axis2',
#  'maven-2',
#  'notifications',
#  'project-structure',
#  'jvm',
#  'usage-statistics',
#  'stack-trace',
#  'gui-testing',
#  'ui-automation',
#  'rms',
#  'menu-items',
#  'ecm',
#  'jcheckbox',
#  'offline',
#  'error-logging',
#  'netbeans',
#  'jpanel',
#  'model-driven',
#  'transactions',
#  'xtunit',
#  'uri',
#  'intellij-idea',
#  'gwt-gin',
#  'jcifs',
#  'broadcast',
#  'rethrow',
#  'platform',
#  'back-button',
#  'lwuit',
#  'gigaspaces',
#  'bufferedimage',
#  'velocity',
#  'lines-of-code',
#  'annotations',
#  'web-frameworks',
#  'dao',
#  'java-io',
#  'swift-mt',
#  'mbt',
#  'android',
#  'android-mapview',
#  'hibernate',
#  'web.xml',
#  'cruisecontrol',
#  'metrics',
#  'bundle',
#  'code-formatting',
#  'checked-exceptions',
#  'equals',
#  'hashcode',
#  'jmx',
#  'mbeans',
#  'gsm',
#  'haversine',
#  'jspx',
#  'bytebuffer',
#  'filechannel',
#  'nio',
#  'eclipse-3.2',
#  'finalize',
#  'slickedit',
#  'specifications',
#  'hashmap',
#  'api-design',
#  'log4j',
#  'sound-synthesis',
#  'synthesizer',
#  'javadoc',
#  'ejb',
#  'weblogic',
#  'drm',
#  'menuitem',
#  'seam',
#  'podcast',
#  'jgroups',
#  'terracotta',
#  'maven',
#  'maven-metadata',
#  'sax',
#  'dialog',
#  'geocoding',
#  'imageicon',
#  'jpa',
#  'decompiling',
#  'wifi',
#  'java.util.logging',
#  'socketexception',
#  'assert',
#  'widget',
#  'test-plan',
#  'jscrollpane',
#  'jfilechooser',
#  'rollback',
#  'parameterized-unit-test',
#  'custom-component',
#  'mobile-phones',
#  'actionlistener',
#  'mouselistener',
#  'noclassdeffounderror',
#  '2d-games',
#  'final',
#  'encoder',
#  'nosuchmethoderror',
#  'distributed-computing',
#  'signing',
#  'chat',
#  'xmpp',
#  'oggvorbis',
#  'cmusphinx',
#  'voicexml',
#  'google-maps-api-2',
#  'nmea',
#  'android-tabhost',
#  'corba',
#  'fault-tolerance',
#  'spring-ws',
#  'jms',
#  'distributed-transactions',
#  'java-ee-5',
#  'vcf-vcard',
#  'distributed-caching',
#  'eclipse-3.3',
#  'eclipse-pde',
#  'datasource',
#  'ibatis',
#  'jndi',
#  'scanning',
#  'struts2',
#  'spring-aop',
#  'documentum',
#  'webtop',
#  'java-3d',
#  'jhat',
#  'phone-number',
#  'waveform',
#  'data-transfer',
#  'apache-commons-fileupload',
#  'black-box',
#  'exif',
#  'number-formatting',
#  'bcel',
#  'bytecode',
#  'tapestry',
#  'jstl',
#  'taglib',
#  'version',
#  'jta',
#  'hudson',
#  'javafx',
#  'esb',
#  'jini',
#  'classcastexception',
#  'wacom',
#  'groovyshell',
#  'blackberry',
#  'native-code',
#  'jface',
#  'xslt-1.0',
#  'eclipse-plugin',
#  'findbugs',
#  'jakarta-mail',
#  'native',
#  'try-catch-finally',
#  'jmf',
#  'splash-screen',
#  'jsp-tags',
#  'hql',
#  'scala',
#  'asterisk',
#  'weak-references',
#  'high-availability',
#  'sdk',
#  'google-reader',
#  'emma',
#  'xsl-fo',
#  'mms',
#  'java1.4',
#  'jcombobox',
#  'arraylist',
#  'xmlspy',
#  'build.xml',
#  'mstdc',
#  'tiles',
#  'standby',
#  'reboot',
#  'rmi',
#  'birt',
#  'midlet',
#  'easymock',
#  'anonymous-inner-class',
#  'webmethods',
#  'jacl',
#  'camera',
#  'wildcard-mapping',
#  'screenshot',
#  'criteria',
#  'visualvm',
#  'cascade',
#  'itemlistener',
#  'ehcache',
#  'kiosk',
#  'javasound',
#  'classloader',
#  'jar',
#  'curl-language',
#  'jmockit',
#  'static-block',
#  'jtds',
#  'photo',
#  'power-management',
#  'altova',
#  'transformation',
#  'qr-code',
#  'resolution',
#  'java-wireless-toolkit',
#  'spring-el',
#  'spring-webflow',
#  'cas',
#  'sunone',
#  'hash-code-uniqueness',
#  'onstart',
#  'wma',
#  'openfire',
#  'toplink',
#  'restful-authentication',
#  'gcj',
#  'eclipse-pdt',
#  'auto-update',
#  'bluetooth',
#  'multipartform-data',
#  'lcdui',
#  'midp',
#  'cdata',
#  'zipinputstream',
#  'zipoutputstream',
#  'rules',
#  'mtj',
#  'resourcebundle',
#  'id3',
#  'spinner',
#  'libxml2',
#  'ejb-2.x',
#  'pressed',
#  'thrift',
#  'saxon',
#  'wicket',
#  'aac',
#  'm4a',
#  'postal-code',
#  'meta-inf',
#  'inner-classes',
#  'connector',
#  'ads',
#  'mdsd',
#  'model-driven-development',
#  'richfaces',
#  'ejbql',
#  'mixer',
#  'shoutcast',
#  'transmission',
#  'jedit',
#  'selenium-rc',
#  'spring-mvc',
#  'webdriver',
#  'opengl-es',
#  'business-process-management',
#  'izpack',
#  'xinclude',
#  'jetty',
#  'jdbc',
#  'restart',
#  'paint',
#  'game-loop',
#  'wsdl2java',
#  'sablecc',
#  'el',
#  'tomcat5.5',
#  'tomcat6',
#  'progress-bar',
#  'hammer',
#  'xml-namespaces',
#  'dirtyrectangle',
#  'sqlexception',
#  'doublebuffered',
#  'ksoap',
#  'load-testing',
#  'regression-testing',
#  'signed-applet',
#  'touchscreen',
#  'smartphone',
#  'griffon',
#  'stomp',
#  'screen',
#  'awtrobot',
#  'future',
#  'phantom-reference',
#  'hibernate-tools',
#  'glassfish',
#  'jax-rs',
#  'java-metro-framework',
#  'xforms',
#  'uberjar',
#  'eager',
#  'aac+',
#  'yahoo-pipes',
#  'xmlbeans',
#  'sony',
#  'manifest.mf',
#  'rxtx',
#  'ems',
#  'updates',
#  'jtable',
#  'polyglot',
#  'facelets',
#  'hibernate-search',
#  'urlconnection',
#  'geolocation',
#  'jsse',
#  'portal',
#  'audio-analysis',
#  'xml-attribute',
#  'linearization',
#  'jdb',
#  'code-by-voice',
#  'speech',
#  'java-6',
#  'permgen',
#  'throw',
#  'jdepend',
#  'maven-plugin',
#  'resultset',
#  'dwr',
#  'sip',
#  'thread-dump',
#  'gwt-ext',
#  'fit-framework',
#  'fitnesse',
#  'soapui',
#  'myfaces',
#  'trinidad',
#  'maven-scm',
#  'selenium-grid',
#  'sapi',
#  'text-to-speech',
#  'user-testing',
#  'jlabel',
#  'renderer',
#  'ibm-mq',
#  'view',
#  'titlebar',
#  'eclipse-jdt',
#  'instant-messaging',
#  'workspace',
#  'cobertura',
#  'javax.script',
#  'stateful',
#  'testcomplete',
#  'cldc',
#  'eclipse-ecf',
#  'eclipse-rcp',
#  'awt',
#  'jvm-languages',
#  'xstream',
#  'rft',
#  'oracle-adf',
#  'freemarker',
#  'sitemesh',
#  'barcode',
#  'sakai',
#  'maven-3',
#  'apache-cocoon',
#  'castor',
#  'oql',
#  'hci',
#  'agi',
#  'wcs',
#  'websphere-commerce',
#  'cql',
#  'netbeans6.1',
#  'rmiregistry',
#  'ui-testing',
#  'verifyerror',
#  'keystroke',
#  'xmlslurper',
#  'multipart',
#  'woodstock',
#  'jax-ws',
#  'xpath-2.0',
#  'ase',
#  'jaxb',
#  'next-generation-plugin',
#  'inject',
#  'jtextpane',
#  'multiple-instances',
#  'copy-protection',
#  'android-emulator',
#  'instanceof',
#  'javac',
#  'jbuilder',
#  'eclipse-wtp',
#  'sun',
#  'thread-local',
#  'xml-nil',
#  'parameterized',
#  'vtl',
#  'builder',
#  'internal',
#  'web-testing',
#  'war',
#  'apache-fop',
#  'lazylist',
#  'manifest',
#  'gyroscope',
#  'policy',
#  'callable',
#  'file-manager',
#  'jprofiler',
#  'geotagging',
#  'rome',
#  'package-explorer',
#  'jbpm',
#  'jcomponent',
#  'jsplitpane',
#  'eclipse-emf',
#  'eclipse-m2t-jet',
#  'calculator',
#  'toolbar',
#  'wcat',
#  'classpath',
#  'jasper-reports',
#  'drools',
#  'biginteger',
#  'jotm',
#  'connectivity',
#  'playback',
#  'lift',
#  'derby',
#  'aspectj',
#  'load-time-weaving',
#  'composite',
#  'hbm',
#  'mda',
#  'message-queue',
#  'j-security-check',
#  'sessionfactory',
#  'software-quality',
#  'marklogic',
#  'headless',
#  'ibm-datapower',
#  'jad',
#  'rad',
#  'docbook',
#  'jmeter',
#  'qt-jambi',
#  'temperature',
#  'javabeans',
#  'javax.imageio',
#  'contextpath',
#  'apache-poi',
#  'oracle-coherence',
#  'nightly-build',
#  'image-caching',
#  'keystore',
#  'codebase',
#  'system.out',
#  'jvlc',
#  'javaspaces',
#  'jersey',
#  'jtextfield',
#  'xa',
#  'reconnect',
#  'assertions',
#  'jls',
#  'optimistic-locking',
#  'pessimistic-locking',
#  'fastinfoset',
#  'jbossws',
#  'jconsole',
#  'jts',
#  'shape',
#  'wav',
#  'jaxp',
#  'log-analysis',
#  'p2',
#  'hotdeploy',
#  '2phase-commit',
#  'application-server',
#  'httpclient',
#  'listitem',
#  'mojo',
#  'error-code',
#  'jconnect',
#  'jtapi',
#  'coordinates',
#  'source-monitor',
#  'listeners',
#  'jgrapht',
#  'mobile-devices',
#  'finalization',
#  'pooling',
#  'path-variables',
#  'selectionmodel',
#  'uat',
#  'browser-automation',
#  'runtime.exec',
#  'archiva',
#  'inputstream',
#  'functional-testing',
#  'alfresco',
#  'popupmenu',
#  'keyevent',
#  'jseparator',
#  'web-inf',
#  'malformedurlexception',
#  'websphere-6.1',
#  'oaw',
#  'xpand',
#  'xtext',
#  'geronimo',
#  'hessian',
#  'runnable',
#  'scriptlet',
#  'ejb-jar.xml',
#  'oc4j',
#  'bufferedinputstream',
#  'objectoutputstream',
#  'quartz-scheduler',
#  'servlet-filters',
#  'audio-player',
#  'spring-security',
#  'jfreechart',
#  'appfuse',
#  'look-and-feel',
#  'wallpaper',
#  'wii',
#  'deployment-descriptor',
#  'serialversionuid',
#  'cellular-network',
#  'save',
#  'tomahawk',
#  'java-2d',
#  'jdesktoppane',
#  'dependency-management',
#  'spring-modules',
#  'jspinclude',
#  'tagfile',
#  'automated-deploy',
#  'accelerometer',
#  'restlet',
#  'mylyn',
#  'jxl',
#  'proguard',
#  'kml',
#  'android-activity',
#  'lego',
#  'nxt',
#  'occam-pi',
#  'websphere-portal',
#  'stringbuffer',
#  'axiom',
#  'hamcrest',
#  'matcher',
#  'failovercluster',
#  'xslt-grouping',
#  'wsadmin',
#  'volume',
#  'opf3',
#  'h2',
#  'jtree',
#  'keylistener',
#  'cargo',
#  'mogilefs',
#  'jeditorpane',
#  'junit4',
#  'bulksms',
#  'ilog',
#  'swingx',
#  'stringtemplate',
#  'executable-jar',
#  'maven-1',
#  'zk',
#  'mockrunner',
#  'subreport',
#  'hsqldb',
#  'adts',
#  'innovation',
#  'spring-dm',
#  'springsource',
#  'truststore',
#  'finally',
#  'infinitest',
#  'javarebel',
#  'static-import',
#  'dead-code',
#  'enunciate',
#  'key-bindings',
#  'yourkit',
#  'syndication',
#  'codesynthesis',
#  'processing',
#  'proximity',
#  'sensors',
#  'transactional',
#  'naked-objects',
#  'jdk1.5',
#  'jdk1.6',
#  'emoticons',
#  'rfid',
#  'bidirectional',
#  'user-inactivity',
#  'java.util.scanner',
#  'one-to-one',
#  'formatter',
#  'jogl',
#  'jboss-tools',
#  'lwjgl',
#  'objectsize',
#  'source-code-protection',
#  'checkstyle',
#  'restriction',
#  'jks',
#  'xdoc',
#  'wiimote',
#  'geotools',
#  'jdk1.4',
#  'prefuse',
#  'logback',
#  'serializable',
#  'maven-shade-plugin',
#  'tostring',
#  'testcase',
#  'artifact',
#  'xfire',
#  'google-earth-plugin',
#  'countdownlatch',
#  'manual-testing',
#  'pmd',
#  'bssid',
#  'rssi',
#  'service-discovery',
#  'dpi',
#  'xalan',
#  'tibco-ems',
#  'system.in',
#  'custom-renderer',
#  'internet-connection',
#  'trampolines',
#  'agent',
#  'code-folding',
#  'h.323',
#  'google-earth',
#  'project',
#  'sd-card',
#  'grape',
#  'jax-rpc',
#  'rapid-prototyping',
#  'treetable',
#  'microphone',
#  'poker',
#  'xerces',
#  'pojo',
#  'root',
#  'progress',
#  'webview',
#  'hibernate-criteria',
#  'frame-rate',
#  'jvm-hotspot',
#  'jfugue',
#  'build-tools',
#  'gesture-recognition',
#  'jsch',
#  'apache-commons-httpclient',
#  'transactionmanager',
#  'white-box',
#  'stateless',
#  'self-contained',
#  'code39',
#  'dialect',
#  'voicemail',
#  'google-feed-api',
#  'atg',
#  'atg-dynamo',
#  'hibernate3',
#  'rabbitmq',
#  'jsdt',
#  'preferences',
#  'preview',
#  'back',
#  'interstitial',
#  'morse-code',
#  'edt',
#  'jml',
#  'decoder',
#  'maven-archetype',
#  'audio-recording',
#  'junit3',
#  'business-rules',
#  'exploratory',
#  'java-persistence-api',
#  'opencms',
#  '7-bit',
#  'java-7',
#  'trove4j',
#  'javafx-1',
#  'file-not-found',
#  'fingerprint',
#  'satellite',
#  'xjc',
#  'cardlayout',
#  'layout-manager',
#  'jmock',
#  'compass-lucene',
#  'jarbundler',
#  'xdoclet',
#  'jna',
#  'jtidy',
#  'hbm2ddl',
#  'jstack',
#  'shred',
#  'eai',
#  'outputstream',
#  'ejabberd',
#  'jdialog',
#  'contextclassloader',
#  'jenkins',
#  'savestate',
#  'dom4j',
#  'google-talk',
#  'beanshell',
#  'rampart',
#  'sleep-mode',
#  'scada',
#  'dalvik',
#  'exslt',
#  'scrollpane',
#  'smoke-testing',
#  'hashset',
#  'viewexpiredexception',
#  'http-put',
#  'target-platform',
#  'synth',
#  'capability',
#  'tetris',
#  'tiles2',
#  'code-standards',
#  'tibco-gi',
#  'hl7',
#  'one-to-many',
#  'vmc',
#  'bug-reporting',
#  'gwt-rpc',
#  'archetypes',
#  'j2mepolish',
#  'panoramio',
#  'clipboardmanager',
#  'pcm',
#  'monkey-testing',
#  'apache-camel',
#  'apache-mina',
#  'xpathdocument',
#  'raw-types',
#  'mmapi',
#  'resume',
#  'screen-capture',
#  'mutation-testing',
#  'applicationcontext',
#  'managed-bean',
#  'rollingfileappender',
#  'java-5',
#  'transformer',
#  'apache-abdera',
#  'capture',
#  'bitblit',
#  'ogg',
#  'linkageerror',
#  'hssf',
#  'jexcelapi',
#  'forward',
#  'ofbiz',
#  'maven-release-plugin',
#  'tablecellrenderer',
#  'keytool',
#  'live-templates',
#  'activemq-cpp',
#  'persistent',
#  'handler',
#  'distributed-system',
#  'foreground',
#  'wadl',
#  'oracleportal',
#  'ibmhttpserver',
#  'bounded-wildcard',
#  'amqp',
#  'anonymous-class',
#  'named-query',
#  'calllog',
#  'implicit',
#  'netbeans6.5',
#  'kindle',
#  'power-saving',
#  'tablemodel',
#  'exe4j',
#  'apache-commons-vfs',
#  'android-listview',
#  'google-street-view',
#  'form-layout',
#  'relaxng',
#  'adapter',
#  'illegalmonitorstateexcep',
#  'end-to-end',
#  'matisse',
#  'message-driven-bean',
#  'audio-streaming',
#  'httpsession',
#  'phpeclipse',
#  'at-command',
#  'unchecked',
#  'tag-soup',
#  'fsm',
#  'traits',
#  'repaint',
#  'textcolor',
#  'spring-test',
#  'soft-references',
#  'openjms',
#  'jboss-portal',
#  'maven-pdf-plugin',
#  'motorola',
#  'jboss5.x',
#  'vibration',
#  'actor',
#  'displaytag',
#  'ioexception',
#  'jbi',
#  'sca',
#  'copyright-display',
#  'jvm-arguments',
#  'javadb',
#  'idref',
#  'gzipinputstream',
#  'dataoutputstream',
#  ...]

# %%
G_1 = G.subgraph(list_of_comm_1[part_1['java']])

# %%
G_1.edges
# Out:
# EdgeView([('mandelbug', 'android'), ('mandelbug', 'android-wake-lock'), ('managed-property', 'jsf'), ('managed-property', 'jsf-2'), ('managed-property', 'managed-bean'), ('managed-property', 'viewparams'), ('jcurses', 'eclipse'), ('jcurses', 'java'), ('eclipse-rse', 'eclipse'), ('eclipse-rse', 'eclipse-plugin'), ('eclipse-rse', 'eclipse-rcp'), ('eclipse-rse', 'java'), ('open-session-in-view', 'hibernate'), ('open-session-in-view', 'java'), ('open-session-in-view', 'jpa'), ('open-session-in-view', 'servlets'), ('open-session-in-view', 'android'), ('open-session-in-view', 'android-asynctask'), ('open-session-in-view', 'jta'), ('open-session-in-view', 'integration-testing'), ('open-session-in-view', 'spring'), ('open-session-in-view', 'wicket'), ('open-session-in-view', 'jsf'), ('java.util.scanner', 'java'), ('java.util.scanner', 'filewriter'), ('java.util.scanner', 'println'), ('java.util.scanner', 'arraylist'), ('java.util.scanner', 'inputstream'), ('java.util.scanner', 'printwriter'), ('java.util.scanner', 'bufferedinputstream'), ('java.util.scanner', 'android'), ('java.util.scanner', 'exception'), ('java.util.scanner', 'exception-handling'), ('java.util.scanner', 'try-catch'), ('java.util.scanner', 'java-io'), ('java.util.scanner', 'bufferedreader'), ('java.util.scanner', 'actionlistener'), ('java.util.scanner', 'hashmap'), ('java.util.scanner', 'guice'), ('java.util.scanner', 'filereader'), ('java.util.scanner', 'jar'), ('java.util.scanner', 'eclipse'), ('java.util.scanner', 'system.in'), ('java.util.scanner', 'jfilechooser'), ('java.util.scanner', 'scala'), ('java.util.scanner', 'jdbc'), ('java.util.scanner', 'jsp'), ('java.util.scanner', 'servlets'), ('java.util.scanner', 'filenotfoundexception'), ('java.util.scanner', 'xml-parsing'), ('karel', 'java'), ('struts-validation', 'java'), ('struts-validation', 'struts2'), ('struts-validation', 'jsp'), ('struts-validation', 'struts'), ('struts-validation', 'spring'), ('struts-validation', 'spring-mvc'), ('struts-validation', 'jakarta-ee'), ('struts-validation', 'struts-1'), ('struts-validation', 'struts-config'), ('code-freeze', 'continuous-integration'), ('code-freeze', 'build-automation'), ('code-freeze', 'cruisecontrol'), ('code-freeze', 'testing'), ('security-constraint', 'application-server'), ('security-constraint', 'tomcat'), ('security-constraint', 'java'), ('security-constraint', 'web-applications'), ('security-constraint', 'jboss'), ('security-constraint', 'web.xml'), ('security-constraint', 'xml'), ('security-constraint', 'jsp'), ('security-constraint', 'servlets'), ('security-constraint', 'jakarta-ee'), ('xmlmapper', 'xml'), ('xmlmapper', 'apache-camel'), ('xmlmapper', 'java'), ('xmlmapper', 'xstream'), ('apache-commons-csv', 'apache-commons'), ('apache-commons-csv', 'java'), ('settext', 'java'), ('settext', 'android'), ('settext', 'textview'), ('settext', 'xml'), ('settext', 'expandablelistadapter'), ('settext', 'expandablelistview'), ('settext', 'android-edittext'), ('settext', 'togglebutton'), ('settext', 'layout'), ('settext', 'jtextfield'), ('settext', 'nullpointerexception'), ('settext', 'swing'), ('settext', 'swt'), ('settext', 'view'), ('settext', 'jbutton'), ('settext', 'jlabel'), ('settext', 'listactivity'), ('settext', 'dialog'), ('settext', 'eclipse'), ('settext', 'android-3.0-honeycomb'), ('settext', 'android-actionbar'), ('settext', 'android-1.5-cupcake'), ('settext', 'android-cursoradapter'), ('settext', 'simplecursoradapter'), ('settext', 'onlongclicklistener'), ('settext', 'android-activity'), ('settext', 'windowlistener'), ('settext', 'imageswitcher'), ('settext', 'ondraw'), ('settext', 'listener'), ('websphere-6.1', 'websphere'), ('websphere-6.1', 'deployment'), ('websphere-6.1', 'rad'), ('websphere-6.1', 'websphere-portal'), ('websphere-6.1', 'jacl'), ('websphere-6.1', 'wsadmin'), ('websphere-6.1', 'ant'), ('websphere-6.1', 'eclipse'), ('websphere-6.1', 'hibernate'), ('websphere-6.1', 'jdbc'), ('websphere-6.1', 'jakarta-ee'), ('websphere-6.1', 'jp ...

# %%
part_2 = community.best_partition(G_1)
mod_2 = community.modularity(part_2,G_1)

# %%
sorted(G_1.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('java', 2737),
#  ('android', 1555),
#  ('eclipse', 979),
#  ('xml', 785),
#  ('spring', 645),
#  ('jakarta-ee', 586),
#  ('user-interface', 532),
#  ('tomcat', 518),
#  ('exception', 516),
#  ('maven', 499),
#  ('scala', 497),
#  ('hibernate', 479),
#  ('netbeans', 474),
#  ('swing', 471),
#  ('maven-2', 459),
#  ('web-applications', 448),
#  ('testing', 437),
#  ('jsp', 413),
#  ('servlets', 407),
#  ('gwt', 407),
#  ('grails', 374),
#  ('ant', 374),
#  ('jboss', 371),
#  ('junit', 362),
#  ('jsf', 357),
#  ('logging', 356),
#  ('configuration', 348),
#  ('groovy', 337),
#  ('jpa', 334),
#  ('service', 333),
#  ('java-me', 328),
#  ('jar', 328),
#  ('blackberry', 313),
#  ('spring-mvc', 313),
#  ('annotations', 310),
#  ('layout', 310),
#  ('android-activity', 307),
#  ('rest', 306),
#  ('sqlite', 305),
#  ('glassfish', 302),
#  ('audio', 288),
#  ('deployment', 285),
#  ('nullpointerexception', 284),
#  ('eclipse-plugin', 283),
#  ('android-intent', 276),
#  ('jdbc', 270),
#  ('android-layout', 266),
#  ('jvm', 264),
#  ('applet', 262),
#  ('view', 258),
#  ('listview', 256),
#  ('intellij-idea', 255),
#  ('android-emulator', 249),
#  ('build', 245),
#  ('exception-handling', 242),
#  ('websphere', 238),
#  ('jetty', 234),
#  ('google-maps', 234),
#  ('listener', 233),
#  ('osgi', 228),
#  ('sdk', 227),
#  ('ejb', 217),
#  ('classpath', 213),
#  ('collections', 212),
#  ('orm', 211),
#  ('jsf-2', 209),
#  ('ide', 208),
#  ('log4j', 207),
#  ('classloader', 206),
#  ('transactions', 204),
#  ('android-widget', 204),
#  ('weblogic', 203),
#  ('dialog', 200),
#  ('xslt', 200),
#  ('xsd', 198),
#  ('jaxb', 198),
#  ('struts2', 196),
#  ('persistence', 195),
#  ('jms', 193),
#  ('graphics', 191),
#  ('dependencies', 190),
#  ('ejb-3.0', 185),
#  ('tomcat6', 183),
#  ('error-handling', 179),
#  ('xpath', 177),
#  ('out-of-memory', 175),
#  ('seam', 173),
#  ('textview', 170),
#  ('bitmap', 169),
#  ('integration', 169),
#  ('arraylist', 168),
#  ('widget', 167),
#  ('selenium', 167),
#  ('webview', 167),
#  ('gps', 166),
#  ('android-3.0-honeycomb', 165),
#  ('hudson', 165),
#  ('android-asynctask', 163),
#  ('javabeans', 163),
#  ('maven-plugin', 161),
#  ('camera', 159),
#  ('automation', 159),
#  ('spring-security', 159),
#  ('java-native-interface', 158),
#  ('mapping', 158),
#  ('glassfish-3', 155),
#  ('struts', 154),
#  ('location', 154),
#  ('sms', 154),
#  ('android-2.2-froyo', 154),
#  ('java-ee-6', 154),
#  ('save', 153),
#  ('playframework', 152),
#  ('notifications', 152),
#  ('integration-testing', 151),
#  ('jax-ws', 150),
#  ('opengl-es', 149),
#  ('garbage-collection', 149),
#  ('geolocation', 149),
#  ('jersey', 149),
#  ('screen', 147),
#  ('automated-tests', 146),
#  ('emulation', 146),
#  ('icons', 145),
#  ('war', 143),
#  ('maven-3', 142),
#  ('bluetooth', 141),
#  ('android-manifest', 140),
#  ('cordova', 140),
#  ('android-edittext', 139),
#  ('wicket', 139),
#  ('jndi', 138),
#  ('eclipse-rcp', 137),
#  ('broadcastreceiver', 134),
#  ('rmi', 133),
#  ('version', 133),
#  ('continuous-integration', 132),
#  ('cxf', 131),
#  ('build-process', 131),
#  ('jboss5.x', 130),
#  ('jpa-2.0', 129),
#  ('inputstream', 129),
#  ('swt', 128),
#  ('android-ndk', 127),
#  ('cluster-computing', 126),
#  ('uri', 126),
#  ('jstl', 126),
#  ('imageview', 125),
#  ('android-listview', 124),
#  ('m2eclipse', 123),
#  ('richfaces', 123),
#  ('eclipselink', 123),
#  ('xml-parsing', 122),
#  ('jmx', 122),
#  ('handler', 120),
#  ('rss', 120),
#  ('jax-rs', 120),
#  ('manifest', 120),
#  ('activemq', 119),
#  ('awt', 119),
#  ('hashmap', 119),
#  ('mp3', 118),
#  ('aspectj', 118),
#  ('media-player', 118),
#  ('progress-bar', 118),
#  ('jenkins', 117),
#  ('maps', 117),
#  ('google-play', 115),
#  ('guice', 114),
#  ('weblogic-10.x', 114),
#  ('native', 114),
#  ('java-web-start', 113),
#  ('datasource', 113),
#  ('junit4', 112),
#  ('axis2', 112),
#  ('httpclient', 112),
#  ('quartz-scheduler', 111),
#  ('bundle', 111),
#  ('jasper-reports', 110),
#  ('classcastexception', 110),
#  ('preferences', 110),
#  ('android-mapview', 109),
#  ('lifecycle', 108),
#  ('testng', 108),
#  ('tomcat7', 107),
#  ('build-automation', 107),
#  ('aop', 106),
#  ('drawable', 105),
#  ('device', 105),
#  ('netbeans-6.9', 105),
#  ('distributed', 103),
#  ('javadoc', 103),
#  ('classnotfoundexception', 103),
#  ('android-fragments', 102),
#  ('xmpp', 101),
#  ('wifi', 101),
#  ('jtable', 101),
#  ('media', 100),
#  ('android-tabhost', 100),
#  ('messaging', 100),
#  ('message', 100),
#  ('project', 99),
#  ('jframe', 99),
#  ('google-maps-api-3', 99),
#  ('liferay', 98),
#  ('spinner', 98),
#  ('noclassdeffounderror', 97),
#  ('coordinates', 97),
#  ('sbt', 97),
#  ('derby', 97),
#  ('apache-commons', 97),
#  ('ear', 97),
#  ('web.xml', 96),
#  ('spring-roo', 95),
#  ('jakarta-mail', 95),
#  ('android-alertdialog', 95),
#  ('jboss6.x', 94),
#  ('portlet', 94),
#  ('storage', 93),
#  ('hsqldb', 93),
#  ('cdi', 93),
#  ('pom.xml', 93),
#  ('adapter', 92),
#  ('ehcache', 92),
#  ('jpanel', 90),
#  ('jdk1.6', 90),
#  ('android-context', 90),
#  ('apk', 90),
#  ('facelets', 89),
#  ('primefaces', 89),
#  ('try-catch', 88),
#  ('android-service', 87),
#  ('surfaceview', 87),
#  ('android-linearlayout', 87),
#  ('screenshot', 87),
#  ('contacts', 87),
#  ('javafx', 86),
#  ('mobile-phones', 86),
#  ('el', 86),
#  ('taglib', 85),
#  ('android-contentprovider', 85),
#  ('rpc', 85),
#  ('listactivity', 84),
#  ('obfuscation', 84),
#  ('message-queue', 83),
#  ('slf4j', 83),
#  ('java-7', 83),
#  ('connection-pooling', 82),
#  ('ivy', 82),
#  ('servlet-filters', 82),
#  ('chat', 81),
#  ('executable-jar', 81),
#  ('dao', 80),
#  ('lift', 80),
#  ('sax', 80),
#  ('apache-camel', 79),
#  ('ioexception', 79),
#  ('javac', 79),
#  ('freemarker', 79),
#  ('jbutton', 79),
#  ('xml-namespaces', 79),
#  ('dtd', 79),
#  ('guava', 79),
#  ('proguard', 78),
#  ('android-webview', 78),
#  ('pojo', 78),
#  ('sd-card', 78),
#  ('ibatis', 77),
#  ('axis', 77),
#  ('jdo', 77),
#  ('sharedpreferences', 76),
#  ('adb', 76),
#  ('accelerometer', 76),
#  ('velocity', 76),
#  ('scrollview', 76),
#  ('websphere-6.1', 75),
#  ('resolution', 75),
#  ('code-coverage', 75),
#  ('icefaces', 75),
#  ('paint', 74),
#  ('android-relativelayout', 74),
#  ('java-ee-5', 74),
#  ('tapestry', 74),
#  ('jnlp', 74),
#  ('gradle', 74),
#  ('rcp', 74),
#  ('stack-trace', 74),
#  ('application-server', 74),
#  ('esb', 72),
#  ('draw', 72),
#  ('nio', 72),
#  ('ibm-mq', 72),
#  ('tablet', 71),
#  ('android-camera', 71),
#  ('equals', 71),
#  ('android-sdk-2.1', 71),
#  ('interceptor', 71),
#  ('resteasy', 70),
#  ('actionlistener', 70),
#  ('jackson', 70),
#  ('selenium-rc', 70),
#  ('jfreechart', 70),
#  ('jta', 69),
#  ('spring-ws', 69),
#  ('gwt-rpc', 69),
#  ('restlet', 69),
#  ('toast', 69),
#  ('dalvik', 69),
#  ('netbeans6.8', 68),
#  ('spring-webflow', 68),
#  ('restart', 68),
#  ('progressdialog', 68),
#  ('adt', 67),
#  ('cassandra', 67),
#  ('tiles', 67),
#  ('scala-2.8', 67),
#  ('sip', 67),
#  ('jmeter', 67),
#  ('vaadin', 67),
#  ('jboss-weld', 67),
#  ('jsp-tags', 67),
#  ('admob', 67),
#  ('specifications', 67),
#  ('screen-orientation', 67),
#  ('entitymanager', 66),
#  ('touch-event', 66),
#  ('jcombobox', 66),
#  ('instrumentation', 66),
#  ('midp', 66),
#  ('look-and-feel', 66),
#  ('qa', 65),
#  ('latitude-longitude', 65),
#  ('logback', 65),
#  ('runtimeexception', 65),
#  ('dependency-management', 65),
#  ('apache-poi', 65),
#  ('mockito', 65),
#  ('grails-plugin', 65),
#  ('ejb-3.1', 65),
#  ('android-ui', 65),
#  ('soapui', 64),
#  ('capture', 64),
#  ('geocoding', 64),
#  ('voip', 64),
#  ('eclipse-wtp', 64),
#  ('expandablelistview', 64),
#  ('viewflipper', 64),
#  ('embedded-jetty', 64),
#  ('android-xml', 63),
#  ('dsl', 63),
#  ('serializable', 63),
#  ('java-6', 63),
#  ('voice', 63),
#  ('android-videoview', 63),
#  ('android-imageview', 63),
#  ('offline', 62),
#  ('selenium-webdriver', 62),
#  ('rabbitmq', 62),
#  ('runnable', 62),
#  ('xerces', 62),
#  ('photo', 62),
#  ('unmarshalling', 61),
#  ('speech-recognition', 61),
#  ('phone-call', 61),
#  ('message-driven-bean', 61),
#  ('tomcat5.5', 61),
#  ('drools', 61),
#  ('processing', 61),
#  ('outputstream', 61),
#  ('smartgwt', 61),
#  ('openjpa', 61),
#  ('inner-classes', 60),
#  ('telephony', 60),
#  ('nexus', 60),
#  ('sts-springsourcetoolsuite', 60),
#  ('portal', 60),
#  ('audio-streaming', 60),
#  ('webdriver', 60),
#  ('hql', 60),
#  ('myfaces', 60),
#  ('bytecode', 60),
#  ('myeclipse', 59),
#  ('websphere-7', 59),
#  ('alfresco', 59),
#  ('back-button', 59),
#  ('sun', 59),
#  ('android-arrayadapter', 58),
#  ('root', 58),
#  ('tablelayout', 58),
#  ('gson', 58),
#  ('progress', 58),
#  ('rad', 58),
#  ('keystore', 58),
#  ('bufferedimage', 58),
#  ('saxparser', 57),
#  ('jboss7.x', 57),
#  ('equinox', 57),
#  ('jaas', 57),
#  ('kml', 57),
#  ('lwuit', 57),
#  ('wav', 57),
#  ('birt', 57),
#  ('swipe', 57),
#  ('jogl', 57),
#  ('audio-recording', 57),
#  ('jtextfield', 56),
#  ('final', 56),
#  ('functional-testing', 56),
#  ('actor', 56),
#  ('htmlunit', 56),
#  ('hibernate-mapping', 56),
#  ('android-appwidget', 55),
#  ('spring-aop', 55),
#  ('cobertura', 55),
#  ('xstream', 55),
#  ('findbugs', 55),
#  ('transformation', 55),
#  ('autowired', 54),
#  ('xquery', 54),
#  ('android-canvas', 54),
#  ('bean-validation', 54),
#  ('distributed-computing', 54),
#  ('ads', 54),
#  ('midlet', 53),
#  ('ireport', 53),
#  ('resultset', 53),
#  ('illegalargumentexception', 53),
#  ('jodatime', 53),
#  ('platform', 53),
#  ('openejb', 53),
#  ('weblogic11g', 53),
#  ('mule', 52),
#  ('atom-feed', 52),
#  ('android-source', 52),
#  ('volume', 52),
#  ('augmented-reality', 52),
#  ('oc4j', 52),
#  ('jtextarea', 52),
#  ('repaint', 52),
#  ('jscrollpane', 52),
#  ('fragment', 52),
#  ('sensors', 51),
#  ('one-to-many', 51),
#  ('metrics', 51),
#  ('live-wallpaper', 51),
#  ('android-image', 51),
#  ('spring-3', 51),
#  ('httpsession', 51),
#  ('shape', 51),
#  ('stripes', 51),
#  ('eclipse-3.6', 51),
#  ('apache-felix', 50),
#  ('feed', 50),
#  ('android-sdk-2.3', 50),
#  ('menuitem', 50),
#  ('broadcast', 50),
#  ('screen-resolution', 50),
#  ('back', 50),
#  ('netbeans-7', 50),
#  ('builder', 50),
#  ('imagebutton', 50),
#  ('gesture', 49),
#  ('android-sdcard', 49),
#  ('java-2d', 49),
#  ('akka', 49),
#  ('filenotfoundexception', 49),
#  ('playback', 49),
#  ('composite', 49),
#  ('jmf', 49),
#  ('keylistener', 49),
#  ('android-actionbar', 49),
#  ('custom-component', 49),
#  ('datanucleus', 49),
#  ('jlabel', 48),
#  ('bufferedreader', 48),
#  ('tostring', 48),
#  ('logcat', 48),
#  ('workspace', 48),
#  ('ontouchlistener', 48),
#  ('nfc', 48),
#  ('multi-touch', 48),
#  ('launcher', 48),
#  ('oncreate', 48),
#  ('jdeveloper', 48),
#  ('headless', 48),
#  ('h2', 48),
#  ('tabactivity', 47),
#  ('toplink', 47),
#  ('transactional', 47),
#  ('managed-bean', 47),
#  ('android-contacts', 47),
#  ('listeners', 47),
#  ('galaxy', 47),
#  ('voice-recognition', 47),
#  ('hotdeploy', 47),
#  ('android-custom-view', 47),
#  ('android-animation', 47),
#  ('3g', 46),
#  ('load-testing', 46),
#  ('android-softkeyboard', 46),
#  ('java-io', 46),
#  ('jna', 46),
#  ('gsm', 46),
#  ('text-to-speech', 46),
#  ('persistent', 46),
#  ('netbeans6.7', 46),
#  ('struts-1', 46),
#  ('toolbar', 46),
#  ('jaxb2', 46),
#  ('java-metro-framework', 46),
#  ('jlist', 45),
#  ('sonarqube', 45),
#  ('microphone', 45),
#  ('resourcebundle', 45),
#  ('avd', 45),
#  ('preview', 45),
#  ('gxt', 44),
#  ('hashcode', 44),
#  ('assert', 44),
#  ('maven-jetty-plugin', 44),
#  ('ddms', 44),
#  ('recording', 44),
#  ('c3p0', 44),
#  ('jdk1.5', 44),
#  ('illegalstateexception', 43),
#  ('intentfilter', 43),
#  ('splash-screen', 43),
#  ('terracotta', 43),
#  ('android-view', 43),
#  ('openjdk', 43),
#  ('checkstyle', 43),
#  ('eclipse-3.5', 43),
#  ('alarmmanager', 43),
#  ('httpurlconnection', 43),
#  ('android-mediaplayer', 43),
#  ('criteria', 43),
#  ('jbpm', 42),
#  ('corba', 42),
#  ('jcomponent', 42),
#  ('apache-servicemix', 42),
#  ('javasound', 42),
#  ('blackberry-jde', 42),
#  ('cruisecontrol', 42),
#  ('aptana', 42),
#  ('wallpaper', 42),
#  ('helios', 42),
#  ('dwr', 42),
#  ('mms', 42),
#  ('netbeans6.5', 42),
#  ('spring-integration', 41),
#  ('rules', 41),
#  ('jpql', 41),
#  ('preferenceactivity', 41),
#  ('java.util.logging', 41),
#  ('rollback', 41),
#  ('listadapter', 41),
#  ('code-formatting', 41),
#  ('surefire', 41),
#  ('resin', 41),
#  ('android-pendingintent', 41),
#  ('saxon', 41),
#  ('keyevent', 41),
#  ('asterisk', 41),
#  ('dbunit', 41),
#  ('amqp', 40),
#  ('web-frameworks', 40),
#  ('jtree', 40),
#  ('permgen', 40),
#  ('eclipse-emf', 40),
#  ('jdialog', 40),
#  ('smartphone', 40),
#  ('jboss-4.2.x', 40),
#  ('touchscreen', 40),
#  ('openstreetmap', 40),
#  ('android-library', 40),
#  ('graphics2d', 40),
#  ('hibernate-validator', 40),
#  ('mybatis', 40),
#  ('spring-batch', 39),
#  ('pcm', 39),
#  ('eclipse-pde', 39),
#  ('wsdl2java', 39),
#  ('bigdecimal', 39),
#  ('stress-testing', 39),
#  ('thrift', 39),
#  ('opengl-es-2.0', 39),
#  ('javax.imageio', 39),
#  ('android-2.1-eclair', 39),
#  ('sqlexception', 39),
#  ('android-wifi', 39),
#  ('eclipse-3.4', 39),
#  ('javadb', 39),
#  ('xalan', 39),
#  ('jconsole', 38),
#  ('jsf-1.2', 38),
#  ('swingworker', 38),
#  ('websphere-portal', 38),
#  ('ejb-2.x', 38),
#  ('requestfactory', 38),
#  ('maven-assembly-plugin', 38),
#  ('nosuchmethoderror', 38),
#  ('fileoutputstream', 38),
#  ('locationmanager', 38),
#  ('ondraw', 38),
#  ('context.xml', 38),
#  ('tabwidget', 38),
#  ('zk', 38),
#  ('simplecursoradapter', 38),
#  ('spring-transactions', 38),
#  ('high-availability', 38),
#  ('barcode', 37),
#  ('oracle-adf', 37),
#  ('android-maps', 37),
#  ('eclipse-indigo', 37),
#  ('cargo', 37),
#  ('android-gallery', 37),
#  ('renderer', 37),
#  ('inflate', 37),
#  ('andengine', 37),
#  ('pmd', 37),
#  ('build.xml', 37),
#  ('fileinputstream', 37),
#  ('blackberry-simulator', 37),
#  ('jsoup', 37),
#  ('easymock', 37),
#  ('apache-commons-dbcp', 37),
#  ('gesture-recognition', 37),
#  ('gsp', 36),
#  ('jfilechooser', 36),
#  ('onresume', 36),
#  ('nexus-s', 36),
#  ('nine-patch', 36),
#  ('jrebel', 36),
#  ('jtabbedpane', 36),
#  ('signing', 36),
#  ('jdbctemplate', 36),
#  ('xml-validation', 36),
#  ('alarm', 36),
#  ('mbeans', 36),
#  ('google-maps-markers', 36),
#  ('jca', 36),
#  ('distributed-transactions', 36),
#  ('urlconnection', 36),
#  ('visualvm', 36),
#  ('xslt-2.0', 36),
#  ('uibinder', 35),
#  ('gestures', 35),
#  ('android-assets', 35),
#  ('ksoap2', 35),
#  ('phone-number', 35),
#  ('android-viewpager', 35),
#  ('activitygroup', 35),
#  ('xmlbeans', 35),
#  ('layout-manager', 35),
#  ('compass-geolocation', 35),
#  ('homescreen', 35),
#  ('httpconnection', 35),
#  ('seekbar', 35),
#  ('internal', 35),
#  ('forward', 35),
#  ('cascade', 35),
#  ('spring-jdbc', 35),
#  ('android-lifecycle', 35),
#  ('jar-signing', 34),
#  ('java-5', 34),
#  ('maven-archetype', 34),
#  ('battery', 34),
#  ('apache-fop', 34),
#  ('tiles2', 34),
#  ('jspx', 34),
#  ('japplet', 34),
#  ('jvm-arguments', 34),
#  ('manifest.mf', 34),
#  ('barcode-scanner', 34),
#  ('api-design', 34),
#  ('number-formatting', 34),
#  ('anonymous-class', 34),
#  ('hudson-plugins', 34),
#  ('ibm-rad', 34),
#  ('castor', 34),
#  ('keytool', 34),
#  ('midi', 34),
#  ('horizontalscrollview', 34),
#  ('shiro', 34),
#  ('wsimport', 34),
#  ('hornetq', 34),
#  ('hbm2ddl', 34),
#  ('power-management', 34),
#  ('jtextpane', 33),
#  ('agent', 33),
#  ('multi-module', 33),
#  ('web-inf', 33),
#  ('eclipse-pdt', 33),
#  ('timertask', 33),
#  ('tibco', 33),
#  ('jaxp', 33),
#  ('blackberry-eclipse-plugin', 33),
#  ('weblogic9.x', 33),
#  ('persistence.xml', 33),
#  ('thread-local', 33),
#  ('composite-component', 33),
#  ('lwjgl', 33),
#  ('decompiling', 33),
#  ('assertions', 33),
#  ('stax', 33),
#  ('eclipse-jdt', 33),
#  ('updates', 33),
#  ('multipartform-data', 33),
#  ('connectivity', 32),
#  ('auto-update', 32),
#  ('tabview', 32),
#  ('jdom', 32),
#  ('cdata', 32),
#  ('geronimo', 32),
#  ('autocompletetextview', 32),
#  ('frame-rate', 32),
#  ('failover', 32),
#  ('springsource', 32),
#  ('motorola', 32),
#  ('policy', 32),
#  ('cglib', 32),
#  ('multipart', 32),
#  ('connector', 32),
#  ('multiple-instances', 32),
#  ('marker', 32),
#  ('layout-inflater', 32),
#  ('emma', 32),
#  ('jface', 32),
#  ('jboss-tools', 32),
#  ('maven-cargo', 32),
#  ('gwt2', 32),
#  ('ringtone', 32),
#  ('direction', 32),
#  ('buildr', 32),
#  ('mojarra', 32),
#  ('nexus-one', 31),
#  ('maven-release-plugin', 31),
#  ('sitemesh', 31),
#  ('titlebar', 31),
#  ('android-progressbar', 31),
#  ('zxing', 31),
#  ('htc-android', 31),
#  ('second-level-cache', 31),
#  ('onpause', 31),
#  ('xoom', 31),
#  ('executorservice', 31),
#  ('liferay-6', 31),
#  ('settext', 30),
#  ('cas', 30),
#  ('artifactory', 30),
#  ('ognl', 30),
#  ('android-sdk-1.6', 30),
#  ('criteria-api', 30),
#  ('named-query', 30),
#  ('android-c2dm', 30),
#  ('netty', 30),
#  ('applicationcontext', 30),
#  ('inject', 30),
#  ('galaxy-tab', 30),
#  ('bamboo', 30),
#  ('android-button', 30),
#  ('dpi', 30),
#  ('jmock', 30),
#  ('restful-authentication', 30),
#  ('audio-player', 30),
#  ('swingx', 30),
#  ('gprs', 30),
#  ('intercept', 29),
#  ('netbeans7.0', 29),
#  ('wap', 29),
#  ('gesturedetector', 29),
#  ('screen-size', 29),
#  ('smack', 29),
#  ('android-cursoradapter', 29),
#  ('ajax4jsf', 29),
#  ('coordinate-systems', 29),
#  ('android-sensors', 29),
#  ('modem', 29),
#  ('business-process-management', 29),
#  ('netbeans-plugins', 29),
#  ('liquibase', 29),
#  ('bytecode-manipulation', 29),
#  ('securitymanager', 29),
#  ('filereader', 29),
#  ('netbeans-platform', 29),
#  ('mobile-application', 29),
#  ('fitnesse', 29),
#  ('lockscreen', 29),
#  ('awtrobot', 29),
#  ('servlet-3.0', 28),
#  ('parcelable', 28),
#  ('android-wake-lock', 28),
#  ('gui-testing', 28),
#  ('scala-collections', 28),
#  ('runtime.exec', 28),
#  ('hibernate-search', 28),
#  ('bytebuffer', 28),
#  ('android-contentresolver', 28),
#  ('android-framelayout', 28),
#  ('reboot', 28),
#  ('screen-capture', 28),
#  ('google-earth', 28),
#  ('libxml2', 28),
#  ('jinternalframe', 28),
#  ('robotium', 28),
#  ('clickable', 28),
#  ('embedded-database', 28),
#  ('java.util.scanner', 27),
#  ('seam3', 27),
#  ('filewriter', 27),
#  ('slidingdrawer', 27),
#  ('viewgroup', 27),
#  ('geocode', 27),
#  ('joptionpane', 27),
#  ('openfire', 27),
#  ('mq', 27),
#  ('android-inflate', 27),
#  ('testcase', 27),
#  ('spock', 27),
#  ('java1.4', 27),
#  ('jsessionid', 27),
#  ('imageicon', 27),
#  ('exif', 27),
#  ('reverse-geocoding', 27),
#  ('ui-thread', 27),
#  ('archetypes', 27),
#  ('demo', 27),
#  ('instanceof', 27),
#  ('sessionfactory', 27),
#  ('p2', 27),
#  ('xa', 27),
#  ('url-mapping', 26),
#  ('proximity', 26),
#  ('listviewitem', 26),
#  ('mouselistener', 26),
#  ('textcolor', 26),
#  ('parameterized', 26),
#  ('comparator', 26),
#  ('smartcard', 26),
#  ('blackberry-storm', 26),
#  ('system-properties', 26),
#  ('selenium-grid', 26),
#  ('vibration', 26),
#  ('jai', 26),
#  ('appserver', 26),
#  ('jspinclude', 26),
#  ('javafx-2', 26),
#  ('speech', 26),
#  ('code-completion', 26),
#  ('scalatest', 26),
#  ('jvm-crash', 26),
#  ('apache-mina', 26),
#  ('geo', 26),
#  ('java-wireless-toolkit', 26),
#  ('glsurfaceview', 26),
#  ('foreground', 26),
#  ('onfling', 26),
#  ('jad', 26),
#  ('url-pattern', 26),
#  ('hibernate-annotations', 26),
#  ('java-3d', 26),
#  ('executor', 26),
#  ('nimbus', 26),
#  ('socketexception', 25),
#  ('restriction', 25),
#  ('midp-2.0', 25),
#  ('stringbuilder', 25),
#  ('one-to-one', 25),
#  ('resume', 25),
#  ('lazy-initialization', 25),
#  ('xjc', 25),
#  ('ivr', 25),
#  ('weak-references', 25),
#  ('project-structure', 25),
#  ('jvm-languages', 25),
#  ('dozer', 25),
#  ('apache-httpclient-4.x', 25),
#  ('j2mepolish', 25),
#  ('jlayeredpane', 25),
#  ('jax-rpc', 25),
#  ('event-dispatch-thread', 25),
#  ('gravity', 25),
#  ('google-talk', 25),
#  ('web-testing', 25),
#  ('simpleadapter', 25),
#  ('jibx', 25),
#  ('calculator', 25),
#  ('file-not-found', 25),
#  ('android-logcat', 25),
#  ('jeditorpane', 25),
#  ('android-resources', 25),
#  ('toplink-essentials', 25),
#  ('docbook', 25),
#  ('grails-domain-class', 25),
#  ('transient', 24),
#  ('wma', 24),
#  ('onitemclicklistener', 24),
#  ('motion', 24),
#  ('rfid', 24),
#  ('pde', 24),
#  ('apache-commons-logging', 24),
#  ('ormlite', 24),
#  ('mapactivity', 24),
#  ('tycho', 24),
#  ('cldc', 24),
#  ('decompiler', 24),
#  ('maven-ear-plugin', 24),
#  ('j-security-check', 24),
#  ('comparable', 24),
#  ('ganymede', 24),
#  ('togglebutton', 24),
#  ('tomahawk', 24),
#  ('spring-annotations', 24),
#  ('encoder', 24),
#  ('sim-card', 24),
#  ('artifacts', 24),
#  ('android-cursor', 24),
#  ('google-geocoder', 24),
#  ('unchecked', 24),
#  ('java-bytecode-asm', 24),
#  ('faces-config', 24),
#  ('artifact', 24),
#  ('hibernate3', 24),
#  ('jcheckbox', 24),
#  ('instant-messaging', 24),
#  ('data-transfer', 24),
#  ('optimistic-locking', 24),
#  ('xslt-1.0', 24),
#  ('appfuse', 24),
#  ('pooling', 24),
#  ('wakelock', 24),
#  ('activity-lifecycle', 24),
#  ('paintcomponent', 24),
#  ('displaytag', 24),
#  ('looper', 24),
#  ('android-homebutton', 24),
#  ('distributed-system', 24),
#  ('qr-code', 24),
#  ('stateful', 24),
#  ('orbeon', 24),
#  ('street-address', 24),
#  ('moxy', 24),
#  ('rule-engine', 24),
#  ('android-notifications', 23),
#  ('miglayout', 23),
#  ('cellular-network', 23),
#  ('monkeyrunner', 23),
#  ('selenium-ide', 23),
#  ('trinidad', 23),
#  ('ui-automation', 23),
#  ('wadl', 23),
#  ('appender', 23),
#  ('spring-test', 23),
#  ('contextpath', 23),
#  ('android-file', 23),
#  ('android-install-apk', 23),
#  ('assertion', 23),
#  ('vxml', 23),
#  ('properties-file', 23),
#  ('hibernate-tools', 23),
#  ('atomikos', 23),
#  ('jde', 23),
#  ('treemap', 23),
#  ('android-menu', 23),
#  ('apache-commons-httpclient', 23),
#  ('hashset', 23),
#  ('tablerow', 23),
#  ('android-location', 23),
#  ('performance-testing', 23),
#  ('buildpath', 23),
#  ('bidirectional', 23),
#  ('absolutelayout', 23),
#  ('xsl-fo', 23),
#  ('listpreference', 23),
#  ('billing', 23),
#  ('msxml', 23),
#  ('zipcode', 23),
#  ('error-code', 23),
#  ('archiva', 22),
#  ('linkedhashmap', 22),
#  ('future', 22),
#  ('xsd-validation', 22),
#  ('galileo', 22),
#  ('audiorecord', 22),
#  ('in-memory-database', 22),
#  ('library-project', 22),
#  ('drm', 22),
#  ('key-bindings', 22),
#  ('mediastore', 22),
#  ('grails-controller', 22),
#  ('jvm-hotspot', 22),
#  ('mmapi', 22),
#  ('pitch', 22),
#  ('throw', 22),
#  ('heap-dump', 22),
#  ('hbm', 22),
#  ('mediarecorder', 22),
#  ('android-scrollview', 22),
#  ('jbehave', 22),
#  ('maven-surefire-plugin', 22),
#  ...]

# %%
f = open("../filter/final_categories.txt", "r")
categories = f.read().split(", ")
categories
# Out:
# ['component',
#  'database',
#  'extension',
#  'environment',
#  'language',
#  'library',
#  'platform',
#  'subsystem',
#  'framework',
#  'ide',
#  'tool',
#  'toolkit',
#  'utility',
#  'system']

# %%
for a, b in sorted(G_1.degree, key=lambda x: x[1], reverse=True):
    if str(G.nodes[a]['root']) != "nan" and str(G.nodes[a]['root']) in categories:
        print(a + "," + str(b) + "," + G.nodes[a]['root'] + "," + node_attr[a]["Body"])
    #else:
    #    print(a + " " + str(b))
# Out:
# java,2737,language,java is a high-level object oriented programming language.
# android,1555,system,android is google's mobile operating system used for programming or developing digital devices (smartphones tablets automobiles tvs wear glass iot).
# eclipse,979,ide,eclipse is an open source ide and platform for building applications.
# spring,645,framework,the spring framework is an open source framework for application development on the java platform.
# user-interface,532,system,user interface (ui) is the system through which people interact with a computer.
# maven,499,tool,apache maven is a build automation and project management tool used primarily for java projects.
# scala,497,language,scala is a general-purpose programming language principally targeting the java virtual machine.
# hibernate,479,library,hibernate is an object-relational mapping (orm) library for the java language enabling developers to utilize pojo-style domain models in their applications in ways extending well beyond object/relational mapping.
# swing,471,toolkit,swing is a user-interface toolkit in java and is shipped with the standard java sdk.
# maven-2,459,tool,apache maven is a software project management and comprehension tool.
# gwt,407,toolkit,gwt (formerly the google web toolkit) is a development toolkit for building and optimizing complex browser-based applications.
# ant,374,tool,apache ant (formerly jakarta ant) is a declarative xml-based build tool created originally for java projects.
# jsf,357,framework,jsf jakarta server faces (formerly known as javaserver faces) is a model-view-presenter framework typically used to create html form based web applications.
# groovy,337,language,groovy is an object-oriented programming language for the java platform.
# java-me,328,platform,java platform micro edition or java me is a java platform designed for embedded systems.
# android-activity,307,component,in android applications an activity is a component that provides a user interface allowing the user to do something.
# sqlite,305,library,sqlite is a software library that implements a self-contained serverless zero-configuration transactional sql database engine.
# eclipse-plugin,283,platform,eclipse is an osgi extensible platform for tool integration.
# intellij-idea,255,ide,intellij idea is an ide by jetbrains.
# osgi,228,system,the osgi (open service gateway initiative) framework is a module system and service platform for the java programming language that implements a complete and dynamic component model.
# jsf-2,209,framework,javaserver faces (jsf) is a model-view-presenter framework typically used to create web applications.
# log4j,207,utility,log4j is a popular java-based logging utility.
# xslt,200,language,xslt is a transformation language for xml designed to transform structured documents into other formats (such as xml html and plain text or in xslt 3 json).
# struts2,196,framework,apache struts 2 is an extensible framework based on servlets and implements model–view–controller (mvc) pattern in its architecture for creating enterprise-ready java web applications.
# seam,173,framework,jboss seam is an open source enterprise framework in java.
# selenium,167,tool,selenium is a popular open-source tool for automating web browsers.
# sms,154,component,short message service (sms) is the standardized text communication service component of phone web or mobile communication systems that allow the exchange of short text messages between fixed line or mobile phone devices.
# playframework,152,framework,play framework is a modern open-source web framework for java and scala.
# maven-3,142,tool,apache maven is a tool for project management and build automation.
# cordova,140,framework,apache cordova (formerly phonegap) is a framework that allows developers to create cross-platform mobile applications using web technologies like html javascript and css.
# wicket,139,framework,apache wicket commonly referred to as wicket is a lightweight component-based web application framework for the java programming language conceptually similar to javaserver faces and tapestry.
# broadcastreceiver,134,component,broadcastreceiver is an android component that responds to system-wide broadcast announcements.
# swt,128,library,swt: the standard widget toolkit is a user interface library for java maintained by the eclipse foundation.
# android-ndk,127,tool,the android native development kit (ndk) is a companion tool to the android sdk that lets build performance-critical portions of apps in native code or port existing libraries in c/c++ to android.
# jstl,126,library,jstl (jsp standard tag library) is a jsp based standard tag library which offers tags to control the flow in the jsp page date/number formatting and internationalization facilities and several utility el functions.
# richfaces,123,library,richfaces was a component library for jsf and an advanced framework for easily integrating ajax capabilities into business applications.
# aspectj,118,extension,aspectj is an aspect-oriented extension to the java programming language that enables clean modularization of crosscutting concerns such as logging error handling standards enforcement and feature variations.
# progress-bar,118,component,a progress bar is a component in a graphical user interface used to convey the progress of a task such as a download or file transfer.
# jenkins,117,tool,jenkins is an open source continuous integration tool written in java that has packages for linux mac os x windows freebsd and openbsd.
# guice,114,framework,guice is a lightweight dependency injection framework for java.
# jasper-reports,110,tool,jasperreports is an open source reporting tool that can be used in all java applications from desktop to web applications.
# testng,108,framework,testng is a testing framework focused on providing both unit and functional testing abilities in the java programming language.
# javadoc,103,system,javadoc is an extensible documentation generation system which reads specially formatted comments in java source code and generates compiled documentation.
# jtable,101,component,jtable is a java swing component used to display and edit regular two-dimensional tables of cells.
# jframe,99,component,a jframe is a component and top-level container of the jfc/swing framework.
# liferay,98,platform,liferay is an open source jsr 286 compliant portal and social platform written in java.
# sbt,97,tool,sbt is an open source build tool for scala and java projects similar to java's maven or ant.
# derby,97,database,derby is an open source relational database implemented entirely in java and available under the apache license version 2.0.
# spring-roo,95,tool,spring roo is a lightweight tool aimed at developer productivity.
# hsqldb,93,system,hsqldb (hypersql database) is a relational database management system.
# android-service,87,component,a service is an application component representing either an application's desire to perform a longer-running operation while not interacting with the user or to supply functionality for other applications to use.
# apache-camel,79,framework,apache camel is an open source integration framework that focuses on quick and easy integration of  systems consuming or producing data.
# freemarker,79,tool,freemarker is a java based template engine a generic tool to generate text output (anything from html to autogenerated source code) based on templates.
# proguard,78,tool,proguard is a tool to shrink optimize obfuscate and preverify java classes.
# ibatis,77,framework,ibatis is an object-relational mapping framework for java.
# adb,76,tool,adb (android debug bridge) is a tool that comes with the android sdk that allows you to control and interface with your android device.
# icefaces,75,library,icefaces is a jsf component library.
# tapestry,74,framework,apache tapestry is a java web application framework that is organized around building pages from reusable components.
# application-server,74,framework,an application server is a software framework dedicated to the efficient execution of procedures (programs routines scripts) for supporting the construction of applications.
# jackson,70,library,jackson is a java library for handling tasks like reading and writing (parsing / generating) and data binding to/from java objects.
# jfreechart,70,library,jfreechart is a free java chart library with many available chart types and support for numerous output types.
# restlet,69,framework,restlet framework is an open source framework for java (and javascript) to expose and consume restful web apis.
# spring-webflow,68,framework,spring webflow is a web-app framework which helps to define the page navigation rules in a intuitive and reusable way.
# apache-poi,65,library,apache poi is a java library for reading and writing various microsoft file formats especially office related ones.
# mockito,65,framework,mockito is a mocking framework for java.
# dsl,63,language,domain-specific language is a programming language intended for a particular application domain
# drools,61,system,drools is a business-rule management system (brms) with a forward-chaining-inference-based rules engine more correctly known as a production rule system using an enhanced implementation of the rete algorithm.
# processing,61,language,processing is an open source programming language and environment for people who want to create images animations interactions and games.
# smartgwt,61,framework,smart gwt is a gwt-based framework that allows you to not only utilize its comprehensive widget library for your application ui but also tie these widgets in with your server-side for data management
# sts-springsourcetoolsuite,60,environment,spring tool suite (sts) is the eclipse-powered development environment for building spring-powered enterprise applications.
# gson,58,library,gson is google's open-source library for serializing and deserializing java objects to/from json.
# jtextfield,56,component,jtextfield is a java swing component that allows the editing of a single line of text.
# cobertura,55,tool,cobertura is a free and open-source java tool based on jcoverage that calculates the percentage of code and branches covered by tests.
# xstream,55,library,xstream is a simple java library to serialize objects to xml and back again.
# xquery,54,language,xquery is a functional language designed to query and manipulate xml data.
# bean-validation,54,framework,bean validation previously commonly called just "jsr-303" is an annotation based validation framework for javabean properties and parameters of arbitrary methods.
# mule,52,platform,mule is a lightweight java-based enterprise service bus (esb) and integration platform that allows developers to connect applications together quickly and easily enabling them to exchange data.
# stripes,51,framework,stripes is an open source web application framework based on the model-view-controller pattern.
# netbeans-7,50,framework,netbeans is a platform development framework and an open-source ide (integrated development environment) for java javascript php etc. netbeans is developed by oracle corporation.
# akka,49,toolkit,akka is an open-source toolkit and runtime simplifying the construction of concurrent and distributed applications on the jvm.
# jdeveloper,48,environment,oracle jdeveloper is an integrated development environment that simplifies the development of java-based soa applications and user interfaces supporting the full software development life cycle.
# h2,48,system,h2 is a relational database management system written in java.
# java-metro-framework,46,framework,metro is a mature web services framework for java.
# jlist,45,component,jlist is a java swing component that displays a list of objects and allows the user to select one or more items.
# sonarqube,45,platform,sonarqube is the open source platform to continuously inspect code quality of applications.
# gxt,44,framework,gxt also known as ext gwt is a dual licensed component framework that seeks to provide similar functionality to extjs for google web toolkit (gwt) applications.
# ddms,44,tool,ddms is an android sdk tool that provides port-forwarding services screen capture on the device thread and heap information on the device logcat process and radio state information incoming call and sms spoofing location data spoofing and more.
# c3p0,44,library,c3p0 is a java library for jdbc drivers with jndi-bindable datasources including datasources that implement connection and statement pooling as described by the jdbc3 spec and jdbc2 std extension.
# checkstyle,43,tool,checkstyle is a static analysis tool for checking compliance of java code to standards.
# cruisecontrol,42,tool,cruisecontrol is both a continuous integration tool and an extensible framework for creating a custom continuous build process.
# dwr,42,library,dwr is a java library that enables java on the server and javascript in a browser to interact and call each other as simply as possible.
# mms,42,extension,multimedia message service(mms) is an extension of the short message service(sms) protocol which allows for multimedia to be passed in messages.
# jpql,41,language,the java persistence query language (jpql) is a platform-independent object-oriented query language defined as part of the java persistence api specification.
# web-frameworks,40,framework,a web application framework is a software framework that is designed to support the development of dynamic websites web applications and web services.
# mybatis,40,framework,mybatis is a framework for mapping objects to relational databases with an emphasis on high performance and simplicity.
# spring-batch,39,framework,spring batch is a lightweight comprehensive framework aimed at enabling the development of  batch applications vital for the daily operations of enterprise systems.
# wsdl2java,39,tool,wsdl2java is a jax-rpc tool that is run against the wsdl file to create java apis and deployment descriptor templates according to these specifications.
# thrift,39,framework,thrift is a software framework for scalable cross-platform cross-language services development available from apache.
# requestfactory,38,component,requestfactory is a component of the google web toolkit that targets developers building data-oriented (crud) applications.
# zk,38,framework,zk is an open-source ajax framework for modern java web applications.
# oracle-adf,37,framework,oracle adf is an end-to-end java ee framework that simplifies application development by providing out of the box infrastructure services and a visual and declarative development experience.
# easymock,37,framework,easymock is a mocking framework for java.
# gsp,36,language,groovy server pages (gsp) is a presentation language for web applications similar to jsp.
# jfilechooser,36,component,jfilechooser is a java swing component to provide a simple mechanism for the user to choose a file.
# visualvm,36,tool,visualvm is a visual tool integrating several commandline jdk tools and lightweight profiling capabilities.
# tiles2,34,framework,apache tiles™ is a java templating framework built to simplify the development of web application user interfaces.
# jspx,34,framework,jspx  is a free open source pure java web rapid application development framework
# ibm-rad,34,ide,ibm rational application developer for websphere software (rad) is an eclipse-based ide made by ibm's rational software division for visually designing constructing testing and deploying web services portals and java enterprise edition applications.
# castor,34,framework,castor is an open source data binding framework.
# shiro,34,framework,apache shiro is a java security framework that performs authentication authorization cryptography and session management.
# wsimport,34,tool,wsimport is a command-line tool to generate client and service artifacts from wsdl.
# eclipse-pdt,33,ide,eclipse pdt is an open source ide for php developers.
# jdom,32,library,jdom is an open source library for working with a java representation of an xml document.
# springsource,32,framework,springsource is an application framework for java orientated at enterprise applications.
# cglib,32,library,cglib (code generation library) is a run time code generation library for the java platform licensed under the apache 2.0 license.
# emma,32,toolkit,emma is an open-source toolkit that measures and reports the percentage of java code covered by unit tests.
# sitemesh,31,framework,sitemesh is a java web application development framework developed by opensymphony.
# jmock,30,framework,jmock is a helper framework for test-driven development and unit testing.
# smack,29,library,smack is an xmpp (jabber) client library written in java for android and java se.
# liquibase,29,library,liquibase is an open source database-independent library for tracking managing and applying database changes.
# netbeans-platform,29,framework,the netbeans platform is a cross-platform desktop application framework implemented in java.
# fitnesse,29,framework,fitnesse is an acceptance testing framework.
# jinternalframe,28,component,jinternalframe is a lightweight java swing component that provides many of the features of a native frame including dragging closing becoming an icon resizing title display and support for a menu bar.
# robotium,28,framework,robotium is an android test automation framework that has full support for native and hybrid applications.
# embedded-database,28,system,an embedded database system is a database management system (dbms) which is tightly integrated with an application software that requires access to stored data such that the database system is “hidden” from the application’s end-user and requires little or no ongoing maintenance.
# spock,27,framework,spock is a testing and specification framework for java and groovy applications.
# archetypes,27,framework,archetypes is a framework designed to ease the building of applications for plone and cmf.
# p2,27,system,p2 is the platform provisioning system used by the eclipse ide and the eclipse rcp framework.
# apache-mina,26,framework,excerpt from apache site :  apache mina is a network application framework which helps users develop high performance and high scalability network applications easily.
# xjc,25,tool,xjc is a jaxb tool for compiling xsd (xml schema) to java source code.
# ivr,25,system,an ivr (interactive voice response) is a system that provides callers to a telephony network typically an organization or call center with an automated interface.
# jibx,25,tool,jibx is a tool for binding xml data to java objects.
# ormlite,24,framework,ormlite is a java open source software framework that provides lightweight object relational mapping (orm) between java classes and sql databases.
# tycho,24,extension,tycho is a maven extension for building eclipse artifacts: eclipse plug-ins/osgi bundles features p2 repositories and rcp applications/eclipse distributions
# tomahawk,24,library,tomahawk is a jsf component library.
# java-bytecode-asm,24,library,asm is a java library used for jvm bytecode manipulation and creation.
# appfuse,24,framework,appfuse is a full-stack framework for building web applications on the jvm.
# moxy,24,component,moxy is the object-to-xml and object-to-json component of eclipselink.
# cellular-network,23,system,a cellular network is a radio communication system characterised by a network of stationary transceivers spread over a wide geographical area for example a city or a country.
# monkeyrunner,23,tool,monkeyrunner is tool from android sdk which provides an api for writing programs that control an android device or emulator from outside of android code.
# selenium-ide,23,tool,the selenium-ide (integrated development environment) is the tool you use to develop your selenium test cases.
# trinidad,23,library,trinidad is a jsf component library.
# jde,23,environment,the blackberry® java® development environment (blackberry jde) is a fully integrated development environment and simulation tool for building java platform micro edition (java® me) applications for java® based blackberry smartphones.
# xsl-fo,23,language,xsl-fo (xsl formatting objects) is a markup language for xml document formatting which is most often used to generate printed content.
# zipcode,23,system,zip codes are a system of postal codes used by the united states postal service (usps) since 1963.
# galileo,22,system,galileo is a global satellite navigation system (gnss) akin to gps but designed built and launched by the european union
# in-memory-database,22,system,an in-memory database (imdb; also main memory database system or mmdb) is a database management system that primarily relies on main memory for computer data storage.
# jbehave,22,framework,jbehave is a java-based framework supporting behavior-driven development (bdd) an evolution of test-driven development (tdd) and acceptance test–driven development (atdd).
# virtual-keyboard,22,component,a virtual keyboard is a software component that allows a user to enter characters.
# jmockit,22,framework,jmockit is a java framework for mocking objects in junit testing.
# ejbql,21,language,ejb ql is a query language provided for navigation across a network of enterprise beans and dependent objects defined by means of container managed persistence.
# aidl,21,language,android interface definition language is a special language that allows a server and a client to establish interface for inter process communication (ipc).
# gwt-ext,21,library,gwt-ext is an open source gwt widget library.
# jprogressbar,21,component,jprogressbar is a java swing component that visually displays the progress of some task.
# jung,21,library,jung is an open-source java library for representing manipulating analyzing and visualizing graph and network data.
# javassist,20,library,javassist is a class library for editing bytecode in java.
# libgdx,20,framework,'libgdx' is an open-source cross-platform java game development framework based on opengl (es) that works on windows linux mac os x android ios and webgl enabled browsers.
# hamcrest,20,library,hamcrest is an open source library of constraint classes used to match objects and values typically by other frameworks such as unit testing mocking or collections.
# robolectric,20,framework,robolectric is a unit testing framework that allows android applications to be tested on the jvm in seconds without using an emulator or device.
# ksoap,20,library,ksoap is a soap web service client library for constrained java environments such as applets or j2me applications.
# dom4j,19,library,dom4j is an open source library for working with xml xpath and xslt on the java platform using the java collections framework and with full support for dom sax and jaxp.
# jprofiler,19,tool,jprofiler is a commercially licensed java profiling tool developed by ej-technologies gmbh targeted at java ee and java se applications.
# geotools,18,library,geotools is an open source java library that provides tools for geospatial data (http://geotools.org).
# pdfbox,18,tool,the apache pdfbox library is an open source java tool for working with pdf documents.
# autoit,17,language,autoit v3 is a freeware basic-like scripting language designed for automating the windows gui and general scripting.
# jsplitpane,17,component,jsplitpane is a java swing component used to divide two (and only two) components.
# magnolia,17,system,magnolia is an open source java- and jcr-based content management system targeted at the enterprise.
# spring-webflow-2,17,framework,spring webflow is a web-app framework which helps to define the page navigation rules in a intuitive and reusable way.
# xdoclet,17,library,xdoclet is an open-source code generation library that enables attribute-oriented programming for java via insertion of special javadoc tags.
# jboss-arquillian,17,platform,jboss arquillian is a testing platform for the jvm that enables developers to create automated integration functional and acceptance tests for java middleware.
# jgroups,17,library,jgroups is a java networking library that supports reliable group communication over udp (ip multicast) or tcp.
# jvisualvm,16,tool,jvisualvm is a java virtual machine monitoring troubleshooting and profiling tool.
# wml,16,language,wml is a markup language intended for devices that implement the wireless application protocol (wap) specification.
# blackberry-webworks,16,platform,webworks is an html5 based platform created by research in motion for building applications for blackberry smartphones and tablets.
# catalina,16,component,catalina is tomcat's component that interacts with java servlets.
# opencms,15,system,opencms is an open source content management system  written in java.
# wlst,15,environment,wlst (weblogic scripting tool) is a command-line scripting environment that can be used to create manage and monitor weblogic domains.
# java-home,15,environment,java_home is an environment variable which should point to the root directory of the jdk installation.
# spring-social,15,extension,spring social is an extension of the spring framework that enables applications to connect with software-as-a-service providers such as twitter facebook and other oauth authentication based apis.
# realm,15,platform,the realm platform is a data synchronization platform for mobile applications.
# spring-el,14,language,the spring expression language (spel for short) is a powerful expression language that supports querying and manipulating an object graph at runtime.
# restlet-2.0,14,framework,restlet is a lightweight comprehensive open source rest framework for the java platform.
# google-latitude,14,tool,google latitude is a (now discontinued) tool to track and share your location.
# visual-editor,14,extension,visualeditor is a mediawiki extension that provides a rich-text editor for wikipedia and other wikis.
# testcomplete,14,platform,testcomplete is a functional automated testing platform developed by smartbear software.
# cactus,14,framework,jakarta cactus is a framework for unit testing server-side java code.
# axiom,14,library,axiom is a java library developed by apache that provides an xml object model implementation.
# apache-tiles,14,framework,apache tiles is a framework that allows authors to define html page fragments which can be assembled into a complete page at runtime.
# robotframework,14,framework,the robot framework is a generic test automation framework for acceptance testing and acceptance test-driven development (atdd).
# querydsl,14,framework,querydsl is a framework which enables the construction of type-safe sql-like queries for multiple backends including jpa mongodb and sql in java.
# sikuli,14,tool,sikuli is a java based automation tool available for windows macos and linux that automates tasks using screen visual inspection.
# rxtx,13,library,rxtx is a java library using a native implementation (via jni) providing serial and parallel communication for the java development toolkit (jdk).
# jslider,13,component,jslider is a java swing component that lets the user graphically select a value by sliding a knob within a bounded interval.
# spring-ldap,13,library,spring ldap is a java library for simplifying ldap operations based on the pattern of spring's jdbctemplate.
# exist-db,13,system,exist-db is an open source database management system built using xml technology.
# gwt-platform,13,framework,gwt-platform or gwtp is a framework to facilitate the development of large applications for the google web toolkit (gwt).
# javahelp,13,system,javahelp is an online help system for java applications.
# infinispan,13,platform,infinispan is an asl2 licensed data grid platform for java and other jvm languages providing a distributed in-memory cache as well as a clustering toolkit.
# apache-wink,12,framework,apache wink is a simple yet solid framework for building restful web services.
# webwork,12,framework,webwork was a java-based web application framework developed by opensymphony that merged into the current struts 2 framework.
# rational-rsa,12,tool,rational software architect is an eclipse-based uml modelling tool made by ibm/rational.
# jboss-portal,12,platform,jboss-portal is a platform that provides a runtime environment for jsr168 and jsr286 portlets.
# oracle-service-bus,12,component,oracle enterprise service bus is a fundamental component of oracle's services-oriented architecture that provides a loosely-coupled framework for inter-application messaging.
# draw2d,12,toolkit,draw2d is a layout and rendering toolkit for displaying graphics on an swt canvas
# batik,12,toolkit,batik is a java-based toolkit for applications or applets that want to use images in the scalable vector graphics (svg) format for various purposes such as display generation or manipulation.
# series-40,12,platform,series 40 is an embedded software platform that is used on nokia's mid-tier smartphones.
# qpid,12,system,apache qpid™ is a cross-platform enterprise messaging system which implements the advanced message queuing protocol (amqp) providing message brokers written in c++ and java along with clients for c++ java jms .net python and ruby.
# loadrunner,12,tool,loadrunner is a commercial performance testing tool supplied by hp.
# woodstock,12,library,project woodstock is an abandoned jsf 1.x component library.
# android-sdk-tools,11,component,sdk tools is a downloadable component for the android sdk.
# black-box,11,system,a black box is a device system or object which can be viewed in terms of its input output and transfer characteristics without any knowledge of its internal workings.
# expat-parser,11,library,expat is an xml parser library written in c
# documentum,11,platform,documentum is an enterprise content management platform now delivered by emc corporation as well as the name of the software company that originally developed the technology.
# osb,11,component,oracle enterprise service bus is a fundamental component of oracle's services-oriented architecture that provides a loosely-coupled framework for inter-application messaging.
# plexus,11,framework,plexus is a software framework for building modular applications using dependency injection.
# flyway,11,tool,flyway by boxfuse is an open-source database migration tool.
# stagefright,11,framework,stagefright is the android media framework.
# jtableheader,11,component,jtableheader is the swing component which manages the header of the jtable.
# worldwind,11,library,worldwind is a geospatial graphical library open-sourced by nasa available in .net java java/android and xcode and based on opengl.
# jrules,11,system,jrules is a business rules management system used to create run and govern rule-based applications.
# exslt,11,library,exslt is an extension library for xslt mainly for xslt 1.0. it includes functionality to provide missing language features such as set operations node-set coercion date methods math functions and type checking.
# lombok,11,tool,project lombok is a tool for reducing boilerplate code in java through annotations and compile time code generation.
# gridgain,10,platform,gridgain is a high performance in-memory platform that enables processing of terabytes of data in-memory on 1000s of computers in less than a second.
# wgs84,10,system,wgs 84 is the reference coordinate system used by the global positioning system
# apache-cocoon,10,framework,apache cocoon usually just called cocoon is a web application framework built around the concepts of pipeline separation of concerns and component-based web development.
# jsfunit,10,framework,jsfunit is a test framework for java serverfaces
# aether,10,library,aether is a java library that provides a foundation of standards and best practices for tools and systems that need to interact with software artifact libraries.
# kotlin,10,language,kotlin is a high-level programming language developed by jetbrains.
# freeswitch,10,platform,freeswitch is a scalable open source cross-platform telephony platform designed to route and interconnect popular communication protocols using audio video text or any other form of media.
# xpand,10,language,xpand is a language specialized on code generation for eclipse.
# cocos2d-android,10,framework,cocos2d is an open source framework for building 2d games and graphical applications.
# yourkit,10,tool,yourkit is a cpu and memory profiling tool for java and .net
# openfaces,10,library,openfaces is an open-source library of ajax-powered jsf components an ajax framework and a client-side validation framework.
# skia,10,library,skia is a complete c++ 2d graphics library for drawing text geometries and images.
# jarjar,10,utility,jar jar links is a utility that makes it easy to repackage java libraries and embed them into your own distribution.
# app-inventor,10,environment,app inventor is a graphical programming environment for making android apps originally developed by google and now run by mit as an open source project.
# jasypt,10,library,jasypt is a java-based encryption library designed for ease of use with minimum necessary knowledge of how cryptography works.
# dynamic-jasper,10,library,dynamicjasper (dj) is an open source free library that hides the complexity of jasper reports.
# mirah,9,language,mirah is a statically typed programming language with ruby-like syntax.
# geb,9,library,geb is a library for headless web browsing on the jvm suitable for automation and functional web testing.
# voicemail,9,system,a voicemail is an electronic communication system in which spoken messages are recorded or digitized for later playback to the intended recipient.
# unitils,9,framework,unitils is an framework that makes unit testing with junit and dbunit smoother and more pleasant.
# sahi,9,tool,sahi is a web browser automation tool used for writing functional test suites for web sites and web applications.
# bluej,9,ide,bluej is a popular java ide aimed at teaching the principles of object oriented programming.
# nokia-s40,9,platform,nokia series 40 is a software platform and application user interface (ui) software on nokia's broad range of mid-tier feature phones.
# hazelcast,9,platform,hazelcast is an open source in-memory data grid platform.
# pbx,9,system,pbx is a system that connects telephone extensions of a company to outside public telephone network as well as to mobile networks
# actionbarsherlock,9,extension,actionbarsherlock is an extension of the compatibility library designed to facilitate the use of the action bar design pattern across all versions of android with a single api.
# asadmin,9,tool,asadmin is a tool for administrative tasks for the oracle glassfish server which is commonly used in the command line.
# jtreetable,9,component,jtreetable is a java swing component that combines tree and table capabilities in one.
# lambdaj,9,library,lambdaj is a library to manipulate a collections without any iterations.
# pax-runner,8,tool,pax runner is a tool to provision osgi bundles in all major open source osgi framework implementations (felix equinox knopflerfish concierge).
# dx,8,tool,dx is a tool that comes with the android sdk that is used to convert java bytecode to dalvik bytecode
# jbuilder,8,ide,jbuilder is a ide for java developed by embarcadero technologies.
# soot,8,framework,soot is an open source java optimization framework.
# greendroid,8,library,greendroid is a development library for the android platform.
# groovyws,8,library,groovyws was a library for creating and consuming ws-i compliant web services.
# asmack,8,environment,before smack added native support for android in smack 41 asmack was the build environment for using the smack library on android enabling xmpp protocols.
# xbrl,8,language,xbrl is the extensible business reporting language.
# jpcap,8,library,jpcap is a java library which enables you to send and capture packets.
# jdepend,8,tool,jdepend is a tool that traverses java class file directories and generates software package metrics (most importantly dependency cycle detection and distance from the main sequence) to measure the design quality for java packages.
# bnd,8,tool,bnd is a java tool for automated building bundles for an osgi environment.
# mockrunner,8,framework,mockrunner is a lightweight framework for unit testing applications in the j2ee environment.
# apache-pivot,8,framework,apache pivot is a gui framework for java to build rias / iias.
# schematron,8,language,schematron is a structural rule-based validation language for xml documents.
# jgrapht,8,library,jgrapht is a free java graph library that provides mathematical graph-theory objects and algorithms.
# libxslt,8,library,libxslt is the xslt c library developed for the gnome project.
# javolution,8,library,javolution is a hard-real-time collections library.
# m4a,8,extension,m4a stands for mpeg 4 audio it is a filename extension used to represent audio files.
# fit-framework,7,tool,framework for integrated test or "fit" is an open-source tool for automated tests.
# orchestra,7,library,apache myfaces orchestra is a small library that can be used in web applications to provide features such as conversation-scope persistence contexts and declarative transaction annotations.
# path-variables,7,environment,path is an environment variable on various operating systems which specifies a list of directories where executable programs are located.
# wicket-1.4,7,framework,apache wicket commonly referred to as wicket is a lightweight component-based web application framework for the java
# scalatra,7,framework,scalatra is a tiny scala web framework inspired by sinatra.
# jdoql,7,language,jdoql is the query language of the jdo persistence api. jdoql is designed as the java developers way of having the power of sql queries yet retaining the java object relationship that exist in their application model.
# circumflex-orm,7,framework,circumflex orm is an object-relational mapping framework written in scala for creating concise and efficient data-centric applications with a dsl resembling the syntax of sql.
# esper,7,library,esper is a lightweight open-source library for cep (complex event processing) and esp (event stream processing) applications developed by espertech inc.
# lwuit-resource-editor,7,tool,the resource editor is an independent gui tool for opening creating and editing resource packages for lwuit.
# sip-server,7,component,a sip server is the main component of an ip pbx dealing with the setup of all sip calls in the network.
# docx4j,7,library,docx4j is an open source (aslv2) java library for manipulating microsoft openxml files (word docx powerpoint pptx and excel xlsx) via jaxb
# cxfrs,7,component,cxfrs is an apache camel component that provides integration with apache cxf for connecting to jax-rs services hosted in cxf.
# xwork,7,framework,xwork is a command-pattern framework that is used to power struts 2 as well as other applications.
# mvel,7,language,mvel is a powerful expression language for java-based applications.
# scala-dispatch,7,library,dispatch is a library for asynchronous http interaction.
# scaladoc,7,system,scaladoc is a documentation generation system which reads specially formatted comments in scala source code and generates compiled documentation.
# scribe,7,library,scribe is a simple oauth library for java
# smali,7,language,smali is the assembly language for the android dalvik virtual machine and is based on the jasmin java assembly language.
# jpf,7,environment,java path finder (jpf) is a highly customizable execution environment for verification of java bytecode programs.
# scalacheck,6,tool,scalacheck is a powerful tool for automatic unit testing of scala and java programs.
# apache-chainsaw,6,tool,chainsaw is a free open source java-based log viewer tool mainly intended as a log4j companion.
# andromda,6,framework,andromda is a framework for creating components from case-models.
# luntbuild,6,tool,luntbuild is a build automation and management tool.
# ebean,6,tool,ebean is an open source object relational mapping tool.
# blackboard,6,system,blackboard is a learning management system used by thousands of schools around the world.
# jfugue,6,library,jfugue is an open-source library for programming music for java and jvm languages.
# castor-jdo,6,framework,castor jdo is an open source data binding framework for java[tm].
# mobility,6,framework,mobility is a pluggable translation framework for ruby.
# richdatatable,6,component,a rich:datatable is a ui component which allow create a table dynamically.
# apache-commons-exec,6,library,apache commons exec is a java library that makes it easier to launch external processes from a java application.
# wcat,6,tool,web capacity analysis tool (wcat) is a lightweight http load generation tool primarily designed to measure the performance of a web server within a controlled environment.
# doxia,6,framework,maven doxia is a content generation framework for generating static and dynamic content.
# kryo,6,framework,kryo is a fast and efficient object graph serialization framework for java.
# javaloader,6,library,do not confuse this tag with java class loader javaloader is a library used with coldfusion to support integration and development of java.
# oaw,6,framework,openarchitectureware is a framework of model-driven technologies such as code generation (xpand) language definition (xtext) and model instance extension (xtend).
# jcreator,6,environment,jcreator is an open source integrated development environment (ide) with a moderate to small user base.
# websphere-commerce,6,platform,ibm websphere commerce is ibm's e-commerce platform
# spring-insight,6,tool,spring insight is a real-time instrumentation tool for java applications providing metrics into application behavior and performance.
# smslib,6,library,smslib is a programmer's library for sending and receiving sms messages via a gsm modem or mobile phone.
# opencsv,6,library,opencsv is a simple csv (comma-separated values) parser library for java
# jericho-html-parser,6,library,jericho html parser is a java library allowing analysis and manipulation of parts of an html document including server-side tags while reproducing verbatim any unrecognised or invalid html.
# kundera,6,library,kundera is a jpa 2.1-compliant object-datastore mapping library for nosql datastores.
# apache-commons-io,5,library,apache commons io is a library of utilities to assist with developing io functionality.
# jline,5,library,jline is a java library for handling console input.
# fastboot,5,tool,fastboot is a tool that comes with the android sdk.
# marklogic,5,database,marklogic server is a multi-model database.
# phpcassa,5,library,phpcassa is a php client library (port of pycassa) for apache cassandra
# jcs,5,system,jcs is a distributed caching system written in java.
# gate,5,framework,gate is a java framework for developing natural language processing applications.
# wcs,5,framework,ibm websphere commerce also known as wcs (websphere commerce suite) is a software platform framework for e-commerce including marketing sales customer and order processing functionality in a tailorable integrated package.
# appframework,5,library,"intel app framework" is a javascript library and the successor of jqmobi.
# rhapsody,5,environment,ibm rational rhapsody is a visual development environment for systems engineers and software developers creating real-time or embedded systems and software.
# scala-xml,5,library,scala xml is the standard xml library built for scala.
# avro,5,framework,apache avro is a data serialization framework primarily used in apache hadoop.
# mongodb-scala,5,database,mongodb is a scalable high-performance open source document-oriented database.
# basic4android,5,environment,basic4android (basic for android) is a simple and powerful development environment for developers of android applications
# quaqua,5,library,quaqua is a java library that provides enhancements to apple's aqua look and feel.
# quickbuild,5,tool,quickbuild is pmease's build automation and management tool derived from luntbuild.
# btrace,5,tool,btrace is a safe dynamic tracing tool for java.
# jscience,5,library,jscience is a comprehensive java library for scientific computing.
# dltk,5,tool,dltk (dynamic languages toolkit) is a tool for vendors researchers and end-users who rely on dynamic languages.
# codepro,5,tool,codepro analytix is java software testing tool owned by google.
# sun-codemodel,5,library,codemodel is a java library for code generators.
# p6spy,5,framework,p6spy is a framework that enables database activity to be seamlessly intercepted and logged with no code changes to the application.
# gemfire,5,database,pivotal gemfire is a distributed in-memory database developed in java that provides real-time data management for applications consistent transactional storage across nodes and resilient clustering.
# voldemort,5,system,voldemort is a distributed key-value storage system used by linkedin.
# blueprint,5,framework,blueprint is a css framework that comes with an easy-to-use grid sensible typography useful plugins and a stylesheet for printing.
# jack,5,library,jack is a code library for handling real-time low latency audio (and midi).
# flexjson,5,library,flexjson is a lightweight library for serializing and deserializing java objects into and from json.
# xmlmapper,4,library,xmlmapper is a third-party library for mapping xml to objects written in swift.
# qf-test,4,tool,qf-test is a gui test tool for java and web.
# android-broadcastreceiver,4,component,broadcastreceiver is an android component that responds to system-wide broadcast announcements.
# bass,4,library,bass is an audio library for use in software on several platforms.
# multiuserchat,4,extension,multi-user chat (muc) is an xmpp protocol extension for multi-user text chat whereby multiple xmpp users can exchange messages in the context of a room or channel similar to irc. in addition to standard chatroom features such as room topics and invitations the protocol defines a strong room control model including the ability to kick and ban users to name room moderators and administrators to require membership or passwords in order to join the room.
# oval,4,framework,oval (object validation framework) is a validation framework for java objects
# jbox2d,4,extension,jbox2d is a java physics engine often used in games an other physics simulations and is a port/extension of the c++ physics engine box2d.
# eclipse-m2t-jet,4,framework,*java emitter templates* (jet) is an eclipse framework that can generate eclipse resources (projects folders and files) from an input model.
# maven-embedder,4,tool,maven is a project development management and comprehension tool.
# ruboto,4,framework,ruboto – ruby on android - is a framework for writing full android apps in ruby.
# tridion,4,platform,sdl tridion is a web content management software platform that supports both java and .net architectures.
# camunda,4,platform,camunda bpm is a light-weight open source platform for business process management and execution.
# jboss-forge,4,tool,jboss forge is a software development tool that extends your java ide providing wizards and extensions (add-ons) for different technologies and solutions.
# jsonix,4,library,jsonix is a javascript library which provides json-xml interfaces that allows to marshalling and unmarshalling json to/from xml.
# alloy,4,language,alloy from mit is a declarative specification language for expressing complex structural constraints and behavior in a software system and a tool for exploring and checking properties of the resulting structures.
# codenarc,4,tool,codenarc is a static analysis tool for groovy source code enabling monitoring and enforcement of many coding standards and best practices.
# exificient,4,library,exificient is a java library for for reading and writing exi files.
# wicket-tester,4,framework,wicket-tester is a unit testing framework specifically built for use with web sites/applications built with the apache wicket framework.
# xbl,4,language,xbl is a declarative xml language which implements the publish/subscribe pattern.
# android-seekbar,4,extension,a seekbar is an extension of progressbar that adds a draggable thumb.
# ccxml,4,language,ccxml call control xml is a w3c standard language to control telephony systems (both sip and pstn).
# openmap,4,toolkit,openmap is a java beans based toolkit for building applications and applets needing geographic information.
# bionic,4,library,bionic is a c language support library (libc) written by google for its android operating system.
# ...
# alfresco-share,3,environment,alfresco share is a web-based collaboration environment for managing documents wiki content blogs and more.
# eclipse-formatter,3,tool,the eclipse code formatter is a tool for performing automatic styling of code in eclipse.
# jzy3d,3,library,jzy3d is an open-source java library that allows you to easily draw 3d scientific data.
# apache-forrest,3,framework,apache forrest software is a publishing framework that transforms input from various sources into a unified presentation in one or more output formats.
# android-graphview,3,library,graphview is a library for android to programmatically create flexible and nice-looking diagrams.
# sedna,3,database,sedna is an xml database with bindings to many programming languages
# supercollider,3,language,supercollider is an environment and programming language for real time audio synthesis and algorithmic composition.
# mt4j,3,framework,mt4j - multitouch for java™ - is an open source java™ framework created for rapid development of visually rich applications.
# jgrasp,3,environment,jgrasp is a lightweight development environment created specifically to provide automatic generation of software visualizations to improve the comprehensibility of software.
# help-balloon,3,system,balloon help was a help system introduced by apple computer in their 1991 release of system 7.0. the name referred to the way the help text was displayed in "balloons" like those containing the words in a comic strip.
# apache-cayenne,3,framework,apache cayenne is an open source persistence framework providing object-relational mapping (orm) and remoting services.
# uispec4j,3,framework,uispec4j is an open source functional and unit testing framework for swing-based java applications built on top of the junit test harness.
# intellij-10,3,ide,intellij idea is a popular ide by jetbrains.
# jdesktop,3,library,jdesktop is a javascript library for those who prefer creating web applications in an object oriented way.
# pylot,3,tool,pylot is a free open source tool for testing performance and scalability of web services
# piccolo,3,toolkit,piccolo2d is a toolkit that supports the development of 2d structured graphics programs in general and zoomable user interfaces (zui) in particular.
# exmpp,3,library,exmpp is an xmpp library written in erlang.
# ibm-jsf,3,library,ibm facesclient framework is an ibm-proprietary closed-source jsf 1.x based component library from ~2004 which is included in websphere 5.x / rad 6.x along with a visual editor.
# paf,3,database,postcode address file (paf) is a database of all known uk addresses and postcodes.
# sshj,3,library,sshj is an ssh client library written in java.
# vraptor,3,framework,vraptor is an open source java mvc framework focused in simplicity.
# scriptom,3,library,scriptom is a java library for scripting com objects
# jtwitter,3,library,jtwitter is a small library providing easy access to the twitter api.
# ddlutils,3,utility,ddlutils is an apache utility which generates database schemas (tables fields) for multiple databases using a common xml format.
# greenfoot,3,environment,greenfoot is an environment that makes it very easy to create 2d animations and games using java.
# jlink,3,tool,jlink is a tool used in java 9 or higher to assemble and optimize a set of modules and their dependencies into a custom runtime image.
# openxava,3,framework,openxava is an ajax java framework for rapid development of enterprise applications
# tla+,3,language,tla+ is a language and toolchain for specifications based on tla the temporal logic of actions.
# grails-2.0,3,framework,grails is a web application framework that uses groovy and java.
# apache-commons-math,3,library,apache commons math is a library of lightweight self-contained mathematics and statistics components addressing the most common problems not available in the java programming language or apache commons lang.
# antbuilder,3,tool,ant is a software tool for automating software build processes.
# dotcms,3,system,dotcms is an open source java based content management system (cms) or if you prefer: web content management system (wcm).
# spring-surf,3,framework,spring surf is a scriptable web framework that powers the presentation tier rendering capabilities of applications in the alfresco application suite.
# jppf,3,framework,jppf is an open source framework and grid computing middleware written in java that makes it easy to parallelize computationally intensive tasks and execute them on a grid
# xfdl,3,language,xfdl is a high-level computer language that defines a form as a single stand-alone object using xml structure.
# gf,3,language,gf grammatical framework is a programming language for multilingual grammar applications.
# spark-java,3,framework,spark is a lightweight web application framework inspired by ruby's sinatra.
# spatialite,3,library,spatialite is a library extending the basic sqlite core in order to get a full fledged spatial dbms.
# millennial-media,3,platform,millennial media is a platform in digital advertising providing opportunities for both advertisers and developers.
# playn,3,framework,playn is an open-source cross-platform game development framework that provides a single java api that can be used to generate html5 android ios and desktop java/applet clients.
# scalaxb,3,tool,scalaxb is an xml data-binding tool for scala that supports w3c xml schema (xsd) and web services description language (wsdl) as the input file.
# dashlet,3,component,a dashlet is a component within the alfresco share web user interface.
# fluentcassandra,3,library,fluentcassandra is a .net library for the cassandra database.
# jcurses,2,library,the java curses library (jcurses) is a library for developing text terminal based applications using java programming language.
# beehive,2,framework,apache beehive is a java application framework designed to make the development of java ee based applications quicker and easier.
# ibm-jvm,2,component,the ibm® java™ virtual machine (jvm) is the core component of the ibm java runtime environment (jre).
# openscript,2,ide,openscript is an ide for creating test scripts.
# ehcache-bigmemory,2,extension,bigmemory is an extension to the enterprise ehcache that allows java system to cache large amounts of data in process but free of the constraints of garbage collection.
# spray,2,toolkit,spray is an open-source toolkit for building rest/http-based integration layers on top of scala and akka.
# epublib,2,library,epublib is a java library for reading epub files available for android as well.
# occam-pi,2,language,occam-pi is a concurrent programming language using the process-oriented programming model which aims to make it straightforward to write correct expressive concurrent programs.
# kestrel,2,system,kestrel is a simple distributed message queue system written in scala.
# jmyron,2,library,jmyron is an external library for processing that allows image manipulation
# pmml,2,language,the predictive model markup language aka `pmml` is an `xml`-based markup language developed by the data mining group (dmg) to provide a way for applications to define models related to predictive analytics and data mining and to share those models between `pmml`-compliant applications.
# scalala,2,library,scalala is the linear algebra library for scala.
# 7digital,2,platform,7digital is an open music platform with the broadest catalogue of fully licensed high quality music.
# pike,2,language,pike is an interpreted object-oriented dynamic programming language with a syntax similar to c. it includes a powerful modules system that for instance has image manipulation database connectivity and advanced cryptography.
# functional-java,2,library,functional java is is an open source library to learn and implement functional programming concepts in java.
# libexif,2,library,libexif is an exif tag parsing library written in c.
# exiftool,2,library,exiftool is a platform-independent perl library and command-line application for reading writing and editing meta information in a wide variety of files.
# max-msp-jitter,2,environment,max/msp/jitter is an object-oriented graphical multimedia programming environment sometimes referred to simply as max.
# photran,2,tool,photran is an ide and refactoring tool for fortran based on eclipse and the cdt.
# mini-xml,2,library,mini-xml is a small xml library that you can use to read and write xml and xml-like data files in your application without requiring large non-standard libraries.
# fmpp,2,tool,fmpp is a general-purpose text file preprocessor tool that uses freemarker templates.
# javaosc,2,library,javaosc is primarily a library that gives jvm language programs the ability of serializing parsing sending and receiving data in the osc content format.
# esapi,2,library,the enterprise security api (esapi) is a library developed by the open web application security project (owasp).
# zipalign,2,tool,zipalign is an archive alignment tool that provides important optimization to android application (.apk) files.
# sonicmq,2,system,sonicmq is a message queueing system based on jms.
# remedy,2,framework,bmc remedy is an application framework most well known for tracking it assets requests and issues.
# epl,2,language,epl stands for the "eltron programming language" and is a proprietary programming language used to communicate to zebra (formerly eltron) branded printers
# jatha,2,library,jatha is a java library that implements a fairly large subset of common lisp including most of the datatypes (e.g. packages bignums) and their associated methods.
# andar,2,library,andar is an open source library to assist with augmented reality on the android platform.
# text-services-framework,2,toolkit,microsoft text services framework is a toolkit for creating advanced text input and natural language technologies.
# pyccuracy,2,tool,pyccuracy is a behaviour-driven-development-style tool written in python that aims to make it easier to write automated acceptance tests.
# bugsense,2,tool,bugsense is a tool that collects and analyzes crash reports from mobile apps.
# sqlitemanager,2,tool,sqlitemanager is a multilingual web based tool to manage sqlite database.
# android-espresso,2,library,espresso is a library which is used to write android ui tests.
# android-webservice,2,system,web service is a system that enables applications to communicate with an api. web service helps to expose business logic through an api interface where different systems communicate over network.
# jsjac,2,library,jsjac is a jabber/xmpp client library written in javascript to ease implementation of web based jabber/xmpp clients
# netrexx,2,language,netrexx is a general-purpose programming language inspired by two very different programming languages rexx and java™.
# universal-image-loader,2,library,universal image loader is the open source library for android which aims to provide a reusable instrument for asynchronous image loading caching and displaying.
# salat,2,library,salat is a bi-directional scala case class serialization library that leverages mongodb's `dbobject` (which uses bson underneath) as its target format.
# karel,1,language,karel is an introductory programming language in which one controls a simulated robot.
# liquidsoap,1,tool,liquidsoap is a tool for controlling the source end of internet radio and video streams.
# apache-commons-dbutils,1,toolkit,apache commons dbutils is a toolkit that simplifies the usage of the java database connectivity (jdbc) api.
# ckan,1,system,ckan is an open-source data management system (dms) to build data portals focused on open data.
# wicket-1.5,1,framework,apache wicket commonly referred to as wicket is a lightweight component-based web application framework for the java programming language conceptually similar to javaserver faces and tapestry.
# localytics,1,platform,localytics is a marketing and analytics platform for mobile and web apps
# modular-arithmetic,1,tool,modular arithmetic is quite a useful tool in number theory.
# jcolorchooser,1,component,jcolorchooser is a java swing component that enable users to choose a color from a palette of colors.
# axon,1,framework,axon framework is a java based open source framework providing building blocks to support developers with domain-driven design cqrs and event sourcing in their application.
# spring-boot,1,framework,spring boot is a framework that allows to easily create spring-powered production-grade applications and services with the absolute minimum fuss.
# intellij-13,1,ide,intellij idea is a popular ide by jetbrains.
# jdownloader,1,platform,jdownloader is open source platform independent and written completely in java.
# jackcess,1,library,jackcess is a pure java library for reading from and writing to ms access databases
# jgraphx,1,component,jgraphx is an open source java swing component.
# sat4j,1,library,sat4j is a full featured boolean reasoning library designed to bring state-of-the-art sat technologies to the java virtual machine.
# mina,1,framework,apache mina is a network application framework which helps users develop high performance and high scalability network applications easily.
# mxgraph,1,library,mxgraph is an open source client side javascript diagramming library that uses svg and html for rendering.
# java-time,1,framework,the java.time package is a modern date-time framework that debuted in java 8 defined by jsr 310 supplanting the java.util.date and .calendar classes.
# antform,1,tool,antform is a java tool designed to add interaction to ant scripts through graphical forms.
# mgwt,1,extension,mgwt  is an mobile extension to gwt which allows to write mobile apps with gwt
# caliper,1,framework,caliper is google's open-source framework for writing running and viewing the results of java microbenchmarks.
# opalvoip,1,library,opalvoip is cross platform c++ library which is implements the commonly used protocols to send voice video and fax data over ip networks.
# password-generator,1,system,a password generator is a system or program that creates random passwords to be used to secure other systems.
# navit,1,system,navit is a car navigation system with routing engine.
# ejml,1,library,efficient java matrix library is a linear algebra library for manipulating dense matrices
# configatron,1,library,configatron is a ruby library that makes it easy to have persistently accessible configuration data available through your ruby application.
# nifty-gui,1,library,nifty gui is a java library that supports the building of interactive user interfaces.
# xmpphp,1,library,xmpphp is a php library for xmpp (aka jabber).
# hierarchyviewer,1,tool,hierarchy viewer is a tool for android developers to examine their apps' view hierarchies.
# svg-salamander,1,toolkit,svgsalamander is a java-based toolkit for manipulating svg
# iwconfig,1,tool,iwconfig is a tool used to configure wireless network interfaces on linux systems.
# sqlcipher,1,extension,sqlcipher is an open source extension to sqlite that provides transparent 256-bit aes encryption of database files.
# boinc,1,system,berkeley open infrastructure for network computing (boinc) is a middleware system for volunteer and grid computing
# quickbase,1,platform,quick base is a low-code platform that allows non-technical developers to build customize and connect scalable secure cloud applications mapped to unique business challenges without compromising it governance and control.
# echoprint,1,system,echoprint is an open source music identification system that allows anyone to build music fingerprinting into their application.
# habanero,1,framework,habanero is an open-source enterprise application development framework for .net released under the gnu lgpl 3.
# windows-mobile-2003,1,platform,microsoft windows mobile 2003 is a platform for cell phones and pdas based on the windows ce operating system family.
# wtx,1,tool,ibm transformation extender is an ibm tool for b2b integration and data transformations.
# jxls,1,library,jxls is a java library for writing excel files using xls templates and reading data from excel into java objects using xml configuration.
# weceem,1,system,weceem is a open source content management system built with grails.
