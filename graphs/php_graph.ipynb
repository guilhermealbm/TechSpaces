# %%
import pandas as pd
import networkx as nx
import community

import operator

# %%
df = pd.read_csv('../tags_with_wiki_relationship.csv')
df
# Out:
#                source           target  weight
# 0                  c#          decimal    3081
# 1                  c#           double    2895
# 2                  c#   floating-point    1946
# 3                  c#  type-conversion    4426
# 4             decimal           double     790
# ...               ...              ...     ...
# 936601       database       parcelable       3
# 936602     web-config  windows-phone-7       4
# 936603  drag-and-drop              lag      12
# 936604      animation           markup      14
# 936605       assembly    factorization       1
#
# [936606 rows x 3 columns]

# %%
df_wiki = pd.read_csv('../tags_with_wiki_and_category.csv', lineterminator='\n')
df_wiki
# Out:
#                       TagName  \
# 0                        java
# 1                       regex
# 2                         xml
# 3                       mysql
# 4                        nant
# ...                       ...
# 41778            minimal-apis
# 41779                  ix.net
# 41780        amazon-memory-db
# 41781           decomposition
# 41782  dasync.asyncenumerator
#
#                                                     Body      root
# 0      java is a high-level object oriented programmi...  language
# 1      Regular expressions provide a declarative lang...       NaN
# 2      xml (extensible markup language) is a structur...    format
# 3      mysql is a free open source relational databas...    system
# 4      nant is a build tool for .net aiming to suppor...      tool
# ...                                                  ...       ...
# 41778  Minimal APIs were introduced in ASP.NET Core 6...       NaN
# 41779  the interactive extensions (ix) is a .net libr...   library
# 41780  memorydb for redis is an in-memory database se...   service
# 41781  Decomposition might refer to Time Series Decom...       NaN
# 41782  dasync.asyncenumerator is a c# library that pr...   library
#
# [41783 rows x 3 columns]

# %%
node_attr = df_wiki.set_index('TagName').to_dict('index')

# %%
Graphtype = nx.Graph()
G = nx.from_pandas_edgelist(df, edge_attr='weight', create_using=Graphtype)
nx.set_node_attributes(G, node_attr)

# %%
G.nodes['php']
# Out:
# {'Body': 'php is a widely used open source general-purpose multi-paradigm dynamically typed and interpreted scripting language originally designed for server-side web development.',
#  'root': 'multi-paradigm'}

# %%
G['php']
# Out:
# AtlasView({'architecture': {'weight': 1501}, 'hook': {'weight': 1564}, 'plugins': {'weight': 5825}, 'database': {'weight': 66186}, 'flat-file': {'weight': 245}, 'sql': {'weight': 121670}, 'java': {'weight': 18711}, 'oop': {'weight': 28430}, 'theory': {'weight': 116}, 'analytics': {'weight': 584}, 'apache': {'weight': 67195}, 'download': {'weight': 7213}, 'logging': {'weight': 3185}, 'arrays': {'weight': 172946}, 'tag-cloud': {'weight': 52}, 'security': {'weight': 20069}, 'exchange-server': {'weight': 434}, 'mapi': {'weight': 12}, 'webdav': {'weight': 236}, 'windows': {'weight': 8761}, 'encryption': {'weight': 10032}, 'passwords': {'weight': 4173}, 'db2': {'weight': 661}, 'ibm-midrange': {'weight': 241}, 'odbc': {'weight': 2821}, 'pass-by-reference': {'weight': 940}, 'pass-by-value': {'weight': 85}, 'variables': {'weight': 22181}, 'debugging': {'weight': 4653}, 'eclipse': {'weight': 3359}, 'phpstorm': {'weight': 5000}, 'xdebug': {'weight': 5519}, 'xampp': {'weight': 14601}, 'authentication': {'weight': 13876}, 'http-authentication': {'weight': 267}, 'error-handling': {'weight': 7007}, 'parameters': {'weight': 3265}, 'migration': {'weight': 2068}, 'mysql': {'weight': 591048}, 'svn': {'weight': 1591}, 'html-parsing': {'weight': 2805}, 'preg-replace': {'weight': 14064}, 'regex': {'weight': 77714}, 'ternary-operator': {'weight': 818}, 'ftp': {'weight': 5353}, 'ftplib': {'weight': 8}, 'python': {'weight': 12002}, 'webserver': {'weight': 2899}, 'c++': {'weight': 3098}, 'ide': {'weight': 1605}, 'linux': {'weight': 19973}, 'iis': {'weight': 4931}, 'upload': {'weight': 12271}, 'paradigms': {'weight': 23}, 'procedural': {'weight': 132}, 'visual-studio': {'weight': 413}, 'web-services': {'weight': 10866}, 'wsdl': {'weight': 3729}, 'ruby': {'weight': 2275}, 'ruby-on-rails': {'weight': 2008}, 'cvs': {'weight': 29}, 'version-control': {'weight': 658}, 'sql-server': {'weight': 15549}, 'sql-server-2005': {'weight': 370}, 'random': {'weight': 5490}, 'build-process': {'weight': 57}, 'scripting': {'weight': 1341}, 'tortoisesvn': {'weight': 109}, 'syntax': {'weight': 4848}, 'register-globals': {'weight': 86}, 'javascript': {'weight': 313339}, 'pdf': {'weight': 13607}, 'web-applications': {'weight': 3229}, 'unix': {'weight': 2055}, 'orm': {'weight': 7026}, 'perl': {'weight': 2392}, 'date': {'weight': 25630}, 'strtotime': {'weight': 3157}, 'http': {'weight': 11758}, 'pear': {'weight': 4039}, 'phppgadmin': {'weight': 85}, 'postgresql': {'weight': 9878}, 'continuous-integration': {'weight': 699}, 'openbsd': {'weight': 29}, 'xinc': {'weight': 25}, 'phpunit': {'weight': 14285}, 'unit-testing': {'weight': 6607}, 'lamp': {'weight': 2637}, 'portability': {'weight': 68}, 'iis-7': {'weight': 1235}, 'curl': {'weight': 54119}, 'performance': {'weight': 10653}, 'mysqli': {'weight': 60223}, 'gd': {'weight': 7165}, 'image': {'weight': 27228}, 'jpeg': {'weight': 1363}, 'encoding': {'weight': 7351}, 'jsp': {'weight': 766}, 'tomcat': {'weight': 530}, 'email': {'weight': 42891}, 'caching': {'weight': 10218}, 'zend-optimizer': {'weight': 100}, 'coding-style': {'weight': 1507}, 'benchmarking': {'weight': 471}, 'codeigniter': {'weight': 125548}, 'pdo': {'weight': 53898}, 'optimization': {'weight': 3800}, 'c#': {'weight': 8040}, 'model-view-controller': {'weight': 9690}, 'zend-framework': {'weight': 34677}, 'algorithm': {'weight': 5629}, 'combinations': {'weight': 672}, 'np-complete': {'weight': 3}, 'puzzle': {'weight': 50}, 'ajax': {'weight': 160050}, 'extends': {'weight': 624}, 'interface': {'weight': 1389}, '.net': {'weight': 2401}, 'asp.net': {'weight': 4381}, 'session': {'weight': 49374}, 'permissions': {'weight': 4121}, 'cgi': {'weight': 1181}, 'cookies': {'weight': 18130}, 'queue': {'weight': 1575}, 'visualsvn-server': {'weight': 30}, 'websvn': {'weight': 62}, 'xml': {'weight': 45918}, 'datetime': {'weight': 17907}, 'timezone': {'weight': 4269}, 'html': {'weight': 294593}, 'dataset': {'weight': 153}, 'testing': {'weight': 3300}, 'goto': {'weight': 110}, 'language- ...

# %%
# Find modularity
part_1 = community.best_partition(G, random_state = 27)
mod_1 = community.modularity(part_1,G)

# %%
part_1['php']
# Out:
# 3

# %%
number_of_comm_1 = max(part_1.items(), key=operator.itemgetter(1))[1] + 1
number_of_comm_1
# Out:
# 20

# %%
list_of_comm_1 = []
for i in range(number_of_comm_1):
    list_of_comm_1.append([k for k,v in part_1.items() if v == i])
    
list_of_comm_1[part_1['php']]
# Out:
# ['datetime',
#  'datediff',
#  'time',
#  'timezone',
#  'timezone-offset',
#  'data-storage',
#  'database',
#  'mysql',
#  'triggers',
#  'mainframe',
#  'zos',
#  'rdbms',
#  'sql',
#  'sql-server',
#  'php',
#  'plugins',
#  'file-type',
#  'mime',
#  'flat-file',
#  'bcp',
#  'sql-server-2005',
#  'analytics',
#  'apache',
#  'download',
#  'virtualhost',
#  'internationalization',
#  'oracle',
#  'security',
#  'email',
#  'email-spam',
#  'lucene',
#  'search',
#  'http',
#  'article',
#  'authentication',
#  'webdav',
#  'encryption',
#  'passwords',
#  'db2',
#  'ibm-midrange',
#  'odbc',
#  'views',
#  'format',
#  'date',
#  'bpgsql',
#  'postgresql',
#  'left-join',
#  'phpstorm',
#  'xdebug',
#  'connection',
#  'escaping',
#  'full-text-search',
#  'indexing',
#  'database-indexes',
#  'account',
#  'dns',
#  'subdomain',
#  'database-performance',
#  'sql-injection',
#  'xss',
#  'xampp',
#  'http-authentication',
#  'permissions',
#  'url',
#  'sql-server-2008',
#  'profile',
#  'preg-replace',
#  'quotes',
#  'coldfusion',
#  'url-rewriting',
#  'ftp',
#  'webserver',
#  'sql-server-2000',
#  'database-design',
#  'tsql',
#  'group-by',
#  'verification',
#  'date-conversion',
#  'curl',
#  'nslookup',
#  'captcha',
#  'cron',
#  '.htaccess',
#  'mod-rewrite',
#  'caching',
#  'foreach',
#  'sql-update',
#  'https',
#  'ssl',
#  'http-referer',
#  'backup',
#  'upload',
#  'privileges',
#  'blob',
#  'replication',
#  'audit',
#  'session',
#  'union',
#  'multilingual',
#  'content-management-system',
#  'hosting',
#  'dynamic-sql',
#  'proxy',
#  'etag',
#  'header',
#  'olap',
#  'delicious-api',
#  'case',
#  'reverse-dns',
#  'zend-studio',
#  'cfml',
#  'ddl',
#  'schema',
#  'joomla',
#  'apache2',
#  'firebird',
#  'interbase',
#  'comments',
#  'informix',
#  'spl',
#  'wiki',
#  'request',
#  'dnsmasq',
#  'yahoo-api',
#  'uuid',
#  'foreign-keys',
#  'sap-ase',
#  'gmail',
#  'icalendar',
#  'ini',
#  'register-globals',
#  'scalability',
#  'pop3',
#  'private-key',
#  'public-key',
#  'authorization',
#  'rest-security',
#  'maintenance-plan',
#  'duplicates',
#  'unique',
#  'redirect',
#  'oracle9i',
#  'insert',
#  'entourage',
#  'redundancy',
#  'reporting-services',
#  'reportingservices-2005',
#  'procmail',
#  'strtotime',
#  'pear',
#  'stored-procedures',
#  'seo',
#  'phppgadmin',
#  'memcached',
#  'metadata',
#  'varchar',
#  'select',
#  'cookies',
#  'sql-server-2005-express',
#  'xinc',
#  'oracle-xe',
#  'api',
#  'pagination',
#  'phpunit',
#  'tns',
#  'tnsnames',
#  'db2-luw',
#  'lamp',
#  'cursors',
#  'fillfactor',
#  'user-defined-functions',
#  'wiki-engine',
#  'file-upload',
#  'openid',
#  'post',
#  'datepart',
#  'ssas',
#  'share',
#  'calendar',
#  'acl',
#  'mysqli',
#  'gd',
#  'denormalization',
#  'zend-optimizer',
#  'rewrite',
#  'codeigniter',
#  'bootstrapping',
#  'upsert',
#  'pdo',
#  'zend-framework',
#  'themes',
#  'wordpress',
#  'picasa',
#  'erd',
#  'ssrs-2008',
#  'sybase',
#  'oracle-pro-c',
#  'shtml',
#  'sql-server-express',
#  'procedure',
#  'utc',
#  'data-driven',
#  'google-analytics',
#  'google-analytics-api',
#  'mediawiki',
#  'solr',
#  'cname',
#  'web-hosting',
#  'restore',
#  'locale',
#  'case-insensitive',
#  'rfc3339',
#  'blogs',
#  'certificate-authority',
#  'openssl',
#  'imap',
#  'toad',
#  'email-client',
#  'business-intelligence',
#  'content-management',
#  'file-permissions',
#  'referential-integrity',
#  'plsql',
#  'innodb',
#  'myisam',
#  'ordinals',
#  'antivirus',
#  '3des',
#  'e-commerce',
#  'database-table',
#  'ssis',
#  'timestamp',
#  'many-to-many',
#  'data-modeling',
#  'tagging',
#  'recovery',
#  'backupexec',
#  'administration',
#  'entity-relationship',
#  'hostmonster',
#  'shared-hosting',
#  'usergroups',
#  'gist-index',
#  'httpserver',
#  'etl',
#  'doctrine',
#  'propel',
#  'ssms',
#  'mork',
#  'thunderbird',
#  'crypt',
#  'md5',
#  'geography',
#  'spell-checking',
#  'audit-trail',
#  'crud',
#  'autoload',
#  'cursor',
#  'code-injection',
#  'iptc',
#  'pivot',
#  'wikipedia',
#  'simpletest',
#  'mdx',
#  'symfony1',
#  'friendly-url',
#  'slug',
#  'freetext',
#  'railo',
#  'database-agnostic',
#  'remote-server',
#  'associative-array',
#  'dts',
#  'harvest',
#  'forward-engineer',
#  'reserved-words',
#  'nocount',
#  'query-string',
#  'google-search',
#  'partitioning',
#  'review',
#  'mamp',
#  'translation',
#  'table-variable',
#  'temp-tables',
#  'doi',
#  'httponly',
#  'mysql-error-1111',
#  'database-connection',
#  'filemaker',
#  'opcode-cache',
#  'database-administration',
#  'tracking',
#  'smtp',
#  'html-entities',
#  'sqldatatypes',
#  'activation',
#  'mysql-error-1062',
#  'content-type',
#  'protection',
#  'nolock',
#  'watermark',
#  'constraints',
#  'onlinebanking',
#  'notnull',
#  'smo',
#  'truncate',
#  'sha1',
#  'natural-sort',
#  'mysql-error-1005',
#  'mysql-workbench',
#  'cryptography',
#  'jrun',
#  'sanitization',
#  'common-table-expression',
#  'nvarchar',
#  'drupal',
#  'drupal-theming',
#  'mysql-management',
#  'geshi',
#  'special-characters',
#  'virus',
#  'postgis',
#  'year2038',
#  'phing',
#  'count',
#  'advanced-queuing',
#  'eaccelerator',
#  'psql',
#  'lucene.net',
#  'join',
#  'duration',
#  'sugarcrm',
#  'cakephp',
#  'maintenance',
#  'dblink',
#  'gtd',
#  'session-variables',
#  'ora-00932',
#  'inner-join',
#  'outer-join',
#  'field',
#  'hierarchy',
#  'wamp',
#  'ssi',
#  'facebook',
#  'mediawiki-extensions',
#  'sql-insert',
#  'privacy',
#  'where',
#  'gnupg',
#  'normalization',
#  '.htpasswd',
#  'oltp',
#  'reportbuilder',
#  'grouping',
#  'ticket-system',
#  'linkedin',
#  'social-media',
#  'login',
#  'smarty',
#  'phpbb',
#  'bulkinsert',
#  'fuzzy-search',
#  'soundex',
#  'msde',
#  'embeddedwebserver',
#  'http-headers',
#  'coalesce',
#  'cubes',
#  'reverse-proxy',
#  'googlebot',
#  'robots.txt',
#  'string-aggregation',
#  'sendmail',
#  'smarthost',
#  'apache2.4',
#  'filezilla',
#  'alter-table',
#  'load-data-infile',
#  'moodle',
#  'data-integrity',
#  'scoring',
#  'sequences',
#  'load-balancing',
#  'rfc2445',
#  'rfc5545',
#  'mysql-error-1093',
#  'sql-delete',
#  'subquery',
#  'http-status-code-403',
#  'author',
#  'quickbooks',
#  'data-quality',
#  'updating',
#  'email-validation',
#  'ora-00942',
#  'openbd',
#  'http-get',
#  'http-post',
#  'mail-server',
#  'er-diagrams',
#  'cobol',
#  'sql-like',
#  'sqlcompare',
#  'blowfish',
#  'des',
#  'rsa',
#  'database-normalization',
#  'html-compression',
#  'social-networking',
#  'aggregation',
#  'sqldmo',
#  'cryptoapi',
#  'bouncycastle',
#  'wildcard-subdomain',
#  'ingres',
#  'union-all',
#  'whois',
#  'apc',
#  'drupal-5',
#  'average',
#  'isapi-rewrite',
#  'aggregate',
#  'pci-dss',
#  'sequence',
#  'currency',
#  'mime-types',
#  'knowledge-management',
#  'xml-rpc',
#  'isolation-level',
#  'paypal',
#  'recursive-query',
#  'zend-server',
#  'domain-name',
#  'payment',
#  'distinct',
#  'search-engine',
#  'error-suppression',
#  'vistadb',
#  'fastcgi',
#  'sqlplus',
#  'aes',
#  'schedule',
#  'acid',
#  'roles',
#  'popularity',
#  'cross-join',
#  'transaction-log',
#  'anti-join',
#  'x509',
#  'forwarding',
#  'data-retrieval',
#  'sqlclr',
#  'pagerank',
#  'cfc',
#  'corrupt',
#  'vps',
#  'capacity-planning',
#  'mysql-error-1451',
#  'customization',
#  'deterministic',
#  'sam',
#  'object-oriented-database',
#  'aspell',
#  'sum',
#  'accounting',
#  'data-migration',
#  'lighttpd',
#  'laconica',
#  'cognos',
#  'primary-key',
#  'cakephp-1.2',
#  'php-5.3',
#  'php-5.4',
#  'php4',
#  'yahoo',
#  'query-optimization',
#  'cube',
#  'cfquery',
#  'cfqueryparam',
#  'zend-pdf',
#  'postfix-mta',
#  'akamai',
#  'front-controller',
#  'credit-card',
#  'sign',
#  'hostname',
#  'mysql-error-2006',
#  'sql-server-agent',
#  'oracle10g',
#  'rman',
#  'file-exists',
#  'firephp',
#  'chunked-encoding',
#  'database-schema',
#  'zend-debugger',
#  'shopping-cart',
#  'oracle-sqldeveloper',
#  'soft-delete',
#  'maildir',
#  'linked-server',
#  'iso',
#  'ocsp',
#  'essbase',
#  'hyperion',
#  'siebel',
#  'contains',
#  'digg',
#  'dataflow',
#  'ora-00933',
#  'asn.1',
#  'mod-alias',
#  'multiple-columns',
#  'gateway',
#  'dual-table',
#  'response',
#  'backend',
#  'sql-convert',
#  'gettime',
#  'punbb',
#  'google-custom-search',
#  'sql-order-by',
#  'mod-deflate',
#  'record',
#  'gdata-api',
#  'google-calendar-api',
#  'adodb-php',
#  'penetration-testing',
#  'diffie-hellman',
#  'exim',
#  'edit',
#  'user-accounts',
#  'cck',
#  'drupal-views',
#  'phpundercontrol',
#  'mod-php',
#  'two-connection-limit',
#  'ini-set',
#  'php-gtk',
#  'certificate',
#  'joomla-article',
#  'oracle11g',
#  'sql-execution-plan',
#  'localhost',
#  'localtime',
#  'x-sendfile',
#  'btrieve',
#  'spam-prevention',
#  'mdb2',
#  'hosts',
#  'case-sensitive',
#  'spool',
#  'wordpress.com',
#  'ftps',
#  'pg-dump',
#  'ora-06512',
#  'permission-denied',
#  'attachment',
#  'odp.net',
#  'database-partitioning',
#  'mysqldump',
#  'authsub',
#  'google-api',
#  'google-authentication',
#  'adhoc-queries',
#  'php-5.2',
#  'get',
#  'exists',
#  'auto-increment',
#  'opensocial',
#  'permalinks',
#  'sql-loader',
#  'wordpress-theming',
#  'unpivot',
#  'jce',
#  'identity-column',
#  'microblogging',
#  'coldfusion-8',
#  'drupal-6',
#  'imagemagick',
#  'nginx',
#  'mysql-error-1071',
#  'pgp',
#  'sqlxml',
#  'compound-key',
#  'easyphp',
#  'xmp',
#  'clustered-index',
#  'non-clustered-index',
#  'fcgid',
#  'advantage-database-server',
#  'social',
#  'spamassassin',
#  'materialized-views',
#  'relational-database',
#  'prado',
#  'subdirectory',
#  'status',
#  'oauth',
#  'intersystems',
#  'intersystems-cache',
#  'squid',
#  'progress-4gl',
#  'progress-db',
#  'records',
#  'ssrs-2008-r2',
#  'uniqueidentifier',
#  'forums',
#  'mashup',
#  'nss',
#  'oracle-call-interface',
#  'phpdoc',
#  'database-project',
#  'peoplesoft',
#  'database-cursor',
#  'natural-join',
#  'mcafee',
#  'authorize.net',
#  'silent-post',
#  'dateadd',
#  'sqlanywhere',
#  'rdl',
#  'sharing',
#  'collation',
#  'mod-proxy',
#  'dynamic-url',
#  'access-control',
#  'phpmyadmin',
#  'no-cache',
#  'put',
#  'sas',
#  'admin',
#  'weather',
#  'denial-of-service',
#  'spf',
#  'http-status-code-404',
#  'ajp',
#  'piracy',
#  'data-warehouse',
#  'dimensional-modeling',
#  'star-schema',
#  'relational-algebra',
#  'ftp-client',
#  'clob',
#  'google-ads-api',
#  'urlencode',
#  'mvcc',
#  'sqlcmd',
#  'database-relations',
#  'oracleforms',
#  'rights',
#  'datetime-format',
#  'iso8601',
#  '2-digit-year',
#  'powerbuilder',
#  'calculated-columns',
#  'connect-by',
#  'httprequest',
#  'twiki',
#  'encryption-asymmetric',
#  'encryption-symmetric',
#  'sql-server-profiler',
#  'mysql5',
#  'row-number',
#  'mod-ssl',
#  'simplexml',
#  'pki',
#  'disaster-recovery',
#  'db2-400',
#  'rpgle',
#  'ntext',
#  'qmail',
#  'squirrel-sql',
#  'entity-attribute-value',
#  'cognos-8',
#  'lookup-tables',
#  'greatest-n-per-group',
#  'pecl',
#  'password-protection',
#  'oracleclient',
#  'crontab',
#  'httpresponse',
#  'oci8',
#  'pervasive',
#  'fedex',
#  'wampserver',
#  'mod-jk',
#  'url-parsing',
#  'max',
#  'mantis',
#  'spyware',
#  'filemtime',
#  'digital-certificate',
#  'salt',
#  'data-scrubbing',
#  'ntpd',
#  'bulk',
#  'shell-exec',
#  'dsn',
#  'notin',
#  'url-redirection',
#  'leap-second',
#  'cardinality',
#  'dst',
#  'ssl-certificate',
#  'whitelist',
#  'ddos',
#  'dig',
#  'mysql.sock',
#  'sql-server-2012',
#  'sql-server-2016',
#  'observers',
#  'rolap',
#  'quote',
#  'gcal',
#  'frontpage',
#  'sql-job',
#  'phpmyid',
#  'cdc',
#  'virtual-hosts',
#  'csrf',
#  'date-range',
#  'bids',
#  'var-dump',
#  'country-codes',
#  'iso-3166',
#  'multiple-domains',
#  'electronic-signature',
#  'postdata',
#  'information-schema',
#  'windows-live',
#  'proxypass',
#  'comp-3',
#  'double-quotes',
#  'str-replace',
#  'cj',
#  'commission-junction',
#  'date-format',
#  'paginator',
#  'control-language',
#  'mysql-error-1044',
#  'datawindow',
#  'netcobol',
#  'email-bounces',
#  'duplicate-removal',
#  'pentaho',
#  'fqdn',
#  'google-data-api',
#  'sasl',
#  'change-password',
#  'uptime',
#  'directory-listing',
#  'mysql-error-1054',
#  'rfc',
#  'unixodbc',
#  'percent-encoding',
#  'urldecode',
#  'database-migration',
#  'mx-record',
#  'fips',
#  'verity',
#  'database-versioning',
#  'sql-limit',
#  'window-functions',
#  'mysqlimport',
#  'symfony',
#  'eml',
#  '3270',
#  'resume-download',
#  'derived-table',
#  'awstats',
#  'strtr',
#  'reportmanager',
#  'plpgsql',
#  'anchor-modeling',
#  'bbcode',
#  'forum',
#  'error-log',
#  'qbxml',
#  'rownum',
#  'cffile',
#  'self-join',
#  'mysql-error-1025',
#  'image-uploading',
#  'breadcrumbs',
#  'cache-control',
#  'sendgrid',
#  'webmail',
#  'ora-12154',
#  'ora-12541',
#  'plaintext',
#  'http-status-code-503',
#  'in-clause',
#  'fraud-prevention',
#  'redgate',
#  'cumulative-sum',
#  'between',
#  'aggregate-functions',
#  'payment-gateway',
#  'invoice',
#  'service-broker',
#  'time-travel',
#  'isnull',
#  'hierarchical-data',
#  'endeca',
#  'row-level-security',
#  'simplepie',
#  'rfc822',
#  'strftime',
#  'mysql-real-escape-string',
#  'phpbb3',
#  'rsacryptoserviceprovider',
#  'token',
#  'prepared-statement',
#  'smart-quotes',
#  'rfc3986',
#  'urn',
#  'ranking',
#  'relevance',
#  'utm',
#  'self-updating',
#  'sqltransaction',
#  'mod-security',
#  'openedge',
#  'signature',
#  'ora-01438',
#  'csr',
#  'virtual-server',
#  'safe-browsing',
#  'theming',
#  'punycode',
#  'die',
#  'upsizing',
#  'dokuwiki',
#  'concat',
#  'require-once',
#  'getdate',
#  'system-stored-procedures',
#  'challenge-response',
#  'html-sanitizing',
#  'http-status-code-302',
#  'product',
#  'sqlbulkcopy',
#  'database-cluster',
#  'rbac',
#  'ora-01555',
#  'min',
#  'directory-traversal',
#  'vbulletin',
#  'registration',
#  'capicom',
#  'user-forums',
#  'wimp',
#  'vin',
#  'group-concat',
#  'newsletter',
#  'userid',
#  'zimbra',
#  'self-signed',
#  'photos',
#  'datetimeoffset',
#  'execute',
#  'kohana',
#  'phplist',
#  'intuit',
#  'keep-alive',
#  'realpath',
#  'foreign-key-relationship',
#  'distributed-database',
#  'grant',
#  'tde',
#  'having',
#  'having-clause',
#  'limit',
#  'php-shorttags',
#  'sp-send-dbmail',
#  'recover',
#  'nested-sets',
#  'dpapi',
#  'chmod',
#  'datamodel',
#  'cpanel',
#  'whm',
#  'vcalendar',
#  'mod-fcgid',
#  'ora-00923',
#  'oracle-text',
#  'non-relational-database',
#  'mcrypt',
#  'clean-url',
#  'certificate-revocation',
#  'nutch',
#  'check-constraints',
#  'ora-12519',
#  'phalanger',
#  'mysql-error-1349',
#  'multiple-tables',
#  'pgadmin',
#  'cmdb',
#  'translate',
#  'change-data-capture',
#  'jobs',
#  'cfform',
#  'cfinput',
#  'freetexttable',
#  'passive-mode',
#  'pdostatement',
#  'contact-form-7',
#  'http-status-codes',
#  'thunderbird-lightning',
#  'document-management',
#  'faceted-search',
#  'ssrs-grouping',
#  'rdbms-agnostic',
#  'mdf',
#  'gettext',
#  'composite-primary-key',
#  'sql-server-migration-assi',
#  'slashdot',
#  'pastebin',
#  'substr',
#  'explode',
#  'rows',
#  'magic-quotes',
#  'modx',
#  'unix-timestamp',
#  'blacklist',
#  'lru',
#  'sql-scripts',
#  'output-buffering',
#  'integrity',
#  'httpd.conf',
#  'composite-key',
#  'sample-data',
#  'haproxy',
#  'http-options-method',
#  'crosstab',
#  'metaphone',
#  'identity-insert',
#  'bcmath',
#  'fatal-error',
#  'recaptcha',
#  'nusoap',
#  'into-outfile',
#  'mozy',
#  'procobol',
#  'basic-authentication',
#  'sessionid',
#  'echo',
#  'sys-refcursor',
#  'flooding',
#  'temporal-database',
#  'digest',
#  'sha',
#  'sha256',
#  'php-socket',
#  'open-basedir',
#  'multi-user',
#  'apache-config',
#  'insert-update',
#  'create-table',
#  'ora-12514',
#  'correlated-subquery',
#  'client-certificates',
#  'movabletype',
#  'preset',
#  'omittag',
#  'spam',
#  'apostrophe',
#  'database-sequence',
#  'bacula',
#  'remember-me',
#  'scribd',
#  'abuse',
#  'mysql-error-1045',
#  'gravatar',
#  'securid',
#  'http-1.1',
#  'synonym',
#  'truncation',
#  'time-format',
#  'php-internals',
#  'mysql-connect',
#  'mysql-pconnect',
#  'ora-00907',
#  'do-loops',
#  'epoch',
#  'bbpress',
#  'silverstripe',
#  'ora-00936',
#  'data-dictionary',
#  'checkout',
#  'magento',
#  'oracle-ucm',
#  'strptime',
#  'pkix',
#  'open-flash-chart',
#  'date-arithmetic',
#  'scgi',
#  ...]

# %%
G_1 = G.subgraph(list_of_comm_1[part_1['php']])

# %%
G_1.edges
# Out:
# EdgeView([('x-cart', 'php'), ('x-cart', 'apache'), ('x-cart', 'security'), ('x-cart', 'payment'), ('x-cart', 'ssl'), ('x-cart', 'file-upload'), ('x-cart', 'ini'), ('x-cart', 'smarty'), ('x-cart', 'session'), ('x-cart', 'facebook'), ('gaps-and-islands', 'sql'), ('gaps-and-islands', 'common-table-expression'), ('gaps-and-islands', 'sql-server'), ('gaps-and-islands', 'tsql'), ('gaps-and-islands', 'date'), ('gaps-and-islands', 'mysql'), ('gaps-and-islands', 'sql-server-2005'), ('gaps-and-islands', 'grouping'), ('gaps-and-islands', 'sql-server-2000'), ('gaps-and-islands', 'sql-server-2008'), ('gaps-and-islands', 'group-by'), ('gaps-and-islands', 'date-arithmetic'), ('gaps-and-islands', 'recursive-query'), ('gaps-and-islands', 'intersect'), ('gaps-and-islands', 'stored-procedures'), ('gaps-and-islands', 'oracle'), ('gaps-and-islands', 'subquery'), ('gaps-and-islands', 'date-range'), ('gaps-and-islands', 'postgresql'), ('gaps-and-islands', 'sql-delete'), ('gaps-and-islands', 'php'), ('gaps-and-islands', 'datetime'), ('gaps-and-islands', 'intervals'), ('gaps-and-islands', 'select'), ('gaps-and-islands', 'database'), ('photos', 'metadata'), ('photos', 'facebook'), ('photos', 'tagging'), ('photos', 'passwords'), ('photos', 'postgresql'), ('photos', 'database'), ('photos', 'schema'), ('photos', 'email'), ('photos', 'php'), ('photos', 'file-upload'), ('photos', 'wordpress'), ('photos', 'database-design'), ('photos', 'mysql'), ('photos', 'sharing'), ('photos', 'upload'), ('photos', 'imagemagick'), ('photos', 'gravatar'), ('photos', 'zend-framework'), ('photos', 'search'), ('photos', 'api'), ('photos', 'cakephp'), ('photos', 'facebook-graph-api'), ('photos', 'social-networking'), ('photos', 'facebook-fql'), ('photos', 'cursor'), ('photos', 'hosting'), ('photos', 'count'), ('photos', 'facebook-like'), ('photos', 'facebook-javascript-sdk'), ('photos', 'access-token'), ('photos', 'fbml'), ('photos', 'xfbml'), ('eaccelerator', 'caching'), ('eaccelerator', 'memcached'), ('eaccelerator', 'apc'), ('eaccelerator', 'opcode-cache'), ('eaccelerator', 'php'), ('eaccelerator', 'xcache'), ('eaccelerator', 'apache'), ('eaccelerator', 'wamp'), ('eaccelerator', 'mysql'), ('eaccelerator', 'fastcgi'), ('eaccelerator', 'joomla'), ('eaccelerator', 'zend-optimizer'), ('eaccelerator', 'hosting'), ('eaccelerator', 'comments'), ('preg-match-all', 'php'), ('preg-match-all', 'foreach'), ('preg-match-all', 'smarty'), ('preg-match-all', 'double-quotes'), ('preg-match-all', 'preg-match'), ('preg-match-all', 'preg-replace'), ('preg-match-all', 'phpbb'), ('preg-match-all', 'preg-replace-callback'), ('preg-match-all', 'str-replace'), ('preg-match-all', 'caching'), ('preg-match-all', 'file-get-contents'), ('preg-match-all', 'format'), ('preg-match-all', 'limit'), ('preg-match-all', 'email'), ('preg-match-all', 'url'), ('preg-match-all', 'fgetcsv'), ('preg-match-all', 'sql'), ('preg-match-all', 'strpos'), ('preg-match-all', 'codeigniter'), ('preg-match-all', 'wordpress'), ('preg-match-all', 'array-unique'), ('preg-match-all', 'strip-tags'), ('preg-match-all', 'curl'), ('preg-match-all', 'count'), ('social-media', 'linkedin'), ('social-media', 'ranking'), ('social-media', 'facebook'), ('social-media', 'php'), ('social-media', 'social-networking'), ('social-media', 'facebook-like'), ('social-media', 'expressionengine'), ('social-media', 'facebook-graph-api'), ('social-media', 'email'), ('social-media', 'wordpress'), ('social-media', 'sharing'), ('apache', 'analytics'), ('apache', 'download'), ('apache', 'php'), ('apache', 'virtualhost'), ('apache', 'xampp'), ('apache', 'authentication'), ('apache', 'http-authentication'), ('apache', 'mysql'), ('apache', '.htaccess'), ('apache', 'mod-rewrite'), ('apache', 'http-referer'), ('apache', 'security'), ('apache', 'apache2'), ('apache', 'webserver'), ('apache', 'https'), ('apache', 'redirect'), ('apache', 'ssl'), ('apache', 'seo'), ('apache', 'upload'), ('apache', 'httpserver'), ('apache', 'crypt'), ('apache', 'md5'), ('apache', 'hosti ...

# %%
part_2 = community.best_partition(G_1)
mod_2 = community.modularity(part_2,G_1)

# %%
sorted(G_1.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('php', 1806),
#  ('mysql', 1191),
#  ('sql', 1138),
#  ('database', 922),
#  ('sql-server', 822),
#  ('oracle', 664),
#  ('security', 631),
#  ('apache', 542),
#  ('postgresql', 518),
#  ('sql-server-2008', 513),
#  ('api', 506),
#  ('sql-server-2005', 493),
#  ('zend-framework', 490),
#  ('wordpress', 482),
#  ('drupal', 469),
#  ('codeigniter', 437),
#  ('tsql', 437),
#  ('email', 434),
#  ('cakephp', 423),
#  ('database-design', 412),
#  ('http', 407),
#  ('authentication', 404),
#  ('url', 374),
#  ('facebook', 368),
#  ('stored-procedures', 368),
#  ('search', 351),
#  ('indexing', 350),
#  ('session', 349),
#  ('caching', 332),
#  ('.htaccess', 318),
#  ('coldfusion', 316),
#  ('ssl', 313),
#  ('date', 310),
#  ('redirect', 307),
#  ('encryption', 307),
#  ('magento', 305),
#  ('select', 297),
#  ('datetime', 296),
#  ('join', 292),
#  ('curl', 282),
#  ('login', 278),
#  ('post', 272),
#  ('symfony1', 271),
#  ('dns', 269),
#  ('plugins', 266),
#  ('oracle10g', 265),
#  ('permissions', 263),
#  ('plsql', 261),
#  ('mod-rewrite', 258),
#  ('joomla', 254),
#  ('insert', 249),
#  ('cookies', 248),
#  ('content-management-system', 242),
#  ('https', 239),
#  ('apache2', 239),
#  ('triggers', 232),
#  ('time', 229),
#  ('file-upload', 227),
#  ('sql-server-2000', 224),
#  ('drupal-6', 217),
#  ('passwords', 216),
#  ('oauth', 214),
#  ('db2', 209),
#  ('phpmyadmin', 204),
#  ('schema', 202),
#  ('upload', 201),
#  ('internationalization', 201),
#  ('header', 199),
#  ('download', 199),
#  ('proxy', 198),
#  ('doctrine', 194),
#  ('count', 193),
#  ('http-headers', 190),
#  ('nginx', 189),
#  ('odbc', 188),
#  ('ftp', 188),
#  ('foreign-keys', 186),
#  ('oracle11g', 185),
#  ('url-rewriting', 182),
#  ('full-text-search', 179),
#  ('seo', 179),
#  ('timestamp', 177),
#  ('views', 177),
#  ('get', 177),
#  ('ssis', 175),
#  ('cryptography', 171),
#  ('hosting', 170),
#  ('e-commerce', 167),
#  ('subquery', 167),
#  ('reporting-services', 167),
#  ('solr', 167),
#  ('field', 165),
#  ('webserver', 165),
#  ('comments', 164),
#  ('group-by', 164),
#  ('kohana', 163),
#  ('sql-update', 163),
#  ('request', 160),
#  ('pdo', 160),
#  ('sql-order-by', 159),
#  ('subdomain', 156),
#  ('gmail', 154),
#  ('cron', 154),
#  ('limit', 154),
#  ('connection', 154),
#  ('facebook-graph-api', 154),
#  ('relational-database', 153),
#  ('lucene', 153),
#  ('openid', 153),
#  ('query-optimization', 151),
#  ('escaping', 151),
#  ('primary-key', 151),
#  ('xampp', 150),
#  ('backup', 149),
#  ('smtp', 149),
#  ('database-connection', 148),
#  ('google-analytics', 147),
#  ('wamp', 147),
#  ('openssl', 145),
#  ('innodb', 144),
#  ('pagination', 144),
#  ('sql-server-2008-r2', 144),
#  ('drupal-7', 144),
#  ('paypal', 142),
#  ('duplicates', 140),
#  ('yii', 140),
#  ('authorization', 139),
#  ('format', 137),
#  ('localhost', 135),
#  ('constraints', 135),
#  ('metadata', 135),
#  ('calendar', 134),
#  ('cakephp-1.3', 134),
#  ('replication', 134),
#  ('admin', 132),
#  ('http-status-code-404', 132),
#  ('symfony', 129),
#  ('rdbms', 127),
#  ('unique', 126),
#  ('timezone', 125),
#  ('registration', 124),
#  ('many-to-many', 124),
#  ('md5', 122),
#  ('auto-increment', 121),
#  ('blogs', 120),
#  ('foreach', 120),
#  ('sybase', 120),
#  ('mysqli', 120),
#  ('pear', 119),
#  ('scalability', 119),
#  ('memcached', 118),
#  ('certificate', 118),
#  ('symfony-1.4', 116),
#  ('social-networking', 114),
#  ('blob', 114),
#  ('phpunit', 112),
#  ('left-join', 112),
#  ('special-characters', 112),
#  ('lamp', 112),
#  ('search-engine', 111),
#  ('mamp', 111),
#  ('normalization', 110),
#  ('cursor', 110),
#  ('token', 109),
#  ('multilingual', 109),
#  ('doctrine-orm', 109),
#  ('max', 107),
#  ('smarty', 107),
#  ('firebird', 107),
#  ('mediawiki', 106),
#  ('analytics', 105),
#  ('data-modeling', 105),
#  ('sql-injection', 104),
#  ('union', 103),
#  ('translation', 103),
#  ('query-string', 103),
#  ('sql-delete', 103),
#  ('ssl-certificate', 102),
#  ('grouping', 101),
#  ('ssms', 101),
#  ('shared-hosting', 101),
#  ('httprequest', 100),
#  ('data-warehouse', 100),
#  ('user-defined-functions', 100),
#  ('informix', 100),
#  ('cpanel', 99),
#  ('http-post', 99),
#  ('aggregate', 99),
#  ('oracle9i', 98),
#  ('rewrite', 98),
#  ('themes', 97),
#  ('aggregate-functions', 97),
#  ('google-api', 96),
#  ('sql-like', 96),
#  ('pivot', 95),
#  ('drupal-modules', 95),
#  ('facebook-like', 94),
#  ('web-hosting', 94),
#  ('case', 94),
#  ('inner-join', 94),
#  ('categories', 93),
#  ('database-schema', 93),
#  ('row', 92),
#  ('distinct', 92),
#  ('where-clause', 90),
#  ('where', 90),
#  ('kohana-3', 90),
#  ('load-balancing', 90),
#  ('imap', 90),
#  ('password-protection', 89),
#  ('hierarchy', 89),
#  ('content-type', 89),
#  ('wiki', 89),
#  ('forum', 89),
#  ('sum', 89),
#  ('response', 89),
#  ('temp-tables', 89),
#  ('echo', 88),
#  ('customization', 88),
#  ('attachment', 88),
#  ('sql-server-express', 88),
#  ('xss', 88),
#  ('rsa', 88),
#  ('joomla1.5', 88),
#  ('fastcgi', 87),
#  ('php-5.3', 87),
#  ('ssrs-2008', 87),
#  ('tracking', 86),
#  ('entity-relationship', 86),
#  ('prepared-statement', 85),
#  ('ssas', 84),
#  ('mysqldump', 84),
#  ('zend-db', 83),
#  ('digital-signature', 82),
#  ('captcha', 82),
#  ('session-variables', 81),
#  ('sequence', 81),
#  ('cck', 81),
#  ('foreign-key-relationship', 80),
#  ('shopping-cart', 80),
#  ('myisam', 80),
#  ('currency', 80),
#  ('dynamic-sql', 80),
#  ('locale', 80),
#  ('acl', 80),
#  ('profile', 79),
#  ('mime-types', 79),
#  ('sha1', 79),
#  ('lighttpd', 78),
#  ('virtualhost', 78),
#  ('case-sensitive', 78),
#  ('preg-replace', 78),
#  ('sendmail', 78),
#  ('etl', 78),
#  ('sqlplus', 77),
#  ('relationship', 77),
#  ('privacy', 77),
#  ('spam', 77),
#  ('hierarchical-data', 76),
#  ('urlencode', 76),
#  ('mime', 76),
#  ('file-get-contents', 75),
#  ('linked-server', 75),
#  ('ibm-midrange', 75),
#  ('verification', 75),
#  ('roles', 75),
#  ('payment-gateway', 74),
#  ('ddl', 74),
#  ('xml-rpc', 73),
#  ('share', 73),
#  ('bulkinsert', 73),
#  ('average', 73),
#  ('edit', 72),
#  ('drupal-views', 71),
#  ('session-cookies', 71),
#  ('exists', 71),
#  ('email-validation', 71),
#  ('simplexml', 71),
#  ('varchar', 71),
#  ('bulk', 70),
#  ('olap', 70),
#  ('propel', 70),
#  ('collation', 70),
#  ('sas', 70),
#  ('mysql-error-1064', 69),
#  ('truncate', 69),
#  ('uniqueidentifier', 69),
#  ('httpd.conf', 69),
#  ('yahoo', 69),
#  ('business-intelligence', 69),
#  ('quotes', 69),
#  ('wampserver', 68),
#  ('sql-execution-plan', 68),
#  ('privileges', 68),
#  ('aes', 68),
#  ('crud', 68),
#  ('ranking', 68),
#  ('gd', 68),
#  ('logout', 68),
#  ('greatest-n-per-group', 68),
#  ('rows', 67),
#  ('case-insensitive', 67),
#  ('sap-ase', 67),
#  ('administration', 67),
#  ('status', 67),
#  ('spam-prevention', 67),
#  ('csrf', 67),
#  ('reverse-proxy', 67),
#  ('product', 66),
#  ('calculated-columns', 65),
#  ('preg-match', 65),
#  ('coldfusion-9', 65),
#  ('alter-table', 65),
#  ('coldfusion-8', 65),
#  ('sphinx', 64),
#  ('partitioning', 64),
#  ('account', 64),
#  ('taxonomy', 64),
#  ('code-injection', 64),
#  ('basic-authentication', 63),
#  ('ubercart', 63),
#  ('uuid', 63),
#  ('httpresponse', 63),
#  ('protection', 62),
#  ('sanitization', 62),
#  ('imagemagick', 62),
#  ('mdx', 62),
#  ('friendly-url', 62),
#  ('phpmailer', 61),
#  ('wordpress-theming', 61),
#  ('http-status-code-301', 61),
#  ('salt', 61),
#  ('phpbb', 61),
#  ('facebook-javascript-sdk', 61),
#  ('php4', 61),
#  ('tagging', 61),
#  ('data-migration', 61),
#  ('file-permissions', 61),
#  ('access-control', 60),
#  ('associative-array', 60),
#  ('subdirectory', 60),
#  ('expressionengine', 60),
#  ('unique-constraint', 60),
#  ('apc', 60),
#  ('xdebug', 60),
#  ('permalinks', 59),
#  ('vps', 59),
#  ('audit', 59),
#  ('bouncycastle', 59),
#  ('icalendar', 59),
#  ('payment', 58),
#  ('zend-form', 58),
#  ('google-calendar-api', 57),
#  ('x509certificate', 57),
#  ('credit-card', 57),
#  ('common-table-expression', 57),
#  ('database-replication', 57),
#  ('date-format', 56),
#  ('alter', 56),
#  ('aggregation', 56),
#  ('database-table', 55),
#  ('date-range', 55),
#  ('facebook-fql', 55),
#  ('backend', 55),
#  ('apache-config', 55),
#  ('materialized-views', 55),
#  ('social', 55),
#  ('host', 54),
#  ('paypal-ipn', 54),
#  ('entity-attribute-value', 54),
#  ('restore', 54),
#  ('plesk', 54),
#  ('http-authentication', 54),
#  ('webdav', 54),
#  ('multiple-tables', 54),
#  ('mysql-management', 54),
#  ('oauth-2.0', 54),
#  ('insert-update', 53),
#  ('wikipedia', 53),
#  ('denormalization', 53),
#  ('maintenance', 53),
#  ('odp.net', 53),
#  ('pecl', 53),
#  ('outer-join', 53),
#  ('user-accounts', 52),
#  ('http-status-code-403', 52),
#  ('http-status-codes', 52),
#  ('html-entities', 52),
#  ('composite-key', 52),
#  ('referrer', 51),
#  ('fbml', 51),
#  ('oracle-sqldeveloper', 51),
#  ('record', 51),
#  ('robots.txt', 51),
#  ('referential-integrity', 51),
#  ('delete-row', 51),
#  ('pop3', 51),
#  ('signature', 51),
#  ('facebook-opengraph', 50),
#  ('facebook-php-sdk', 50),
#  ('execute', 50),
#  ('self-join', 49),
#  ('unix-timestamp', 49),
#  ('fatal-error', 49),
#  ('linkedin', 49),
#  ('postfix-mta', 49),
#  ('flat-file', 49),
#  ('x509', 49),
#  ('oscommerce', 49),
#  ('mysql-workbench', 49),
#  ('plpgsql', 49),
#  ('recursive-query', 48),
#  ('recaptcha', 48),
#  ('toad', 48),
#  ('slug', 47),
#  ('database-partitioning', 47),
#  ('codeigniter-2', 47),
#  ('unique-key', 47),
#  ('lucene.net', 47),
#  ('varnish', 47),
#  ('cache-control', 46),
#  ('autoload', 46),
#  ('intervals', 46),
#  ('http-referer', 46),
#  ('database-migration', 46),
#  ('nested-sets', 46),
#  ('vbulletin', 46),
#  ('ini', 46),
#  ('login-script', 46),
#  ('group-concat', 46),
#  ('email-spam', 46),
#  ('private-key', 45),
#  ('database-backups', 45),
#  ('crontab', 45),
#  ('session-timeout', 45),
#  ('create-table', 45),
#  ('checkout', 45),
#  ('contact', 45),
#  ('gdata', 45),
#  ('authorize.net', 45),
#  ('forwarding', 45),
#  ('facebook-c#-sdk', 44),
#  ('rfc', 44),
#  ('contains', 44),
#  ('clustered-index', 44),
#  ('procedure', 44),
#  ('cart', 44),
#  ('public-key', 44),
#  ('data-integrity', 44),
#  ('hostname', 43),
#  ('sqlclr', 43),
#  ('pki', 43),
#  ('clob', 43),
#  ('cakephp-1.2', 43),
#  ('jobs', 43),
#  ('teradata', 43),
#  ('custom-fields', 43),
#  ('faceted-search', 43),
#  ('url-encoding', 43),
#  ('sql-server-2008-express', 42),
#  ('access-token', 42),
#  ('mainframe', 42),
#  ('mcrypt', 42),
#  ('synonym', 42),
#  ('gettext', 42),
#  ('datediff', 42),
#  ('database-performance', 42),
#  ('moodle', 42),
#  ('relation', 42),
#  ('newsletter', 42),
#  ('hotmail', 42),
#  ('relationships', 42),
#  ('grant', 41),
#  ('php-extension', 41),
#  ('records', 41),
#  ('sha256', 41),
#  ('http-status-code-302', 41),
#  ('breadcrumbs', 41),
#  ('plaintext', 41),
#  ('zend-db-table', 41),
#  ('mysql-error-1054', 41),
#  ('domain-name', 41),
#  ('apostrophe', 41),
#  ('facebook-page', 41),
#  ('rank', 40),
#  ('having', 40),
#  ('sqlanywhere', 40),
#  ('oracle-apex', 40),
#  ('mail-server', 40),
#  ('bcp', 40),
#  ('http-get', 40),
#  ('oracle-xe', 40),
#  ('powerbuilder', 40),
#  ('reportingservices-2005', 40),
#  ('date-arithmetic', 40),
#  ('fsockopen', 40),
#  ('gdata-api', 39),
#  ('hmac', 39),
#  ('cube', 39),
#  ('concat', 39),
#  ('bootstrapping', 39),
#  ('php-5.2', 39),
#  ('public-key-encryption', 39),
#  ('cryptoapi', 39),
#  ('multiple-domains', 39),
#  ('postgis', 39),
#  ('coalesce', 39),
#  ('translate', 39),
#  ('google-search', 39),
#  ('sqlbulkcopy', 38),
#  ('datetime-format', 38),
#  ('magento-1.4', 38),
#  ('min', 38),
#  ('digest', 38),
#  ('utc', 38),
#  ('mysql-real-escape-string', 38),
#  ('shipping', 38),
#  ('substr', 38),
#  ('google-checkout', 38),
#  ('modx', 38),
#  ('mod-proxy', 38),
#  ('gnupg', 38),
#  ('chmod', 38),
#  ('drupal-theming', 37),
#  ('ansi-sql', 37),
#  ('cascading-deletes', 37),
#  ('digital-certificate', 37),
#  ('rating', 37),
#  ('filemaker', 37),
#  ('sharing', 37),
#  ('sql-loader', 37),
#  ('spell-checking', 37),
#  ('mediatemple', 37),
#  ('cname', 37),
#  ('database-relations', 37),
#  ('virtual-hosts', 37),
#  ('payment-processing', 37),
#  ('sanitize', 37),
#  ('integrity', 37),
#  ('sql-drop', 36),
#  ('sqldatatypes', 36),
#  ('zend-studio', 36),
#  ('erd', 36),
#  ('clean-urls', 36),
#  ('full-text-indexing', 36),
#  ('str-replace', 36),
#  ('row-number', 36),
#  ('vhosts', 36),
#  ('strtotime', 36),
#  ('content-management', 36),
#  ('data-storage', 36),
#  ('phpbb3', 36),
#  ('multiple-columns', 36),
#  ('explode', 36),
#  ('pci-dss', 36),
#  ('dst', 36),
#  ('database-agnostic', 36),
#  ('sign', 35),
#  ('sessionid', 35),
#  ('facebook-social-plugins', 35),
#  ('recovery', 35),
#  ('virtuemart', 35),
#  ('opencart', 35),
#  ('doctrine-1.2', 35),
#  ('keep-alive', 35),
#  ('ora-00904', 35),
#  ('domdocument', 35),
#  ('pgp', 35),
#  ('information-schema', 35),
#  ('meta', 35),
#  ('pem', 35),
#  ('encryption-asymmetric', 34),
#  ('zend-server', 34),
#  ('xfbml', 34),
#  ('between', 34),
#  ('upsert', 34),
#  ('isnull', 34),
#  ('whitelist', 34),
#  ('prestashop', 34),
#  ('url-shortener', 34),
#  ('web-analytics', 34),
#  ('sql-server-agent', 34),
#  ('sha', 34),
#  ('smo', 34),
#  ('duplicate-removal', 34),
#  ('pentaho', 34),
#  ('epoch', 34),
#  ('tcpdf', 34),
#  ('database-deadlocks', 34),
#  ('zen-cart', 34),
#  ('isapi-rewrite', 33),
#  ('sql-server-2005-express', 33),
#  ('dql', 33),
#  ('database-administration', 33),
#  ('swiftmailer', 33),
#  ('unique-index', 33),
#  ('google-analytics-api', 33),
#  ('sql-function', 33),
#  ('cobol', 33),
#  ('hosts', 33),
#  ('sugarcrm', 33),
#  ('duration', 33),
#  ('remember-me', 33),
#  ('varbinary', 33),
#  ('photos', 32),
#  ('encryption-symmetric', 32),
#  ('sql-view', 32),
#  ('load-data-infile', 32),
#  ('dml', 32),
#  ('google-plus', 32),
#  ('advantage-database-server', 32),
#  ('setcookie', 32),
#  ('datamodel', 32),
#  ('remote-server', 32),
#  ('picasa', 32),
#  ('bbcode', 32),
#  ('ssi', 31),
#  ('virus', 31),
#  ('drupal-taxonomy', 31),
#  ('simpletest', 31),
#  ('http-redirect', 31),
#  ('crosstab', 31),
#  ('restrict', 31),
#  ('put', 31),
#  ('permission-denied', 31),
#  ('user-roles', 31),
#  ('cubes', 31),
#  ('star-schema', 31),
#  ('phpdoc', 31),
#  ('hierarchical', 31),
#  ('stored-functions', 31),
#  ('mysql-error-1062', 31),
#  ('activation', 31),
#  ('joomla1.6', 31),
#  ('antivirus', 31),
#  ('dts', 31),
#  ('oracle-call-interface', 31),
#  ('mysql-error-1146', 31),
#  ('facebook-wall', 30),
#  ('mysql5', 30),
#  ('forums', 30),
#  ('crypt', 30),
#  ('email-attachments', 30),
#  ('squid', 30),
#  ('thunderbird', 30),
#  ('ora-01722', 30),
#  ('railo', 30),
#  ('dblink', 30),
#  ('zend-search-lucene', 30),
#  ('user-profile', 30),
#  ('blowfish', 30),
#  ('wildcard-subdomain', 30),
#  ('ampersand', 29),
#  ('interbase', 29),
#  ('query-performance', 29),
#  ('self-reference', 29),
#  ('google-ads-api', 29),
#  ('mysql-error-1045', 29),
#  ('cognos', 29),
#  ('phpexcel', 29),
#  ('twig', 29),
#  ('blacklist', 29),
#  ('facebook-authentication', 29),
#  ('authsub', 29),
#  ('sql-scripts', 29),
#  ('apache2.2', 29),
#  ('google-data-api', 29),
#  ('sequences', 29),
#  ('file-type', 29),
#  ('data-retrieval', 29),
#  ('bids', 29),
#  ('database-normalization', 29),
#  ('composite-primary-key', 29),
#  ('fuzzy-search', 29),
#  ('email-client', 28),
#  ('plsqldeveloper', 28),
#  ('lookup-tables', 28),
#  ('pkcs#7', 28),
#  ('unixodbc', 28),
#  ('sfguard', 28),
#  ('rights', 28),
#  ('.htpasswd', 28),
#  ('googlebot', 28),
#  ('yslow', 28),
#  ('facebook-apps', 28),
#  ('derived-table', 28),
#  ('identity-column', 28),
#  ('gateway', 28),
#  ('opensocial', 28),
#  ('user-permissions', 28),
#  ('sql-insert', 27),
#  ('nutch', 27),
#  ('drupal-blocks', 27),
#  ('gmt', 27),
#  ('cross-join', 27),
#  ('where-in', 27),
#  ('image-uploading', 27),
#  ('audit-trail', 27),
#  ('cfquery', 27),
#  ('iso', 27),
#  ('zend-auth', 27),
#  ('drupal-forms', 27),
#  ('pci-compliance', 27),
#  ('cfc', 27),
#  ('reserved-words', 27),
#  ('drupal-fapi', 27),
#  ('email-headers', 27),
#  ('schedule', 27),
#  ('rownum', 26),
#  ('htmlpurifier', 26),
#  ('file-exists', 26),
#  ('check-constraints', 26),
#  ('correlated-subquery', 26),
#  ('usergroups', 26),
#  ('slash', 26),
#  ('yahoo-api', 26),
#  ('quote', 26),
#  ('swfupload', 26),
#  ('solrnet', 26),
#  ('forgot-password', 26),
#  ('dsn', 26),
#  ('olap-cube', 26),
#  ('client-certificates', 26),
#  ('urldecode', 26),
#  ('zend-server-ce', 26),
#  ('relational-algebra', 26),
#  ('redundancy', 26),
#  ('drupal-5', 26),
#  ('nvarchar', 26),
#  ('dayofweek', 26),
#  ('schema-design', 26),
#  ('gaps-and-islands', 25),
#  ('sql-server-profiler', 25),
#  ('nusoap', 25),
#  ('inventory', 25),
#  ('fbjs', 25),
#  ('invoice', 25),
#  ('webmail', 25),
#  ('asn.1', 25),
#  ('bluehost', 25),
#  ('dimension', 25),
#  ('autologin', 25),
#  ('short-url', 25),
#  ('canonical-link', 25),
#  ('user-defined-types', 25),
#  ('database-versioning', 25),
#  ('surrogate-key', 25),
#  ('in-clause', 25),
#  ('implode', 25),
#  ('magento-1.5', 25),
#  ('htmlspecialchars', 25),
#  ('affiliate', 25),
#  ('mysql-error-1005', 25),
#  ('sqlperformance', 25),
#  ('service-broker', 25),
#  ('tablespace', 25),
#  ('elgg', 25),
#  ('table-variable', 25),
#  ('foursquare', 25),
#  ('joomla-extensions', 25),
#  ('csr', 25),
#  ('zend-mail', 25),
#  ('quickbooks', 25),
#  ('date-formatting', 25),
#  ('preg-match-all', 24),
#  ('facebook-fbml', 24),
#  ('phing', 24),
#  ('zend-route', 24),
#  ('jce', 24),
#  ('having-clause', 24),
#  ('facebook-oauth', 24),
#  ('mod-jk', 24),
#  ('google-contacts-api', 24),
#  ('ora-00942', 24),
#  ('double-quotes', 24),
#  ('isolation-level', 24),
#  ('digg', 24),
#  ('transaction-log', 24),
#  ('server-side-includes', 24),
#  ('rfc822', 24),
#  ('openquery', 24),
#  ('paypal-sandbox', 24),
#  ('janrain', 24),
#  ('malware', 24),
#  ('watermark', 24),
#  ('output-buffering', 24),
#  ('strftime', 24),
#  ('strpos', 24),
#  ('relevance', 24),
#  ('mdf', 24),
#  ('owasp', 24),
#  ('cdc', 23),
#  ('cursors', 23),
#  ('banking', 23),
#  ('oracleclient', 23),
#  ('rbac', 23),
#  ('union-all', 23),
#  ('cfml', 23),
#  ('superglobals', 23),
#  ('drupal-themes', 23),
#  ('digest-authentication', 23),
#  ('iso8601', 23),
#  ('drupal-webform', 23),
#  ('zos', 23),
#  ('url-parameters', 23),
#  ('wikipedia-api', 23),
#  ('matomo', 23),
#  ('strip-tags', 23),
#  ('accounting', 23),
#  ('pkcs#12', 23),
#  ('lampp', 23),
#  ('case-statement', 23),
#  ('contact-form', 23),
#  ('solrj', 23),
#  ('cfhttp', 23),
#  ('password-recovery', 23),
#  ('userid', 23),
#  ('password-hash', 23),
#  ('pagerank', 23),
#  ('master-slave', 23),
#  ('secret-key', 22),
#  ('sqlcmd', 22),
#  ('pbkdf2', 22),
#  ('google-api-java-client', 22),
#  ('self-signed', 22),
#  ('content-length', 22),
#  ('mysql-connector', 22),
#  ('database-project', 22),
#  ('silverstripe', 22),
#  ('phishing', 22),
#  ('window-functions', 22),
#  ('google-openid', 22),
#  ('sql-optimization', 22),
#  ('rijndaelmanaged', 22),
#  ('google-plus-one', 22),
#  ('nonce', 22),
#  ('data-synchronization', 22),
#  ('filezilla', 22),
#  ('database-cursor', 22),
#  ('dsa', 22),
#  ('analyzer', 22),
#  ('analytic-functions', 22),
#  ('symfony-forms', 22),
#  ('period', 22),
#  ('corrupt', 22),
#  ('parameterized-query', 22),
#  ('web-traffic', 22),
#  ('gmail-imap', 22),
#  ('require-once', 22),
#  ('organic-groups', 21),
#  ('diffie-hellman', 21),
#  ('openrowset', 21),
#  ('ora-00932', 21),
#  ('pkcs#11', 21),
#  ('tnsnames', 21),
#  ('bit.ly', 21),
#  ('job-scheduling', 21),
#  ('database-indexes', 21),
#  ('last.fm', 21),
#  ('unset', 21),
#  ('case-when', 21),
#  ('ora-00001', 21),
#  ('identity-insert', 21),
#  ('hmvc', 21),
#  ('distinct-values', 21),
#  ('geography', 21),
#  ('ddos', 21),
#  ('buddypress', 21),
#  ('compound-key', 21),
#  ('zend-form-element', 21),
#  ('webmin', 21),
#  ('tld', 21),
#  ('rule', 21),
#  ('firebird2.1', 21),
#  ('des', 21),
#  ('zend-gdata', 21),
#  ('spoofing', 21),
#  ('subtotal', 21),
#  ('getdate', 21),
#  ('imagick', 21),
#  ('custom-post-type', 21),
#  ('data-recovery', 21),
#  ('openedge', 21),
#  ('bcrypt', 21),
#  ('zend-navigation', 21),
#  ('document-management', 21),
#  ('progress-db', 21),
#  ('merge-replication', 21),
#  ('certificate-authority', 21),
#  ('3des', 21),
#  ('isset', 20),
#  ('not-exists', 20),
#  ('socialengine', 20),
#  ('spl', 20),
#  ('isql', 20),
#  ('etag', 20),
#  ('review', 20),
#  ('deterministic', 20),
#  ('movabletype', 20),
#  ('intersect', 20),
#  ('httpserver', 20),
#  ('dateadd', 20),
#  ('content-disposition', 20),
#  ('object-oriented-database', 20),
#  ('mkdir', 20),
#  ('drupal-hooks', 20),
#  ('zend-acl', 20),
#  ('ora-06550', 20),
#  ('denial-of-service', 20),
#  ('posts', 20),
#  ('phpinfo', 20),
#  ('simpledateformat', 20),
#  ('pyrocms', 20),
#  ('zend-view', 20),
#  ('freetds', 20),
#  ('mod-security', 20),
#  ('mdb2', 20),
#  ('quota', 20),
#  ('data-dictionary', 20),
#  ('makecert', 20),
#  ('chunked', 19),
#  ('sef', 19),
#  ('kohana-orm', 19),
#  ('data-import', 19),
#  ('whm', 19),
#  ('freetext', 19),
#  ('datadude', 19),
#  ('disaster-recovery', 19),
#  ('sfdoctrineguard', 19),
#  ('hotlinking', 19),
#  ('whois', 19),
#  ('netezza', 19),
#  ('ingres', 19),
#  ('mod-expires', 19),
#  ('socks', 19),
#  ('days', 19),
#  ('popularity', 19),
#  ('multivalue', 19),
#  ('chunked-encoding', 19),
#  ('http-proxy', 19),
#  ('drupal-nodes', 19),
#  ('easyphp', 19),
#  ('ora-00933', 19),
#  ('cumulative-sum', 19),
#  ('haproxy', 19),
#  ('datamart', 19),
#  ('article', 19),
#  ('fact-table', 19),
#  ('reportbuilder', 19),
#  ('navicat', 19),
#  ('dompdf', 19),
#  ('oracleforms', 19),
#  ('multi-user', 19),
#  ('facebook-sharer', 19),
#  ('tinyurl', 19),
#  ('zend-translate', 19),
#  ('junction-table', 18),
#  ('query-builder', 18),
#  ('facebook-canvas', 18),
#  ('document-root', 18),
#  ('datetimeoffset', 18),
#  ('uptime', 18),
#  ('resolve', 18),
#  ('cardinality', 18),
#  ('smime', 18),
#  ('sybase-asa', 18),
#  ('transactional-replication', 18),
#  ('paypal-subscriptions', 18),
#  ('pervasive', 18),
#  ('elliptic-curve', 18),
#  ('codeigniter-url', 18),
#  ('week-number', 18),
#  ('sp-executesql', 18),
#  ('mod-alias', 18),
#  ('http-method', 18),
#  ('google-buzz', 18),
#  ('mx-record', 18),
#  ('mysql-error-1093', 18),
#  ('password-encryption', 18),
#  ('theming', 18),
#  ('joomla-sef-urls', 18),
#  ('tns', 18),
#  ('rijndael', 18),
#  ('gravatar', 18),
#  ('vertica', 18),
#  ('rate', 18),
#  ('chown', 18),
#  ('mysql-connect', 18),
#  ('httpcookie', 18),
#  ('weather', 18),
#  ('explain', 18),
#  ('drupal-comments', 18),
#  ('zend-session', 18),
#  ('google-search-api', 18),
#  ('dbo', 18),
#  ('cakephp-model', 18),
#  ('error-log', 18),
#  ('redgate', 18),
#  ('containable', 17),
#  ('ora-00900', 17),
#  ...]

# %%
f = open("../filter/final_categories.txt", "r")
categories = f.read().split(", ")
categories
# Out:
# ['component',
#  'database',
#  'extension',
#  'environment',
#  'language',
#  'library',
#  'platform',
#  'subsystem',
#  'framework',
#  'ide',
#  'tool',
#  'toolkit',
#  'utility',
#  'system']

# %%
for a, b in sorted(G_1.degree, key=lambda x: x[1], reverse=True):
    if str(G.nodes[a]['root']) != "nan" and str(G.nodes[a]['root']) in categories:
        print(a + "," + str(b) + "," + G.nodes[a]['root'] + "," + node_attr[a]["Body"])
    #else:
    #    print(a + " " + str(b))
# Out:
# mysql,1191,system,mysql is a free open source relational database management system (rdbms) that uses structured query language (sql).
# sql,1138,language,structured query language (sql) is a language for querying databases.
# sql-server,822,system,microsoft sql server is a relational database management system (rdbms).
# oracle,664,system,oracle database is a multi-model database management system created by oracle corporation.
# postgresql,518,system,postgresql is an open-source relational database management system (rdbms) available for all major platforms including linux unix windows and os x. mention your version of postgres when asking questions.
# zend-framework,490,framework,zend framework is an open source object-oriented web application framework implemented in php 7.1 and licensed under the new bsd license.
# drupal,469,framework,drupal is an open source cms framework written in php.
# codeigniter,437,framework,codeigniter is an application development framework - a toolkit - for people who build web sites using php.
# tsql,437,extension,t-sql (transact structured query language) is the extension of sql functionality supported by sybase ase and microsoft sql server.
# cakephp,423,framework,cakephp is an open-source web rapid development framework for php that provides an extensible architecture for developing maintaining and deploying applications.
# coldfusion,316,platform,coldfusion is a server-side rapid application development platform implementing the dynamic general purpose cfml programming language.
# magento,305,platform,magento is an e-commerce platform written in php.
# curl,282,tool,curl is a library and command-line tool for transferring data using various protocols such as http ftp and sftp.
# plsql,261,extension,pl/sql (procedural language/structured query language) is oracle corporation's procedural language extension for sql.
# content-management-system,242,platform,a content management system (cms) is a platform used to build websites that are easily edited by multiple users.
# phpmyadmin,204,tool,phpmyadmin is an open-source web-based mysql administration tool written in php.
# oracle11g,185,system,oracle is an object-relational database management system (ordbms) created by oracle corporation.
# ssis,175,platform,ssis (microsoft sql server integration services) is a platform for building enterprise-level data integration and data transformations solutions.
# relational-database,153,database,a relational database is a database consisting of relation variables (which are also called *relvars* *r-tables* or just *tables*).
# openssl,145,toolkit,openssl is an open source software toolkit that implements the ssl/tls protocol as well as a general cryptographic library.
# calendar,134,system,a calendar is a system of reckoning time in which the beginning length and divisions of a year are defined.
# rdbms,127,system,a relational database management system (rdbms) is a database management system (dbms) in which data is stored in tables and the relationships among the data are also stored in tables.
# phpunit,112,framework,phpunit is a programmer-oriented testing framework for php.
# special-characters,112,language,special characters (as they apply to programming) are language-specific reserved characters or symbols used to accomplish a specific task (e.g. wildcard characters data type indicators escape characters etc).
# firebird,107,system,firebird is a free and open-source cross-platform client-server sql relational database management system running on linux unix and windows.
# ssms,101,tool,microsoft sql server management studio is a graphical tool for configuring managing and administering all components within microsoft sql server.
# data-warehouse,100,database,a data warehouse (dw) is a database specifically structured/designed to aid in querying analyzing and reporting (generating reports out of) of current and historical data.
# oracle9i,98,system,oracle is a relational database management system (rdbms) product.
# kohana-3,90,framework,kohana 3 is a hmvc (hierarchical model-view-controller) php framework that places security scalability and rapid development at its forefront.
# ibm-midrange,75,platform,the ibm i is a proprietary platform from ibm which runs on their power systems and pure systems and contains a db2 database integrated into the ibm i os.
# coldfusion-9,65,platform,coldfusion is a server-side rapid application development platform from adobe.
# mdx,62,language,multidimensional expressions (mdx) is a query language for olap databases.
# expressionengine,60,system,expressionengine is a commercial content management system written in php.
# xdebug,60,extension,xdebug is a php extension with developing aids a profiler an interactive debugging and a code coverage information gatherer.
# oauth-2.0,54,framework,oauth (open authorization) is an open protocol framework to allow secure api authorization in a simple and standardized way for desktop mobile and web applications.
# oracle-sqldeveloper,51,tool,oracle sql developer is a free and fully supported graphical tool for oracle database development.
# flat-file,49,system,a flat-file database model is any system using a single file for storage with one record per line usually plain-text or text mixed with binary data.
# mysql-workbench,49,tool,mysql workbench is a visual database design tool that is developed by mysql.
# plpgsql,49,language,pl/pgsql is the default procedural language for postgresql.
# toad,48,tool,toad is a database query tool from quest software.
# teradata,43,system,teradata is a relational database management system (rdbms) capable of supporting many concurrent users from various client platforms.
# sql-server-2008-express,42,platform,sql server 2008 express is a free edition of sql server that is an ideal data platform for learning and building desktop and small server applications and for redistribution by isvs.
# moodle,42,system,moodle is an open source learning management system (lms) written in php.
# oracle-apex,40,tool,oracle application express (oracle apex) is a rapid web application development tool that lets you share data and create applications.
# oracle-xe,40,database,oracle database express edition (oracle database xe) is an entry-level small-footprint database free to develop deploy and distribute; fast to download; and simple to administer.
# reportingservices-2005,40,system,ssrs (sql server reporting services) is a server-based report generation software system from microsoft.
# magento-1.4,38,platform,magento is an ecommerce platform written in php.
# sql-loader,37,utility,sql*loader is a high-speed data loading utility that loads data from external files into tables in an oracle database.
# zend-studio,36,environment,zend studio is a commercial proprietary integrated development environment (ide) for php developed by zend technologies based on the php development tools (pdt) plugin for the eclipse platform (the pdt project is led by zend).
# epoch,34,system,unix time or posix time is a system for describing points in time defined as the number of seconds elapsed since midnight coordinated universal time (utc) of january 1 1970 not counting leap seconds.
# dql,33,language,doctrine query language (dql) is an object query language created for helping users in complex object retrieval.
# swiftmailer,33,library,swift mailer is a library that integrates into any web app written in php offering a flexible and elegant object-oriented approach to sending emails with a multitude of features.
# advantage-database-server,32,system,advantage database server is an embedded relational database management system from sybase.
# datamodel,32,tool,according to hoberman (2009) "a data model is a wayfinding tool for both business and it professionals which uses a set of symbols and text to precisely explain a subset of real information to improve communication within the organization and thereby lead to a more flexible and stable application environment.
# bbcode,32,language,bulletin board code is a lightweight markup language used to format posts in many message boards.
# ssi,31,language,server side includes (ssi) is a simple interpreted server-side scripting language used almost exclusively for the web.
# cubes,31,framework,cubes is an open-source light-weight python framework and olap http server for easy development of reporting applications and aggregate browsing of multi-dimensionally modeled data.
# phpdoc,31,tool,phpdocumentor (phpdoc) is an automatic code-documentation tool for php based on javadoc.
# railo,30,platform,railo is an open source (lgpl) rapid application development platform implementing the general-purpose cfml language compatible with adobe coldfusion's implementation but with various extensions/updates.
# zend-search-lucene,30,library,zend search lucene is a php library for creating and searching full text indexes using the lucene index format.
# interbase,29,system,interbase is a sql database system for server desktop and embedded applications for use on windows linux macos ios and android.
# plsqldeveloper,28,environment,pl/sql developer is an integrated development environment by allround automations that is specifically targeted at the development of stored program units for oracle databases.
# olap-cube,26,database,an olap cube is a multidimensional database that is optimized for data warehouse and online analytical processing (olap) applications.
# magento-1.5,25,platform,magento is an ecommerce platform written in php.
# service-broker,25,framework,sql server service broker is a messaging framework built into sql server.
# phing,24,system,phing is a project build system based on apache ant.
# zend-route,24,framework,zend framework is an open source object-oriented web application framework implemented in php 5 and licensed under the new bsd license.
# server-side-includes,24,language,server side includes (ssi) is a simple interpreted server-side scripting language used almost exclusively for the web.
# paypal-sandbox,24,environment,the paypal sandbox is a self-contained environment within which you can prototype and test paypal features and apis.
# cfml,23,language,cfml is a dynamic general-purpose programming language especially suited for web and intranet development.
# zos,23,system,z/os is a 64-bit operating system that runs on ibm's traditional mainframe hardware also known as system z.
# sqlcmd,22,tool,sqlcmd is a command line tool used to run sql batches on microsoft sql server.
# google-api-java-client,22,library,the google apis client library for java is a flexible efficient and powerful java client library for accessing any http-based api on the web not just google apis.
# silverstripe,22,framework,silverstripe is a free and open source php web development framework and content management system (cms) based on the eponymous silverstripe framework.
# symfony-forms,22,library,the symfony form component is a standalone library that can be used outside of symfony projects.
# imagick,21,extension,imagick is a native php extension to create and modify images using the imagemagick library.
# openedge,21,platform,progress openedge is an application development platform from progress software corporation
# zend-navigation,21,component,zend_navigation is a component for managing trees of pointers to web pages  on zend framework
# socialengine,20,platform,socialengine is a php-based white label social network platform.
# isql,20,utility,the isql utility is a command-line interactive sql utility that uses the adaptive server enterprise open client api.
# movabletype,20,system,movable type is a weblog publishing system developed by six apart ltd.
# makecert,20,tool,makecert.exe is a command line x.509 digital certificate creation tool included with microsoft visual studio.
# facebook-canvas,18,environment,facebook canvas is the application environment for 3rd party games & applications that live within facebook in a framed environment.
# vertica,18,database,vertica is an mpp column-store analytics database that runs on clusters of linux servers or in the cloud.
# zend-session,18,component,zend session is a component made by zend which helps in managing and preserving sessions in any application which uses zend libraries.
# awstats,17,tool,awstats is an open source web analytics tool that parses server logs to provide website analytics.
# suhosin,17,system,suhosin is an advanced protection system for php installations.
# basecamp,16,tool,basecamp is a web-based project-management tool developed by 37signals and launched in 2004.
# concrete5,16,system,concrete5 is an open source content management system (cms) written in php and based on the zend framework.
# zend-debugger,16,extension,zend debugger is a web server extension providing support for remote debugging of the php language.
# spf,16,system,sender policy framework (spf) is a system designed to prevent email spoofing/forgery
# gdlib,15,library,gd library is free php extension library used for image manipulation.
# phpstorm,15,ide,jetbrains phpstorm is a commercial ide for php built on jetbrains' intellij idea.
# posterous,15,platform,posterous was a simple blogging platform started in may 2008 funded by y combinator.
# progress-4gl,15,language,the progress 4gl is a multi-platform interpreted language typically used to build business applications and is now known as abl.
# suphp,14,tool,suphp is a tool for executing php scripts with the permissions of their owners.
# informatica-powercenter,14,tool,informatica powercenter is an etl (extract transform and load) tool developed by informatica corporation.
# bitnami,14,library,bitnami is a library of popular server applications and development environments that can be installed with one click either in your laptop in a virtual machine or hosted in the cloud.
# ioncube,14,tool,ioncube is a tool to obfuscate php code so clients can run software without having the source code.
# zend-lucene,14,framework,[tag:zend-lucene] is the lucene library of the zend framework which is a powerful open source web application framework for developing php 5 web applications.
# mantis,14,system,mantisbt is a free popular web-based bugtracking system.
# joomla-template,14,system,joomla is an open source content management system for web sites which includes a powerful template system.
# lightopenid,14,library,lightopenid is a lightweight openid library written in php.
# zend-paginator,14,component,zend-paginator is a flexible component for paginating collections of data and presenting that data to users.
# jcl,14,language,job control language (jcl) is a scripting language used on the ibm mainframe operating systems z/os and z/vse (and predecessors) to instruct the system on how to run a batch job or start a subsystem.
# intl,13,extension,intl is a php extension which give ability to use unicode software internationalization (i18n) and globalization (g11n) from the icu library.
# storage-engines,13,component,a storage engine is the underlying software component used to create read update and delete data from a data store.
# simplepie,13,library,simplepie is a php library intended to make it ridiculously easy for people to manage rss and atom feeds.
# gearman,12,system,gearman is a system to farm out work to other machines dispatching function calls to machines that are better suited to do work to do work in parallel to load balance lots of function calls or to call functions between languages.
# tankauth,12,library,tank auth is an authentication library for php-framework codeigniter.
# zend-controller-router,12,framework,zend framework is an open source object-oriented web application framework implemented in php 5 and licensed under the new bsd license.
# phpthumb,12,library,phpthumb is a php library used to create thumbnails from images on the fly.
# phpass,12,framework,phpass is a portable public domain password hashing framework for use in php applications.
# pg-dump,12,utility,pg_dump is a utility for backing up a postgresql database.
# pywikibot,12,library,pywikibot is a python library to access the mediawiki api.
# opcode-cache,11,system,an opcode cache is a system to cache the result of the php code compilation to bytecode.
# textpattern,11,system,textpattern is an open source content management system written in php and uses mysql as a database backend.
# phped,11,environment,phped is the integrated development environment for php (php ide) html css xml smarty xhtml and other.
# creole,11,language,creole is a common wiki markup language to be used across different wikis.
# atk4,10,framework,agile toolkit is object oriented php framework for building rich web ui
# hierarchyid,10,extension,hierarchyid is a tsql extension available from sql server 2008 to map hierarchical structures in a flat table.
# mage,10,tool,the manifest generation and editing tool (mage.exe) is a command-line tool that supports the creation and editing of application and deployment manifests for windows applications.
# zend-tool,10,utility,zend tool or zftool is a command line utility for managing zend framework 2 (previously  zend framework 1) applications.
# sql-agent,10,system,sql agent also known as sql server agent is a microsoft sql server relational database management system (rdbms) background tool.
# cmsmadesimple,10,system,cms made simple is a content management system for small to mid sized websites.
# signpost,10,framework,signpost is a java oauth-1.0 framework under apl-2.0 license written and maintained by matthias käppler.
# php-gettext,10,library,php-gettext is a library for emulating gettext (a widely used framework for internationalization) in php.
# rpg,10,language,rpg (report program generator) is a high-level programming language (hll) for business applications.
# distributed-database,9,database,a distributed database is a database whose information is not stored in a single physical location but it is spread over various devices often placed far apart.
# joomla-k2,9,extension,k2 is a content extension for joomla!
# phppgadmin,9,utility,phppgadmin is a fully functional web-based administration utility for a postgresql database server.
# pdflib,9,library,pdflib is a library for generating and manipulating files in adobe’s well known portable document format (pdf).
# edge-side-includes,9,language,edge side includes is a markup language designed for dynamic assembly of cached web content.
# oracle-spatial,9,extension,oracle spatial is an extension to oracle db which provides support for location data.
# express-checkout,9,system,express checkout is a paypal api payment system that allows users to accept payments from paypal accounts.
# ziparchive,9,extension,ziparchive is a php extension for manipulating zip compressed archives.
# dbvisualizer,9,tool,dbvisualizer is a popular database tool by dbvis software ab. written in java it runs on windows mac os x and unix/linux and will connect to any jdbc enabled database server.
# greenplum,9,database,greenplum is the worlds first open-source massively parallel processing database based on postgresql.
# powerdesigner,9,tool,powerdesigner is an enterprise modeling tool from sap.
# rman,8,tool,rman or recovery manager is a cli tool for performing backups and recoveries on an oracle database.
# qlikview,8,platform,qlikview is a business intelligence platform created and distributed by qlik corporation.
# authorize.net-arb,8,tool,automated recurring billing (arb) is a tool developed by authorize.
# google-website-optimizer,8,tool,google website optimizer was a free website optimization tool that provides a framework for a/b and multivariate testing.
# tso,8,environment,tso (time sharing option) is a command-line environment for ibm mainframes analogous to a unix shell.
# mailman,8,platform,mailman is a python-based open-source platform for managing email lists and discussion groups.
# btrieve,8,database,btrieve is a transactional database based on indexed sequential access method.
# 4d-database,8,platform,4d is an integrated development platform containing all of the components needed to create and distribute professional applications.
# podscms,8,framework,pods is a cms framework that lets you add and display your own content types.
# genexus,7,tool,genexus is a knowledge-based development tool mainly oriented to enterprise-class applications for the web and smart devices platforms.
# lithium,7,framework,lithium is an rad framework for php 5.3+
# reportserver,7,platform,reportserver is a  modern and versatile business intelligence (osbi) platform.
# roundhouse,7,system,roundhouse is an automated database deployment (change management) system.
# laravel,7,framework,the laravel framework is an open-sourced php web framework that allows developers to create dynamic and scalable web applications.
# rexx,7,language,rexx is a (most of the time) interpreted programming language developed by ibm in the end of 70's and beginning of 80's.
# model-glue,7,framework,model-glue is an oo web application framework based on the mvc design pattern.
# geshi,7,library,geshi is a free software library that allows syntax highlighting of source code for several markup and programming languages.
# recess,7,framework,recess is an open source restful php framework designed to give you a fun & delightful development experience.
# ccavenue,7,system,ccavenue is a very popular payment gateway system in india.
# cfeclipse,7,environment,cfeclipse is an open source integrated development environment (ide) extension to the eclipse ide.
# datastage,6,component,datastage is the etl (extract transform load) component of the ibm infosphere information server suite.
# zeta-components,6,library,apache zeta components are a high quality general purpose library of loosly coupled components for development of applications based on php 5.
# mahara,6,system,mahara is an open source e-portfolio and social-networking system allowing students at educational institutions to organise samples of their work to show to others and collaborate to form communities of practice.
# log4php,6,framework,apache log4php is a versatile logging framework for php.
# coldfusionbuilder,6,ide,coldfusion® builder™ is a professional ide from adobe® for quickly and easily building coldfusion applications.
# pchart,6,library,pchart is an object oriented php charting library.
# coldbox,6,framework,coldbox is an object-oriented event-driven framework for coldfusion that includes tools to help developers with bug reporting logging enterprise caching debugging i18n url rewriting orm integration testing and mocking.
# phpactiverecord,6,library,phpactiverecord is an open source orm library based on the activerecord pattern.
# rapidsql,6,ide,rapid sql is a sql ide allowing sql scripting query building object management debugging and version control.
# voltdb,6,database,voltdb is an in-memory database designed by several well-known database system researchers including michael stonebraker.
# ssis-2005,6,platform,microsoft sql server integration services (ssis) is a platform for building enterprise-level data integration and data transformations solutions.
# pidcrypt,6,library,pidcrypt is a javascript cryptographic library implementing rsa aes sha2 etc…
# redbean,6,library,redbeanphp is an open-source orm library written for php.
# pylucene,6,extension,pylucene is a python extension for accessing java lucene.
# pimcore,6,platform,pimcore is an open source software platform used for content management and digital commerce (backed by the pimcore company which has the same name).
# coldspring,5,framework,coldspring is a web framework for the coldfusion application programming language based on the java spring framework providing dependency injection inversion of control and aspect oriented programming.
# yii-components,5,framework,yii is an open source object-oriented component-based mvc php web application framework.
# fw1,5,framework,framework one or fw/1 is a lightweight convention-based mvc framework for cfml.
# xacml,5,language,xacml is the extensible access control markup language an open standard for specifying and evaluating authorization and access control policies.
# reportmanager,5,tool,report manager is a browser-based report access and management tool for use with sql server reporting services.
# buzz,5,framework,buzz is a lightweight php framework for http requests.
# qcodo,5,framework,qcodo development framework is an open-source php framework that focuses on freeing developers from unnecessary tedious mundane coding.
# imapx,5,library,imapx 2 is a crossplatform imap library for .net supporting ssl/tls oauth2 and all major gmail imap extensions.
# ning,5,platform,ning is a platform for creating social websites
# browscap,5,database,browscap is a browser capabilities database that provides detailed information about a browser from its user agent.
# drupal-commerce,5,framework,drupal commerce is an e-commerce framework built on drupal.
# xml-swf-charts,5,library,xml/swf charts is a library written in flash that read a xml in order to make impressive graphics charts.
# vsdbcmd,5,utility,vsdbcmd.exe is a command line utility which can be used to deploy a database or to import a database schema into a `.dbschema` file.
# usercake,5,system,usercake is a simple and secure user management system written in php.
# zend-feed,5,component,zend-feed is the feed component from zend framework.
# smtps,4,extension,smtps is an extension of smtp to secure connections with the use of ssl or tls.
# mura,4,system,mura cms is an open source content management system for cfml created by blue river interactive.
# transactional-database,4,database,a transactional database is a database in which crud operations must be done within an atomic consistent isolated and durable(acid) processing model.
# firebird-.net-provider,4,library,ado.net provider for firebird is a c# library for connecting microsoft .net programs with firebird sql server.
# ims-db,4,component,ims-db is the database-component of ibm's information management system (ims).
# datalife-engine,4,system,datalife engine (dle) is a commercial content management system written in php and mysql aimed primarily at news distribution and blogs.
# simplecaptcha,4,library,simplecaptcha is a java library for generating captcha images and audio for the challenge/answer pairs.
# sql-server-migration-assi,4,tool,sql server migration assistant is a tool to automate migration from number of various databases (oracle access sybase mysql) to sql server platform.
# ssrs-2012,4,system,ssrs (sql server reporting services) is a server-based report generation software system from microsoft.
# extended-events,4,system,sql server extended events (extended events) is a general event-handling system for server systems.
# numberformatter,4,component,numberformatter is a component of icu - international components for unicode to format numbers.
# eloquera,4,system,the eloquera database is an object-oriented database management system (oodbms) designed for the .net environment.
# gpgme,4,library,gpgme (abbreviated from gnupg made easy) is a library designed to make access to gnupg easier for applications.
# intersystems-ensemble,4,system,ensemble is an enterprise application integration system developed by intersystems in cambridge ma.
# dday,4,library,dday.ical is an icalendar class library written in c# and based on the rfc 2445 standard.
# manifold,4,system,manifold system is a geographic information system (gis) software package with support for vector and raster data spatial sql a built-in internet map server (ims) and general programming.
# ion-auth,4,library,ion auth is a user library for codeigniter.
# xmlseclibs,4,library,xmlseclibs is a library written in php for working with xml encryption and signatures.
# loginradius,3,platform,loginradius is a unified api platform enabling customers to implement social login capture social data enable social sharing and more
# sqlbuddy,3,tool,sql buddy is an open source tool written in php intended to handle the administration of mysql over the world wide web.
# varnish-vcl,3,language,the varnish configuration language (vcl) is a small domain-specific language used to define request handling and caching policies for the varnish http accelerator.
# behat,3,framework,behat is a php framework for autotesting your business expectations.
# cmdb,3,database,a configuration management database is a database storing information about equipment and their relationships in it installations.
# zikula,3,framework,zikula is an open source application framework written in php
# instapaper,3,tool,instapaper is a simple tool to save web pages for reading later.
# easytrieve,3,language,easytrieve is a programming language tailored to generating reports.
# miva,3,language,miva script is a proprietary computer scripting language mainly used for internet applications such as e-commerce just like its competitor [tag:php].
# sieve-language,3,language,sieve is a programming language that can be used to create filters for email.
# phpfox,3,platform,phpfox is a social networking platform created in php.
# cryptlib,3,library,cryptlib is a security toolkit library that allows programmers to incorporate encryption and authentication services to software.
# php4delphi,3,framework,php4delphi is a visual development framework for creating custom php extensions using delphi.
# starttls,3,extension,starttls is an extension to plain text communication protocols which offers a way to upgrade a plain text connection to an encrypted (tls or ssl) connection instead of using a separate port for encrypted communication.
# joomla-module,3,extension,a joomla module is an extension that offers certain functionality to a site that is not supposed to serve as main content and is usually placed around component code.
# sam,3,framework,simple asynchronous messaging is a php framework that provides a very simple api that can be used to access a number of messaging middleware systems from php.
# nls-lang,3,environment,nls_lang is a client side environment variable used to define language territory and character set properties and to specify the locale behavior.
# ssis-2008,3,platform,microsoft sql server integration services (ssis) is a platform for building enterprise-level data integration and data transformations solutions.
# currency-formatting,3,system,currency is a system of monetary units in common use.
# schemaspy,3,tool,schemaspy is a java-based tool that analyzes the metadata of a schema in a database and generates a visual representation of it in a browser-displayable format.
# dmx-ssas,3,language,dmx is the language used in microsoft analysis services to implement data mining.
# drizzle,3,database,drizzle is a transactional relational community-driven open-source database that is forked from the popular mysql database.
# ibm-ifs,3,component,ibm ifs (integrated files system) is a storage component in os/400.
# doophp,3,framework,doo is a high-performance mvc-based php framework for developing web 2.0 applications rapidly.
# ezapi,3,library,ezapi is a .net library written in c# by evgeny koblov one of the testers on the ssis team to abstracts away a lot of the cumbersome low-level coding needed to create ssis packages xml directly in a programming language
# authorize.net-cim,3,tool,customer information manager (cim) is a tool developed by authorize.
# yii-events,2,framework,yii is a high-performance component-based open source php framework best for developing web 2.0 applications.
# softaculous,2,library,softaculous is a commercial script library automating installation of open source or commercial web applications on a website.
# phpspreadsheet,2,library,phpspreadsheet is a library written in pure php and providing a set of classes that allow you to read from and to write to different spreadsheet file formats like excel and libreoffice calc.
# rpcl,2,framework,rpcl is a framework used to build php applications on radphp xe.
# openvas,2,framework,openvas is a framework of several services and tools offering a comprehensive and powerful vulnerability scanning and vulnerability management solution.
# activecollab,2,system,active collab is project collaboration system.
# mogrify,2,tool,mogrify is a tool from the imagemagick suite of programs and performs many actions such as resize and convert upon image files.
# frapi,2,framework,frapi is a high-level api framework that puts the “rest” back into restful.
# php-qt,2,extension,php-qt is an extension for php5 that aims to write software with the qt toolkit
# fcmp,2,language,fcmp is the sas function compilation language allowing users to write functions and subroutines that can be used in sas data steps ds2 packages and certain proc steps.
# mysqlbinlog,2,utility,mysqlbinlog is a mysql utility for processing binary log files
# libmysql,2,library,libmysql is a client library for connecting c written application to mysql.
# netcobol,2,environment,fujitsu netcobol is a cobol compiler and runtime environment for ansi standard cobol.
# object-role-modeling,2,language,object role modeling is a graphical language for expressing conceptual models.
# gmagick,2,extension,gmagick is a php extension to create modify and obtain meta information of images using the graphicsmagick api.
# sparks-pakage-management,2,system,sparks is a package management system for codeigniter that will allow you install libraries into your applications.
# yii-routing,2,framework,yii is a free open source php web application framework and it is released under the new bsd license.
# siege,2,utility,siege is an http/https regression testing and benchmarking utility.
# querypath,2,library,querypath is a php library for manipulating xml and html.
# peoplesoft-app-engine,2,language,peoplecode is an object-oriented proprietary language used by oracle's peoplesoft applications.
# notorm,2,library,notorm is a php library for data access based on pdo.
# httperf,2,tool,httperf is a tool for measuring web server performance.
# cognos-tm1,2,tool,cognos tm1 is an in-memory multi-dimensional read/write online analytical processing (olap) tool which can be used for data warehousing budgeting and planning reporting or analysis of data.
# sqlsrv,2,extension,the sqlsrv is a php extension which allows you to access microsoft sql server and sql azure databases when running php on windows or linux.
# lucee,2,language,lucee is a light-weight dynamic scripting language for the jvm that enables the rapid development of simple to highly sophisticated web applications.
# agavi,2,framework,agavi is a scalable php mvc application framework that enables developers to create clean maintainable and extensible code for all kinds of applications (cli web soap etc.)
# symfony-routing,2,framework,symfony is a free open source php web application framework and it is released under the mit license.
# phpcrawl,2,framework,phpcrawl is a framework for crawling/spidering websites written in the programming language php.
# qbfc,2,library,the quickbooks foundation classes (qbfc) are a com library for interoping with quickbooks products from intuit software
# procobol,2,tool,pro*cobol is a programming tool that enables you to embed sql statements in a cobol program.
# cognos-8,2,tool,cognos version 8 is a reporting tool from ibm used widely for business intelligence.
# makumba,1,framework,makumba is a framework for creating scalable and robust data-driven web-applications.
# mpdf,1,library,mpdf is a php library for generating pdf files from html with unicode/utf-8 and cjk support.
# odp,1,extension,odp opendocument presentation is an extension of presentation files in open document format for office applications (odf).
# dbisam,1,database,dbisam is an embeddable relational database mainly geared to delphi and c++builder application developers.
# sqlmap,1,tool,sqlmap is an "automatic sql injection and database takeover tool".
# radphp,1,framework,embarcadero® radphp™ is a visual php framework and ide that supports web facebook® and mobile applications.
# philips-hue,1,system,philips hue is a personal wireless lighting system using lightbulbs with multi-colored leds.
# gora,1,framework,apache gora is an open source framework that provides an in-memory data model and persistence for big data.
# espn,1,platform,espn.com is an online platform for multiple sports news statistics team information and player information.
# bitbake,1,tool,bitbake is a simple tool for the execution of tasks.
# phpdocx,1,library,phpdocx is a php library designed to generate completely dynamic fully customizable and digitally signed word documents.
# sede,1,tool,stack exchange data explorer is a web tool for sharing querying and analyzing the creative commons data from every website in the stack exchange network.
# oracle-net-services,1,framework,oracle net services is oracle's networking framework.
# opentbs,1,tool,opentbs is a php tool that enables you to create ms office libreoffice and openoffice documents using templates.
# pmwiki,1,system,pmwiki is a wiki-based system written in php for collaborative creation and maintenance of websites.
# kiss-mvc,1,framework,kissmvc is a simple and minimalist php model-view-controller (mvc) framework for rapid development of web applications.
# lasso-lang,1,language,lasso is an interpreted programming language and server for developing database-driven web applications.
# semantic-mediawiki,1,extension,semantic mediawiki (smw) is a free open-source extension to mediawiki – the wiki software that powers wikipedia – that lets developer store and query data within the wiki's pages
# alfa,1,language,alfa the axiomatics language for authorization is a domain-specific language used to write fine-grained authorization policies which are then converted into xacml 3.0.
# dam,1,tool,digital asset management is a digital asset management tool that is fully integrated with the cq platform and enables your enterprise to share and distribute digital assets.
# hangout,1,platform,google hangouts is an instant messaging and video chat platform developed by google.
# getid3,1,library,getid3 is an open source php library that extracts useful information from mp3s and other multimedia file formats
# sas-ods,1,system,sas ods is the output delivery system for the sas language the method by which various formats of output (pdf html rtf etc.) are usually produced in sas.
# beanstalkc,1,library,beanstalkc is a simple python client library for beanstalkd a work queue daemon.
# rtml,1,language,rtml is the proprietary language used by yahoo for their ecommerce hosting services.
# leveldb,1,library,leveldb is a fast key-value storage library written at google that provides an ordered mapping from string keys to string values.
# foxyproxy,1,tool,foxyproxy is an advanced proxy management tool for firefox chorme and ie
# versant-vod,1,database,actian nosql (formerly versant object database) is an enterprise-grade nosql object database supporting massive concurrency and large data sets provided by actian corporation.
# pel,1,library,the php exif library (pel) is a library that will read and write the exif metadata headers found in jpeg and tiff images.
# objectscript,1,language,objectscript is a general purpose object-oriented programming language.
# fciv,1,utility,the file checksum integrity verifier (fciv) is a utility from microsoft for checking hashes of files.
