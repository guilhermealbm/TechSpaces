# %%
import pandas as pd
import networkx as nx
import community

import operator

# %%
df = pd.read_csv('../tags_with_wiki_relationship.csv')
df
# Out:
#                source           target  weight
# 0                  c#          decimal    3081
# 1                  c#           double    2895
# 2                  c#   floating-point    1946
# 3                  c#  type-conversion    4426
# 4             decimal           double     790
# ...               ...              ...     ...
# 936601       database       parcelable       3
# 936602     web-config  windows-phone-7       4
# 936603  drag-and-drop              lag      12
# 936604      animation           markup      14
# 936605       assembly    factorization       1
#
# [936606 rows x 3 columns]

# %%
df_wiki = pd.read_csv('../tags_with_wiki_and_category.csv', lineterminator='\n')
df_wiki
# Out:
#                       TagName  \
# 0                        java
# 1                       regex
# 2                         xml
# 3                       mysql
# 4                        nant
# ...                       ...
# 41778            minimal-apis
# 41779                  ix.net
# 41780        amazon-memory-db
# 41781           decomposition
# 41782  dasync.asyncenumerator
#
#                                                     Body      root
# 0      java is a high-level object oriented programmi...  language
# 1      Regular expressions provide a declarative lang...       NaN
# 2      xml (extensible markup language) is a structur...    format
# 3      mysql is a free open source relational databas...    system
# 4      nant is a build tool for .net aiming to suppor...      tool
# ...                                                  ...       ...
# 41778  Minimal APIs were introduced in ASP.NET Core 6...       NaN
# 41779  the interactive extensions (ix) is a .net libr...   library
# 41780  memorydb for redis is an in-memory database se...   service
# 41781  Decomposition might refer to Time Series Decom...       NaN
# 41782  dasync.asyncenumerator is a c# library that pr...   library
#
# [41783 rows x 3 columns]

# %%
node_attr = df_wiki.set_index('TagName').to_dict('index')

# %%
Graphtype = nx.Graph()
G = nx.from_pandas_edgelist(df, edge_attr='weight', create_using=Graphtype)
nx.set_node_attributes(G, node_attr)

# %%
G.nodes['c#']
# Out:
# {'Body': 'c# (pronounced "see sharp") is a high level statically typed multi-paradigm programming language developed by microsoft.',
#  'root': 'language'}

# %%
G['c#']
# Out:
# AtlasView({'decimal': {'weight': 3081}, 'double': {'weight': 2895}, 'floating-point': {'weight': 1946}, 'type-conversion': {'weight': 4426}, '.net': {'weight': 514411}, 'datetime': {'weight': 24448}, 'datediff': {'weight': 72}, 'time': {'weight': 2120}, '.net-3.5': {'weight': 10568}, 'linq': {'weight': 158582}, 'web-services': {'weight': 31988}, 'timer': {'weight': 9374}, 'vb.net': {'weight': 36617}, 'ascii': {'weight': 1249}, 'hex': {'weight': 1901}, 'sql': {'weight': 80169}, 'compression': {'weight': 2174}, 'file': {'weight': 13377}, 'html': {'weight': 36531}, 'printing': {'weight': 7362}, 'asp.net': {'weight': 441589}, 'globalization': {'weight': 1479}, 'internationalization': {'weight': 956}, 'compiler-construction': {'weight': 2529}, 'scripting': {'weight': 1282}, 'dictionary': {'weight': 16202}, 'sorting': {'weight': 10563}, 'data-binding': {'weight': 24387}, 'winforms': {'weight': 193103}, 'medium-trust': {'weight': 77}, 'int': {'weight': 2866}, 'integer': {'weight': 1220}, 'java': {'weight': 21277}, 'c++': {'weight': 27522}, 'random': {'weight': 5383}, 'versioning': {'weight': 593}, 'visual-studio': {'weight': 81548}, 'nunit': {'weight': 9696}, 'unit-testing': {'weight': 29895}, 'performance': {'weight': 19804}, 'reflection': {'weight': 27431}, 'types': {'weight': 7164}, 'left-join': {'weight': 547}, 'connection': {'weight': 1872}, 'database': {'weight': 28886}, 'loops': {'weight': 7653}, 'exception': {'weight': 17239}, 'exception-handling': {'weight': 8614}, 'adobe': {'weight': 275}, 'flash': {'weight': 1351}, 'macromedia': {'weight': 2}, 'file-locking': {'weight': 150}, 'safari': {'weight': 212}, 'viewstate': {'weight': 1462}, 'sockets': {'weight': 15888}, 'filelock': {'weight': 91}, 'io': {'weight': 3581}, 'dependency-properties': {'weight': 2831}, 'polymorphism': {'weight': 3002}, 'silverlight': {'weight': 25207}, 'wpf': {'weight': 251120}, 'error-handling': {'weight': 3747}, 'testing': {'weight': 4647}, 'mouse': {'weight': 1819}, 'winapi': {'weight': 10006}, 'artificial-intelligence': {'weight': 770}, 'image': {'weight': 18772}, 'image-processing': {'weight': 5764}, 'csv': {'weight': 8606}, 'import': {'weight': 1198}, 'asp.net-mvc': {'weight': 193589}, 'master-pages': {'weight': 2399}, 'bdd': {'weight': 686}, 'tdd': {'weight': 2237}, 'dataset': {'weight': 7640}, 'datatable': {'weight': 18941}, 'data-structures': {'weight': 3903}, 'binaryfiles': {'weight': 567}, 'struct': {'weight': 5247}, 'contextmenu': {'weight': 2507}, 'treeview': {'weight': 9470}, 'ado.net': {'weight': 15694}, 'colors': {'weight': 3387}, 'memory-management': {'weight': 3453}, 'picturebox': {'weight': 4661}, 'marshalling': {'weight': 4130}, 'getter': {'weight': 421}, 'setter': {'weight': 491}, 'path': {'weight': 2962}, 'language-design': {'weight': 503}, 'foreach': {'weight': 7488}, 'ienumerable': {'weight': 7270}, 'ienumerator': {'weight': 713}, 'directory': {'weight': 4344}, 'file-management': {'weight': 59}, 'javascript': {'weight': 67147}, 'onclick': {'weight': 859}, 'user-interface': {'weight': 9605}, 'registry': {'weight': 4200}, 'windows': {'weight': 39744}, 'profiler': {'weight': 340}, 'profiling': {'weight': 946}, 'configuration': {'weight': 4212}, 'properties': {'weight': 10228}, 'linq-to-sql': {'weight': 22557}, 'activemq': {'weight': 393}, 'messaging': {'weight': 570}, 'soa': {'weight': 457}, 'wcf': {'weight': 60659}, 'c#-2.0': {'weight': 2159}, 'namespaces': {'weight': 4421}, 'dns': {'weight': 1575}, 'reverse-dns': {'weight': 29}, 'browser': {'weight': 5163}, 'directx': {'weight': 2039}, 'button': {'weight': 7758}, 'assemblies': {'weight': 3132}, 'sharepoint': {'weight': 10513}, 'forms': {'weight': 13619}, 'postback': {'weight': 2318}, 'lambda': {'weight': 19887}, 'language-agnostic': {'weight': 503}, 'logic': {'weight': 1233}, 'request': {'weight': 1396}, 'patch': {'weight': 180}, 'backwards-compatibility': {'weight': 163}, 'controls': {'weight': 7970}, 'genealogy': {'weight': 21}, 'tree': {'weight': 1866}, 'events': {'weight': 198 ...

# %%
# Find modularity
part_1 = community.best_partition(G, random_state = 27)
mod_1 = community.modularity(part_1,G)

# %%
part_1['c#']
# Out:
# 0

# %%
number_of_comm_1 = max(part_1.items(), key=operator.itemgetter(1))[1] + 1
number_of_comm_1
# Out:
# 20

# %%
list_of_comm_1 = []
for i in range(number_of_comm_1):
    list_of_comm_1.append([k for k,v in part_1.items() if v == i])
    
list_of_comm_1[part_1['c#']]
# Out:
# ['c#',
#  '.net',
#  '.net-3.5',
#  'linq',
#  'web-services',
#  'datatable',
#  'timer',
#  'vb.net',
#  'architecture',
#  'com-interop',
#  'asp.net',
#  'sitemap',
#  'printing',
#  'globalization',
#  'generics',
#  'com',
#  'vb6',
#  'pocketpc',
#  'data-binding',
#  'winforms',
#  'pdf',
#  'unit-testing',
#  'medium-trust',
#  'exchange-server',
#  'visual-studio',
#  'lambda',
#  'active-directory',
#  'iis',
#  'nunit',
#  'legacy',
#  'oledb',
#  'visual-foxpro',
#  'reflection',
#  'installation',
#  'cruisecontrol.net',
#  'msbuild',
#  'documentation',
#  'sandcastle',
#  'xml-comments',
#  'localization',
#  'windows-server-2003',
#  'chm',
#  'winhelp',
#  'viewstate',
#  'nant',
#  'nhibernate',
#  'subsonic',
#  'windows-server-2008',
#  'dependency-properties',
#  'silverlight',
#  'wpf',
#  'projects-and-solutions',
#  'asp.net-mvc',
#  'datacontext',
#  'linq-to-sql',
#  'throttling',
#  'tdd',
#  'design-patterns',
#  'model-view-controller',
#  'mvp',
#  '.net-2.0',
#  'clr',
#  'web-controls',
#  'master-pages',
#  'interop',
#  'dataset',
#  'url-routing',
#  'asp.net-ajax',
#  'keyboard-shortcuts',
#  'visual-studio-2008',
#  'contextmenu',
#  'treeview',
#  'shortcuts',
#  'user-controls',
#  'ado.net',
#  'mono',
#  'picturebox',
#  'paging',
#  'marshalling',
#  'indexing-service',
#  'modi',
#  'dynamic-data',
#  'maintainability',
#  'inversion-of-control',
#  'sharepoint',
#  'settings',
#  'mbunit',
#  'teamcity',
#  'ienumerable',
#  'ienumerator',
#  'clickonce',
#  'event-viewer',
#  'controls',
#  'propertygrid',
#  'wmi',
#  'innerxml',
#  'xelement',
#  'visual-studio-2005',
#  'vdproj',
#  'wix',
#  'testdriven.net',
#  'properties',
#  'tfs',
#  'mocking',
#  'business-logic-layer',
#  'objectdatasource',
#  'soa',
#  'wcf',
#  'ironruby',
#  'wsdl',
#  't4',
#  'vsx',
#  'pinvoke',
#  'intellisense',
#  'c#-2.0',
#  'assemblies',
#  'remoting',
#  'postback',
#  'moss',
#  'wss',
#  'j#',
#  'asp.net-mvc-routing',
#  'nothing',
#  'n-tier-architecture',
#  'connection-string',
#  'scsf',
#  'cls-compliant',
#  'enumeration',
#  'covariance',
#  'configuration-files',
#  'asmx',
#  'asp.net-2.0',
#  'string.format',
#  'compact-framework',
#  'code-reuse',
#  'resources',
#  'skins',
#  'xna',
#  'extension-methods',
#  'enums',
#  'refactoring',
#  'linq-to-objects',
#  'xaml',
#  'ws-security',
#  'serialization',
#  'msdtc',
#  'binding',
#  'webforms',
#  'windows-services',
#  'interface',
#  'extensibility',
#  'html-helper',
#  'first-chance-exception',
#  'visual-studio-2003',
#  'f#',
#  'crystal-reports',
#  'entity-framework',
#  'visual-studio-2008-sp1',
#  'mdi',
#  'acrobat',
#  '.net-1.1',
#  'image-scanner',
#  'wia',
#  'hidden-features',
#  'enterprise-library',
#  'il',
#  'iis-7',
#  'ilmerge',
#  'datagrid',
#  'report',
#  'c++-cli',
#  'mixed-mode',
#  'directoryservices',
#  'design-decisions',
#  'foxpro',
#  'windows-ce',
#  'openxml',
#  'impersonation',
#  'linq-to-entities',
#  'outputcache',
#  'web-application-project',
#  'web-site-project',
#  'adam',
#  'azman',
#  'trace',
#  'ikvm',
#  'code-generation',
#  'workflow-foundation',
#  'attributes',
#  'twain',
#  'windows-installer',
#  'publish',
#  'sn.exe',
#  'strongname',
#  'health-monitoring',
#  'nlog',
#  'reflector',
#  'n2',
#  'repeater',
#  'dispose',
#  'virtualpathprovider',
#  'ironpython',
#  'xmldocument',
#  'dbnull',
#  'infopath',
#  'soap',
#  'reference-type',
#  'value-type',
#  'boxing',
#  'unboxing',
#  'system.drawing',
#  'multi-tenant',
#  'gridview',
#  'resharper',
#  '.net-1.0',
#  '.net-client-profile',
#  'add-in',
#  'dynamics-crm',
#  'combobox',
#  'dotnetnuke',
#  'pdf-generation',
#  'watin',
#  'vsto',
#  'infragistics',
#  'ultrawebgrid',
#  'csla',
#  'gdi+',
#  'ilist',
#  'web-deployment-project',
#  'styles',
#  'textbox',
#  'entity',
#  'wse',
#  'dotnetopenauth',
#  'reporting',
#  'typelib',
#  'identity',
#  'membership',
#  'silverlight-3.0',
#  'cmyk',
#  'listbox',
#  'activex',
#  'installshield',
#  'webbrowser-control',
#  'nvelocity',
#  'iis-6',
#  'entities',
#  'window-handles',
#  'viewdata',
#  'expression',
#  'tray',
#  'cassini',
#  'trayicon',
#  '.net-attributes',
#  'boo',
#  'configurationmanager',
#  'data-access',
#  'xml-serialization',
#  'cil',
#  'mstest',
#  'yellow-screen-of-death',
#  'reportviewer',
#  'reportviewer2008',
#  'rtf',
#  'code-access-security',
#  'ria',
#  'dcom',
#  'db4o',
#  'visual-web-developer',
#  'dependency-injection',
#  'com+',
#  'linq-to-xml',
#  'vb.net-to-c#',
#  'single-sign-on',
#  'ntlm',
#  'tfs-2005',
#  'intranet',
#  'duplex',
#  'updatepanel',
#  'formview',
#  'string-formatting',
#  'microsoft-dynamics',
#  'gac',
#  'castle-monorail',
#  'architectural-patterns',
#  'factory-method',
#  'strategy-pattern',
#  'asynchronous',
#  'workflow-activity',
#  'biztalk',
#  'biztalk2006r2',
#  'timeout',
#  'domain-driven-design',
#  'plugin-architecture',
#  'pdf-scraping',
#  'code-snippets',
#  'c#-3.0',
#  'xmlwriter',
#  'timespan',
#  'design-time',
#  'uitypeeditor',
#  'wcf-data-services',
#  'fxcop',
#  'managed-c++',
#  'playstation',
#  'factory',
#  'modalpopupextender',
#  'visual-studio-2010',
#  'code-analysis',
#  'tcptrace-pocketsoap',
#  'windows-server-2000',
#  'expression-studio',
#  'filesystemwatcher',
#  'faults',
#  'taskbar',
#  'codedom',
#  'office-addins',
#  'managed-code',
#  'system.net',
#  'visual-studio-express',
#  'openfiledialog',
#  'contravariance',
#  'embedded-resource',
#  'response.redirect',
#  'itemtemplate',
#  'mhtml',
#  'devexpress',
#  'xpo',
#  'castle-windsor',
#  'virtual-earth',
#  'novell',
#  'installutil',
#  'securityexception',
#  'datarowview',
#  'trust',
#  'moq',
#  'rhino-mocks',
#  'func',
#  'predicate',
#  'tabcontrol',
#  'msmq',
#  'observer-pattern',
#  'forms-authentication',
#  'custom-server-controls',
#  'app-config',
#  'radiobuttonlist',
#  'sharepoint-designer',
#  'ribbon',
#  'crm',
#  'elmah',
#  'toolkit',
#  'asp.net-membership',
#  'asp.net-1.1',
#  'behavior',
#  'gacutil',
#  'expression-trees',
#  'debuggervisualizer',
#  'task',
#  'client-applications',
#  'entity-framework-ctp5',
#  'lazy-loading',
#  'fax',
#  'perfmon',
#  'dbf',
#  'codeplex',
#  'unsafe',
#  'sql-server-ce',
#  'entity-sql',
#  'webclient',
#  'castle',
#  'spn',
#  'resx',
#  'treenode',
#  'class-library',
#  'filedialog',
#  'viewport3d',
#  'vb6-migration',
#  'tfs-migration',
#  'guid',
#  'opc',
#  'custom-action',
#  'units-of-measurement',
#  'ocx',
#  'rapi',
#  'self-hosting',
#  'type-inference',
#  'castle-activerecord',
#  'partial-methods',
#  'mef',
#  'point-of-sale',
#  'dynamic-language-runtime',
#  'web-reference',
#  'spring.net',
#  'kerberos',
#  'ncover',
#  'ndepend',
#  'nullable',
#  'idisposable',
#  'devforce',
#  'page-lifecycle',
#  'autocompleteextender',
#  'solution-explorer',
#  '.net-assembly',
#  'typemock',
#  'inno-setup',
#  'adobe-reader',
#  'config',
#  'type-constraints',
#  'memorystream',
#  'business-logic',
#  'windows-server',
#  'llblgenpro',
#  'using',
#  'duck-typing',
#  'datagridview',
#  'citrix',
#  'anonymous-types',
#  'webservice-client',
#  'hotkeys',
#  'visual-studio-addins',
#  'application-settings',
#  'cal',
#  'prism',
#  'animationextender',
#  'visual-inheritance',
#  'upgrade',
#  'metabase',
#  'navision',
#  'custom-controls',
#  'selectedindex',
#  'session-state',
#  'mysql-parameter',
#  'htmlbridge',
#  'xmldatasource',
#  'unmanaged',
#  'xml-documentation',
#  'mappoint',
#  'visual-studio-extensions',
#  'typeloadexception',
#  'nsis',
#  'desktop-application',
#  'workitem',
#  'solution',
#  'datatrigger',
#  'data-access-layer',
#  'wcsf',
#  'appsettings',
#  'system.configuration',
#  'html-encode',
#  'sspi',
#  'xpsdocument',
#  'suo',
#  'ajaxcontroltoolkit',
#  'microsoft.mshtml',
#  'coderush',
#  'web-config',
#  'performancecounter',
#  'mvvm',
#  'readonly',
#  'icloneable',
#  'wmp',
#  'windows-xp-embedded',
#  'modularity',
#  'brownfield',
#  'cab',
#  'design-principles',
#  'liskov-substitution-principle',
#  'solid-principles',
#  'form-control',
#  'tempdir',
#  'fluent-interface',
#  '.net-framework-version',
#  'obout',
#  'gallio',
#  'dropdownextender',
#  'ldap',
#  'qfe',
#  'stylecop',
#  '.net-3.0',
#  'ws-eventing',
#  'structuremap',
#  'system.diagnostics',
#  'httpcontext',
#  'servercontrols',
#  'event-log',
#  'eventlog-source',
#  'interface-segregation-principle',
#  'open-closed-principle',
#  'printdocument',
#  'pex',
#  'anonymous-methods',
#  'sharpdevelop',
#  'xmldataprovider',
#  'zedgraph',
#  'httpmodule',
#  'linq-to-nhibernate',
#  'sqlcommand',
#  'sqlconnection',
#  'expression-blend',
#  'design-by-contract',
#  'skype',
#  'uninstallation',
#  'xbox',
#  'tfs-workitem',
#  'assemblyinfo',
#  'xaf',
#  'tcplistener',
#  'dependency-inversion',
#  'principles',
#  'castle-dynamicproxy',
#  'notimplementedexception',
#  'managed',
#  'wmf',
#  'downgrade',
#  'jscript.net',
#  'global-asax',
#  'iis-5',
#  'mta',
#  'server-core',
#  'stateserver',
#  'xmlreader',
#  'monodevelop',
#  'datareader',
#  'edi',
#  'x12',
#  'axacropdf',
#  'printdialog',
#  'deepzoom',
#  'blogengine.net',
#  'proxy-classes',
#  'fluent',
#  'credentials',
#  'saas',
#  'business-objects',
#  'astoria',
#  'factory-pattern',
#  'static-classes',
#  'tlbexp',
#  'web-deployment',
#  'u2',
#  'universe',
#  'white-framework',
#  'chartfx',
#  'ultrawingrid',
#  'biztalk-2006',
#  'anti-patterns',
#  'officedev',
#  'iqueryable',
#  'siteminder',
#  'autopostback',
#  'partial-views',
#  'tfs-code-review',
#  'system-tray',
#  'systray',
#  'xbap',
#  'using-statement',
#  'value-objects',
#  'autosize',
#  'dbase',
#  'appbar',
#  'docking',
#  'full-trust',
#  'reflection.emit',
#  'groupbox',
#  'cups',
#  'c64',
#  'mshtml',
#  'umbraco',
#  'platform-builder',
#  'nhibernate-mapping',
#  'vsta',
#  'postscript',
#  'provider',
#  'generic-constraints',
#  'designer',
#  'alt.net',
#  'poppler',
#  'gtk#',
#  'dynamics-crm-4',
#  'code-duplication',
#  'logparser',
#  'mtom',
#  'routed-events',
#  '.nettiers',
#  'sap',
#  'actualwidth',
#  'mru',
#  'backgroundworker',
#  'ironspeed',
#  'single-responsibility-principle',
#  'log4net',
#  'branding',
#  'worker-process',
#  'adsi',
#  'al.exe',
#  'mvcroutehandler',
#  'aero',
#  'tapi',
#  'ajax.net',
#  'selectedindexchanged',
#  'dotnetnuke-module',
#  'webrequest',
#  'viemu',
#  'visual-assist',
#  'datarepeater',
#  'baml',
#  'setup-project',
#  'app-code',
#  'converter',
#  'appdomain',
#  'facade',
#  'imposition',
#  'dataview',
#  'icomparable',
#  'code-metrics',
#  'culture',
#  'sqldependency',
#  'printer-control-language',
#  'license-key',
#  'primary-interop-assembly',
#  'sqldatareader',
#  'ldap-query',
#  'pdfa',
#  'robohelp',
#  'drawstring',
#  'xunit',
#  'postsharp',
#  'stopwatch',
#  'scintilla',
#  'dbml',
#  'windows-forms-designer',
#  'selecteditem',
#  'scriptmanager',
#  'finalbuilder',
#  'windows-authentication',
#  'sharepoint-2007',
#  'access-modifiers',
#  'oledbconnection',
#  'validationrules',
#  'windows-mobile-5.0',
#  'shdocvw',
#  'datalist',
#  'console-application',
#  'messagebox',
#  'tfsbuild',
#  'wise',
#  'ngen',
#  'masstransit',
#  'nservicebus',
#  'cyclomatic-complexity',
#  'code-behind',
#  'directoryinfo',
#  'getdirectories',
#  'dynamic-compilation',
#  'monthcalendar',
#  'documentation-generation',
#  'farseer',
#  'repository-pattern',
#  'httphandler',
#  'adfs',
#  'rdlc',
#  'detailsview',
#  'sitecore',
#  'regtlib',
#  'microsoft-bits',
#  'command-pattern',
#  'table-driven',
#  'blend',
#  'padleft',
#  'remoteapp',
#  'immediate-window',
#  'json.net',
#  'internalsvisibleto',
#  'wndproc',
#  'unity-container',
#  'publishing',
#  'scaffolding',
#  'aspnet-regiis.exe',
#  'bdc',
#  'fluent-nhibernate',
#  'isolatedstorage',
#  'helpfile',
#  'maml',
#  'server.mappath',
#  '.sbr',
#  'legacy-code',
#  '.net-micro-framework',
#  'code-conversion',
#  'networkstream',
#  'http-status-code-401',
#  'localreport',
#  'datarow',
#  'codesmith',
#  'strong-typing',
#  'outlining',
#  'statusstrip',
#  'unshelve',
#  'virtual-directory',
#  'user32',
#  'etw',
#  'xbox360',
#  'xunit.net',
#  'project-server',
#  'wcf-routing',
#  'static-constructor',
#  'asp.net-routing',
#  'application-start',
#  'prerequisites',
#  'mmc',
#  'mmc3',
#  'zebra-printers',
#  'html-agility-pack',
#  'imaging',
#  'int32',
#  'ushort',
#  'findcontrol',
#  'reusability',
#  'configurationsection',
#  'asp.net-profiles',
#  'poeaa',
#  'episerver',
#  'ui-virtualization',
#  'aspmenu',
#  'uddi',
#  'apartments',
#  'calendarextender',
#  'nhaml',
#  'customvalidator',
#  'silverlight-2.0',
#  'magicknet',
#  'ektron',
#  'adonetappender',
#  'webtest',
#  'snk',
#  'wse2.0',
#  'rad-controls',
#  'telerik',
#  'cqwp',
#  'thread-static',
#  'custom-errors',
#  'sqlmetal',
#  'isam',
#  'asp.net-mvc-migration',
#  'microsoft-sync-framework',
#  'occasionallyconnected',
#  '3-tier',
#  'superpreview',
#  'datatemplate',
#  'code-cleanup',
#  'sgen',
#  'textblock',
#  'envdte',
#  'processmodel',
#  'console.writeline',
#  'mdiparent',
#  'sqldatasource',
#  'krypton-toolkit',
#  'validationsummary',
#  'wix3',
#  'starter-kits',
#  'late-binding',
#  'rightnow-crm',
#  'saleslogix',
#  'file-conversion',
#  'dynamics-gp',
#  'linkbutton',
#  'linklabel',
#  'timtowtdi',
#  'soap-extension',
#  'invoke',
#  'membership-provider',
#  'xna-3.0',
#  'zune',
#  'toolstrip',
#  'k2',
#  'runtime-compilation',
#  'event-based-programming',
#  'object-initializers',
#  'desktop-shortcut',
#  'bpel',
#  'basic',
#  'richtext',
#  'webinvoke',
#  'asp.net-3.5',
#  'regasm',
#  'compiler-directives',
#  'securestring',
#  'currentculture',
#  'bindinglist',
#  'generic-list',
#  '.net-4.0',
#  'permissionset',
#  'ioc-container',
#  'event-driven',
#  'savefiledialog',
#  'transactionscope',
#  'smartclient',
#  'mediaelement',
#  'exchangewebservices',
#  'actionlink',
#  'onpaint',
#  'disposable',
#  'finalizer',
#  'suppressfinalize',
#  'multi-tier',
#  'application-state',
#  'cop',
#  'oslo',
#  'wse3.0',
#  'ashx',
#  'ax',
#  'axapta',
#  'x++',
#  '.emf',
#  'farpoint-spread',
#  'office-interop',
#  'panel',
#  'word-automation',
#  'autoresetevent',
#  'manualresetevent',
#  'powercommands',
#  'richtextbox',
#  'dllimport',
#  'side-by-side',
#  'sharpziplib',
#  'xmltextwriter',
#  'tablelayoutpanel',
#  'file-access',
#  'resource-files',
#  'ascx',
#  'orca',
#  'oledbexception',
#  'mdichild',
#  'custom-attributes',
#  'community-server',
#  'numericupdown',
#  'csproj',
#  'application-pool',
#  'dispatcher',
#  'expander',
#  'scrollviewer',
#  'httpexception',
#  'law-of-demeter',
#  'sqlmembershipprovider',
#  'partial-classes',
#  'itemscontrol',
#  'idictionary',
#  '.refresh',
#  'iprincipal',
#  'mailaddress',
#  'dispatchertimer',
#  'eula',
#  'sta',
#  'collectioneditor',
#  'base-class-library',
#  'pia',
#  'updatepanelanimationexte',
#  'basichttpbinding',
#  'template-method-pattern',
#  'asp.net-dynamic-data',
#  'httpwebrequest',
#  'autocad',
#  'cad',
#  'dwg',
#  'change-tracking',
#  'aero-glass',
#  'razor',
#  'kofax',
#  'windows-media-player',
#  'visitor-pattern',
#  'datacontract',
#  'system.data.sqlite',
#  'invalidoperationexception',
#  'ghostdoc',
#  'itext',
#  'tagged-pdf',
#  'software-design',
#  'caml',
#  'flowdocument',
#  'eventtrigger',
#  'multidatatrigger',
#  'routedevent',
#  'composite-controls',
#  'abcpdf',
#  'asplinkbutton',
#  'gridviewcolumn',
#  'ddd-repositories',
#  'bootstrapper',
#  'menustrip',
#  'syncfusion',
#  'ieditableobject',
#  'strongly-typed-dataset',
#  'econnect',
#  'databound',
#  'report-designer',
#  'process.start',
#  'nullreferenceexception',
#  'sqlparameter',
#  'thermal-printer',
#  'bulletedlist',
#  'uielement',
#  'separation-of-concerns',
#  'documentviewer',
#  'xps',
#  'custom-error-pages',
#  'dynamic-linq',
#  'endpoint',
#  'routed-commands',
#  'system.xml',
#  'naudio',
#  'w3wp',
#  'controltemplate',
#  'z-order',
#  'bitmapsource',
#  'mono-service',
#  'access-synchronization',
#  'tfs-process-template',
#  'ref',
#  'observablecollection',
#  'outlook-object-model',
#  'sdf',
#  'fileinfo',
#  'xtragrid',
#  'eventargs',
#  'antixsslibrary',
#  'filestream',
#  'wcftestclient',
#  'savechanges',
#  'ws-addressing',
#  'activereports',
#  'icriteria',
#  'params-keyword',
#  'iis-manager',
#  'contentplaceholder',
#  'dotimage',
#  'nemerle',
#  'notifyicon',
#  'chain-of-responsibility',
#  'option-strict',
#  'dataformat',
#  'xfa',
#  'requiredfieldvalidator',
#  'enumerator',
#  'fusion',
#  'clr-profiling-api',
#  'merge-module',
#  'version-compatibility',
#  'special-folders',
#  'typeconverter',
#  'spweb',
#  'checkboxlist',
#  'sqlclient',
#  'sqlcommandbuilder',
#  'clr-hosting',
#  'login-control',
#  'resourcemanager',
#  'poco',
#  'componentone',
#  'tcpclient',
#  'tabitem',
#  'script#',
#  'bad-request',
#  'configsection',
#  'ibatis.net',
#  'fiddler',
#  'cider',
#  'activesync',
#  'soap-client',
#  'submitchanges',
#  'setup.exe',
#  '.net-core',
#  'activator',
#  'missingmethodexception',
#  'memento',
#  'table-per-type',
#  'wcf-binding',
#  'spsite',
#  'design-view',
#  'hresult',
#  'httplistener',
#  'ownerdrawn',
#  'getmethod',
#  'namevaluecollection',
#  'programmers-notepad',
#  'domaincontroller',
#  'comexception',
#  'application-design',
#  'msbuild-task',
#  'ghostscript',
#  'fileopendialog',
#  'toolbox',
#  'dynamics-sl',
#  'expression-web',
#  'common.logging',
#  'xsp',
#  'system.drawing.color',
#  'act',
#  'wbxml',
#  'build-server',
#  'dmz',
#  ...]

# %%
G_1 = G.subgraph(list_of_comm_1[part_1['c#']])

# %%
G_1.edges
# Out:
# EdgeView([('checkboxlist', 'asp.net-mvc'), ('checkboxlist', '.net'), ('checkboxlist', 'c#'), ('checkboxlist', 'asp.net'), ('checkboxlist', 'user-controls'), ('checkboxlist', 'updatepanel'), ('checkboxlist', '.net-3.5'), ('checkboxlist', 'formview'), ('checkboxlist', 'objectdatasource'), ('checkboxlist', 'viewstate'), ('checkboxlist', 'binding'), ('checkboxlist', 'data-binding'), ('checkboxlist', 'linq'), ('checkboxlist', 'properties'), ('checkboxlist', 'asp.net-3.5'), ('checkboxlist', 'postback'), ('checkboxlist', 'vb.net'), ('checkboxlist', 'controls'), ('checkboxlist', 'radiobuttonlist'), ('checkboxlist', 'webforms'), ('checkboxlist', 'linq-to-sql'), ('checkboxlist', 'dotnetnuke'), ('checkboxlist', 'customvalidator'), ('checkboxlist', 'nullreferenceexception'), ('checkboxlist', 'panel'), ('checkboxlist', 'mvccontrib'), ('checkboxlist', 'linkbutton'), ('checkboxlist', 'asp.net-mvc-2'), ('checkboxlist', 'model-binding'), ('checkboxlist', 'selecteditem'), ('checkboxlist', 'linq-to-entities'), ('checkboxlist', 'winforms'), ('checkboxlist', 'silverlight'), ('checkboxlist', 'gridview'), ('checkboxlist', 'popupcontrolextender'), ('checkboxlist', 'textbox'), ('checkboxlist', 'asp.net-mvc-3'), ('checkboxlist', 'datalist'), ('checkboxlist', 'autopostback'), ('checkboxlist', 'listbox'), ('checkboxlist', 'c#-4.0'), ('checkboxlist', 'sqlcommand'), ('checkboxlist', 'wpf'), ('checkboxlist', 'crm'), ('checkboxlist', 'dynamics-crm'), ('checkboxlist', 'treeview'), ('checkboxlist', 'checkedlistbox'), ('checkboxlist', 'linq-to-objects'), ('checkboxlist', 'model-view-controller'), ('checkboxlist', 'repeater'), ('checkboxlist', 'obout'), ('checkboxlist', 'htmltextwriter'), ('checkboxlist', 'c#-2.0'), ('checkboxlist', 'custom-controls'), ('checkboxlist', 'custom-server-controls'), ('checkboxlist', 'asp.net-roles'), ('checkboxlist', 'visual-studio-2008'), ('checkboxlist', 'styles'), ('checkboxlist', 'windows-phone-7'), ('checkboxlist', 'xaml'), ('wbxml', 'exchange-server'), ('wbxml', 'c#'), ('wbxml', 'activesync'), ('custom-action-filter', 'asp.net-mvc'), ('custom-action-filter', 'outputcache'), ('custom-action-filter', 'c#'), ('custom-action-filter', 'dependency-injection'), ('custom-action-filter', 'ninject'), ('custom-action-filter', 'asp.net-mvc-3'), ('custom-action-filter', 'model-binding'), ('custom-action-filter', 'tempdata'), ('dynamicobject', '.net'), ('dynamicobject', 'c#-4.0'), ('dynamicobject', 'data-binding'), ('dynamicobject', 'datagrid'), ('dynamicobject', 'wpf'), ('dynamicobject', 'expandoobject'), ('dynamicobject', 'c#'), ('dynamicobject', 'entity-framework-4'), ('dynamicobject', 'dynamic-language-runtime'), ('dynamicobject', 'ironpython'), ('dynamicobject', 'dynamic-class-creation'), ('dynamicobject', 'generics'), ('dynamicobject', 'datagridview'), ('dynamicobject', 'reflection'), ('dynamicobject', 'dynamic-proxy'), ('dynamicobject', 'office-interop'), ('entity-framework-4.1', 'entity-framework'), ('entity-framework-4.1', '.net'), ('entity-framework-4.1', 'asp.net-mvc-3'), ('entity-framework-4.1', 'ef-code-first'), ('entity-framework-4.1', 'code-first'), ('entity-framework-4.1', 'entity-framework-4'), ('entity-framework-4.1', 'entity-framework-ctp5'), ('entity-framework-4.1', 'nuget'), ('entity-framework-4.1', 'sql-server-ce'), ('entity-framework-4.1', 'sql-server-ce-4'), ('entity-framework-4.1', 'ado.net'), ('entity-framework-4.1', 'c#'), ('entity-framework-4.1', 'change-tracking'), ('entity-framework-4.1', 'repository-pattern'), ('entity-framework-4.1', 'f#'), ('entity-framework-4.1', 'castle-windsor'), ('entity-framework-4.1', 'inversion-of-control'), ('entity-framework-4.1', 'poco'), ('entity-framework-4.1', 'unit-of-work'), ('entity-framework-4.1', 'expression-trees'), ('entity-framework-4.1', 'reflection'), ('entity-framework-4.1', 'nullreferenceexception'), ('entity-framework-4.1', 'automapper'), ('entity-framework-4.1', 'fluent-interface'), ('entity-framework-4.1', 'asp.net-mvc'), ('entity-framework-4.1', 'eager-loading'), ...

# %%
part_2 = community.best_partition(G_1)
mod_2 = community.modularity(part_2,G_1)

# %%
sorted(G_1.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('c#', 2395),
#  ('.net', 2097),
#  ('asp.net', 1478),
#  ('vb.net', 1081),
#  ('wpf', 951),
#  ('visual-studio-2010', 892),
#  ('asp.net-mvc', 881),
#  ('visual-studio', 880),
#  ('silverlight', 797),
#  ('wcf', 783),
#  ('winforms', 773),
#  ('visual-studio-2008', 735),
#  ('.net-4.0', 673),
#  ('.net-3.5', 639),
#  ('c#-4.0', 638),
#  ('web-services', 617),
#  ('asp.net-mvc-3', 588),
#  ('linq', 558),
#  ('unit-testing', 540),
#  ('asp.net-mvc-2', 523),
#  ('iis', 473),
#  ('entity-framework', 449),
#  ('silverlight-4.0', 438),
#  ('data-binding', 435),
#  ('sharepoint', 428),
#  ('nhibernate', 413),
#  ('linq-to-sql', 409),
#  ('xaml', 388),
#  ('reflection', 371),
#  ('design-patterns', 366),
#  ('architecture', 366),
#  ('windows-phone-7', 361),
#  ('binding', 360),
#  ('model-view-controller', 359),
#  ('mvvm', 356),
#  ('generics', 355),
#  ('.net-2.0', 354),
#  ('iis-7', 348),
#  ('c#-3.0', 344),
#  ('serialization', 338),
#  ('installation', 334),
#  ('com', 332),
#  ('mono', 331),
#  ('user-controls', 330),
#  ('controls', 328),
#  ('webforms', 311),
#  ('properties', 309),
#  ('web-config', 299),
#  ('azure', 295),
#  ('msbuild', 295),
#  ('visual-studio-2005', 292),
#  ('assemblies', 290),
#  ('entity-framework-4', 290),
#  ('interface', 288),
#  ('windows-services', 287),
#  ('ado.net', 283),
#  ('f#', 282),
#  ('vb6', 281),
#  ('gridview', 281),
#  ('dependency-injection', 277),
#  ('asynchronous', 274),
#  ('localization', 267),
#  ('resources', 262),
#  ('datagrid', 262),
#  ('compact-framework', 255),
#  ('interop', 255),
#  ('sharepoint-2010', 253),
#  ('iis-6', 251),
#  ('nunit', 249),
#  ('pdf', 248),
#  ('tfs', 248),
#  ('attributes', 241),
#  ('textbox', 240),
#  ('combobox', 239),
#  ('soap', 232),
#  ('razor', 222),
#  ('telerik', 220),
#  ('enums', 213),
#  ('datagridview', 210),
#  ('windows-installer', 209),
#  ('treeview', 209),
#  ('dataset', 209),
#  ('listbox', 209),
#  ('printing', 208),
#  ('active-directory', 208),
#  ('c#-2.0', 208),
#  ('lambda', 204),
#  ('silverlight-3.0', 202),
#  ('asp.net-ajax', 201),
#  ('c++-cli', 201),
#  ('datatable', 200),
#  ('extension-methods', 197),
#  ('asp.net-membership', 197),
#  ('clr', 196),
#  ('sharepoint-2007', 193),
#  ('custom-controls', 191),
#  ('domain-driven-design', 191),
#  ('asp.net-3.5', 191),
#  ('code-generation', 189),
#  ('xml-serialization', 187),
#  ('tdd', 186),
#  ('ninject', 184),
#  ('windows-server-2008', 183),
#  ('mef', 182),
#  ('fluent-nhibernate', 182),
#  ('wpf-controls', 180),
#  ('wcf-ria-services', 180),
#  ('mocking', 180),
#  ('linq-to-entities', 178),
#  ('inversion-of-control', 178),
#  ('resharper', 176),
#  ('entity', 175),
#  ('prism', 174),
#  ('moq', 173),
#  ('viewmodel', 172),
#  ('asmx', 172),
#  ('sql-server-ce', 172),
#  ('ienumerable', 172),
#  ('refactoring', 171),
#  ('log4net', 171),
#  ('iis-7.5', 171),
#  ('asp.net-2.0', 170),
#  ('devexpress', 169),
#  ('timeout', 168),
#  ('clickonce', 167),
#  ('unity-container', 167),
#  ('crystal-reports', 165),
#  ('enterprise-library', 165),
#  ('nullreferenceexception', 165),
#  ('httpwebrequest', 165),
#  ('castle-windsor', 164),
#  ('activex', 162),
#  ('app-config', 162),
#  ('asp.net-4.0', 162),
#  ('connection-string', 162),
#  ('wix', 161),
#  ('datacontext', 158),
#  ('intellisense', 155),
#  ('entity-framework-4.1', 153),
#  ('mstest', 153),
#  ('linq-to-xml', 150),
#  ('forms-authentication', 150),
#  ('gac', 149),
#  ('styles', 147),
#  ('xna', 147),
#  ('poco', 147),
#  ('console-application', 147),
#  ('dispose', 146),
#  ('timer', 145),
#  ('contextmenu', 145),
#  ('data-access-layer', 145),
#  ('repository-pattern', 145),
#  ('code-behind', 145),
#  ('structuremap', 144),
#  ('com-interop', 142),
#  ('add-in', 142),
#  ('lazy-loading', 141),
#  ('settings', 140),
#  ('wsdl', 139),
#  ('ioc-container', 139),
#  ('nant', 138),
#  ('appdomain', 138),
#  ('master-pages', 136),
#  ('automapper', 136),
#  ('xamarin.ios', 135),
#  ('impersonation', 134),
#  ('backgroundworker', 134),
#  ('subsonic', 134),
#  ('pinvoke', 133),
#  ('documentation', 132),
#  ('dotnetnuke', 132),
#  ('postback', 131),
#  ('windows-server-2003', 130),
#  ('ironpython', 130),
#  ('reporting', 130),
#  ('wcf-data-services', 130),
#  ('observablecollection', 129),
#  ('t4', 128),
#  ('rhino-mocks', 128),
#  ('windows-authentication', 128),
#  ('data-annotations', 127),
#  ('guid', 127),
#  ('ria', 126),
#  ('idisposable', 126),
#  ('teamcity', 123),
#  ('vsto', 123),
#  ('report', 122),
#  ('datatemplate', 122),
#  ('soa', 122),
#  ('designer', 121),
#  ('upgrade', 120),
#  ('mvvm-light', 120),
#  ('ldap', 120),
#  ('projects-and-solutions', 120),
#  ('wmi', 120),
#  ('biztalk', 119),
#  ('mvp', 119),
#  ('cruisecontrol.net', 118),
#  ('configuration-files', 117),
#  ('msmq', 117),
#  ('nullable', 116),
#  ('richtextbox', 116),
#  ('httpcontext', 116),
#  ('pdf-generation', 116),
#  ('httphandler', 114),
#  ('embedded-resource', 114),
#  ('workflow-foundation', 114),
#  ('windows-ce', 114),
#  ('wcf-binding', 114),
#  ('n-tier-architecture', 112),
#  ('odata', 112),
#  ('webbrowser-control', 112),
#  ('wcf-security', 112),
#  ('updatepanel', 112),
#  ('expression', 111),
#  ('tabcontrol', 111),
#  ('readonly', 111),
#  ('viewstate', 109),
#  ('webclient', 109),
#  ('.net-1.1', 107),
#  ('paging', 107),
#  ('dependency-properties', 107),
#  ('session-state', 107),
#  ('class-library', 105),
#  ('expression-blend', 105),
#  ('inotifypropertychanged', 105),
#  ('tfsbuild', 105),
#  ('workflow-foundation-4', 104),
#  ('moss', 104),
#  ('gdi+', 103),
#  ('ajaxcontroltoolkit', 103),
#  ('unmanaged', 102),
#  ('html-helper', 102),
#  ('reportviewer', 102),
#  ('global-asax', 102),
#  ('iqueryable', 102),
#  ('nservicebus', 101),
#  ('ef-code-first', 101),
#  ('single-sign-on', 101),
#  ('dynamic-data', 101),
#  ('remoting', 101),
#  ('spring.net', 101),
#  ('task', 101),
#  ('monodevelop', 100),
#  ('sitecore', 100),
#  ('identity', 100),
#  ('oledb', 99),
#  ('dto', 98),
#  ('objectdatasource', 98),
#  ('setup-project', 98),
#  ('anonymous-types', 98),
#  ('repeater', 97),
#  ('panel', 97),
#  ('filestream', 97),
#  ('desktop-application', 96),
#  ('windows-server-2008-r2', 96),
#  ('credentials', 96),
#  ('exchange-server', 95),
#  ('autofac', 94),
#  ('wcf-client', 93),
#  ('system.reactive', 92),
#  ('task-parallel-library', 92),
#  ('fiddler', 90),
#  ('globalization', 90),
#  ('controltemplate', 90),
#  ('url-routing', 90),
#  ('umbraco', 90),
#  ('httpmodule', 90),
#  ('web-controls', 89),
#  ('expression-trees', 89),
#  ('dynamics-crm', 89),
#  ('trace', 89),
#  ('asp.net-mvc-routing', 88),
#  ('linq-to-objects', 88),
#  ('custom-attributes', 88),
#  ('keyboard-shortcuts', 88),
#  ('publish', 87),
#  ('using', 87),
#  ('fxcop', 87),
#  ('publishing', 87),
#  ('isolatedstorage', 86),
#  ('infragistics', 85),
#  ('elmah', 85),
#  ('membership-provider', 85),
#  ('json.net', 85),
#  ('config', 85),
#  ('silverlight-2.0', 85),
#  ('wpfdatagrid', 85),
#  ('nuget', 85),
#  ('subsonic3', 85),
#  ('factory', 84),
#  ('.net-assembly', 84),
#  ('wpftoolkit', 84),
#  ('ribbon', 83),
#  ('watin', 83),
#  ('event-log', 83),
#  ('resx', 83),
#  ('marshalling', 82),
#  ('castle', 82),
#  ('visual-studio-2008-sp1', 82),
#  ('code-first', 81),
#  ('application-settings', 81),
#  ('partial-views', 81),
#  ('web-deployment-project', 81),
#  ('memorystream', 80),
#  ('invoke', 80),
#  ('business-logic', 80),
#  ('code-analysis', 80),
#  ('datacontract', 80),
#  ('installshield', 79),
#  ('datacontractserializer', 79),
#  ('membership', 79),
#  ('appfabric', 78),
#  ('itemscontrol', 78),
#  ('nhibernate-mapping', 78),
#  ('visual-studio-express', 78),
#  ('caliburn.micro', 78),
#  ('messagebox', 77),
#  ('generic-list', 77),
#  ('extensibility', 77),
#  ('nlog', 77),
#  ('xmldocument', 77),
#  ('reflection.emit', 76),
#  ('s#arp-architecture', 76),
#  ('provider', 76),
#  ('itextsharp', 75),
#  ('separation-of-concerns', 75),
#  ('xbap', 74),
#  ('behavior', 74),
#  ('silverlight-toolkit', 74),
#  ('strong-typing', 74),
#  ('rtf', 73),
#  ('string-formatting', 73),
#  ('enumeration', 73),
#  ('propertygrid', 73),
#  ('windows-forms-designer', 73),
#  ('business-objects', 73),
#  ('office-interop', 73),
#  ('culture', 72),
#  ('partial-classes', 72),
#  ('sitemap', 72),
#  ('codedom', 72),
#  ('data-access', 72),
#  ('strongly-typed-dataset', 71),
#  ('wif', 71),
#  ('transactionscope', 71),
#  ('model-binding', 71),
#  ('openxml', 71),
#  ('managed', 71),
#  ('webservice-client', 71),
#  ('dllimport', 71),
#  ('dispatcher', 70),
#  ('cil', 70),
#  ('inno-setup', 70),
#  ('azure-sql-database', 70),
#  ('deserialization', 70),
#  ('uninstallation', 70),
#  ('legacy', 70),
#  ('unit-of-work', 70),
#  ('application-pool', 70),
#  ('web-deployment', 69),
#  ('rdlc', 69),
#  ('cassini', 69),
#  ('radgrid', 69),
#  ('invalidoperationexception', 69),
#  ('postsharp', 68),
#  ('xmlserializer', 68),
#  ('iis-5', 68),
#  ('ascx', 68),
#  ('sqldatasource', 68),
#  ('converter', 67),
#  ('code-reuse', 67),
#  ('ntlm', 67),
#  ('setup-deployment', 67),
#  ('strongname', 66),
#  ('castle-activerecord', 66),
#  ('system.drawing', 66),
#  ('selecteditem', 65),
#  ('solution', 65),
#  ('sqlconnection', 65),
#  ('webrequest', 65),
#  ('dotnetopenauth', 65),
#  ('outputcache', 65),
#  ('dynamics-crm-2011', 65),
#  ('wix3.5', 64),
#  ('code-contracts', 64),
#  ('code-access-security', 64),
#  ('streamreader', 64),
#  ('windows-phone-7.1', 64),
#  ('msbuild-task', 64),
#  ('nettcpbinding', 64),
#  ('fluent', 64),
#  ('mvccontrib', 64),
#  ('ado.net-entity-data-model', 64),
#  ('ilist', 63),
#  ('factory-pattern', 63),
#  ('visual-studio-addins', 63),
#  ('medium-trust', 63),
#  ('visual-studio-2003', 63),
#  ('scrollviewer', 63),
#  ('custom-action', 63),
#  ('vsx', 62),
#  ('resourcedictionary', 62),
#  ('itemtemplate', 62),
#  ('wss', 62),
#  ('decoupling', 62),
#  ('objectcontext', 62),
#  ('custom-server-controls', 62),
#  ('webmatrix', 62),
#  ('design-time', 62),
#  ('reusability', 61),
#  ('kerberos', 61),
#  ('checkboxlist', 60),
#  ('iis-express', 60),
#  ('infopath', 60),
#  ('windows-phone', 60),
#  ('datatrigger', 60),
#  ('dataview', 60),
#  ('securityexception', 60),
#  ('openfiledialog', 60),
#  ('textblock', 60),
#  ('virtual-directory', 60),
#  ('orchardcms', 59),
#  ('datareader', 59),
#  ('entities', 59),
#  ('uielement', 59),
#  ('datalist', 59),
#  ('page-lifecycle', 59),
#  ('linq-to-nhibernate', 59),
#  ('sap', 59),
#  ('system.diagnostics', 59),
#  ('com+', 59),
#  ('appsettings', 58),
#  ('cab', 58),
#  ('toolkit', 58),
#  ('xelement', 58),
#  ('ivalueconverter', 57),
#  ('xunit.net', 57),
#  ('edmx', 57),
#  ('outlook-addin', 57),
#  ('legacy-code', 57),
#  ('bindingsource', 57),
#  ('telerik-grid', 57),
#  ('ilmerge', 56),
#  ('scriptmanager', 56),
#  ('formview', 56),
#  ('fluent-interface', 56),
#  ('taskbar', 56),
#  ('access-denied', 56),
#  ('http-status-code-401', 56),
#  ('wix3', 56),
#  ('exchangewebservices', 55),
#  ('ashx', 55),
#  ('managed-c++', 55),
#  ('nsis', 55),
#  ('datarow', 55),
#  ('entity-framework-ctp5', 55),
#  ('detailsview', 55),
#  ('ironruby', 55),
#  ('multi-tenant', 55),
#  ('attached-properties', 54),
#  ('roleprovider', 54),
#  ('ddd-repositories', 54),
#  ('unhandled-exception', 54),
#  ('dynamic-language-runtime', 54),
#  ('asp.net-mvc-areas', 54),
#  ('sqldatareader', 54),
#  ('domain-model', 53),
#  ('svcutil.exe', 53),
#  ('domainservices', 53),
#  ('performancecounter', 53),
#  ('ninject-2', 53),
#  ('cultureinfo', 53),
#  ('endpoint', 53),
#  ('auto-generate', 53),
#  ('azure-storage', 53),
#  ('visual-web-developer', 53),
#  ('proxy-classes', 53),
#  ('tableadapter', 53),
#  ('xmlreader', 53),
#  ('windows-8', 52),
#  ('hotkeys', 52),
#  ('csla', 52),
#  ('bootstrapper', 52),
#  ('foxpro', 52),
#  ('service-reference', 52),
#  ('scaffolding', 52),
#  ('modalpopupextender', 51),
#  ('mschart', 51),
#  ('msdeploy', 51),
#  ('protobuf-net', 51),
#  ('stackpanel', 51),
#  ('xml-deserialization', 51),
#  ('visual-studio-debugging', 51),
#  ('bitmapimage', 51),
#  ('db4o', 50),
#  ('mbunit', 50),
#  ('value-type', 50),
#  ('sharpdevelop', 50),
#  ('configurationmanager', 50),
#  ('service-layer', 50),
#  ('system.data.sqlite', 50),
#  ('ravendb', 50),
#  ('predicate', 50),
#  ('vb6-migration', 50),
#  ('directoryservices', 50),
#  ('crm', 50),
#  ('observer-pattern', 49),
#  ('picturebox', 49),
#  ('bing-maps', 49),
#  ('software-design', 49),
#  ('asp.net-routing', 49),
#  ('anonymous-methods', 49),
#  ('visual-foxpro', 49),
#  ('3-tier', 49),
#  ('linqpad', 48),
#  ('csproj', 48),
#  ('wss-3.0', 48),
#  ('blend', 48),
#  ('basichttpbinding', 48),
#  ('using-statement', 48),
#  ('spark-view-engine', 48),
#  ('saas', 48),
#  ('sqlmembershipprovider', 48),
#  ('databound', 48),
#  ('documentation-generation', 48),
#  ('wcf-rest', 48),
#  ('eager-loading', 47),
#  ('webmethod', 47),
#  ('httpwebresponse', 47),
#  ('moles', 47),
#  ('listboxitem', 47),
#  ('func', 47),
#  ('sandcastle', 47),
#  ('reflector', 47),
#  ('quartz.net', 46),
#  ('flowdocument', 46),
#  ('xamarin.android', 46),
#  ('business-logic-layer', 46),
#  ('xml-comments', 46),
#  ('docking', 46),
#  ('castle-dynamicproxy', 46),
#  ('timespan', 46),
#  ('cqrs', 46),
#  ('access-modifiers', 46),
#  ('isapi', 46),
#  ('msdtc', 46),
#  ('xps', 46),
#  ('openxml-sdk', 46),
#  ('dynamic-linq', 45),
#  ('saml', 45),
#  ('stylecop', 45),
#  ('modelstate', 45),
#  ('coded-ui-tests', 45),
#  ('action-filter', 45),
#  ('mdi', 45),
#  ('login-control', 45),
#  ('.net-3.0', 45),
#  ('idataerrorinfo', 44),
#  ('toolbox', 44),
#  ('wpf-4.0', 44),
#  ('claims-based-identity', 44),
#  ('itext', 44),
#  ('maintainability', 44),
#  ('duplex', 44),
#  ('ihttphandler', 44),
#  ('sitecore6', 44),
#  ('code-snippets', 44),
#  ('caliburn', 44),
#  ('anti-patterns', 44),
#  ('castle-monorail', 44),
#  ('soap-client', 43),
#  ('xmlwriter', 43),
#  ('ws-security', 43),
#  ('typelib', 43),
#  ('gallio', 43),
#  ('mediaelement', 43),
#  ('visual-studio-lightswitch', 43),
#  ('acrobat', 43),
#  ('adfs', 43),
#  ('self-tracking-entities', 43),
#  ('web-site-project', 43),
#  ('covariance', 43),
#  ('mvc-mini-profiler', 43),
#  ('filesystemwatcher', 42),
#  ('dynamics-crm-4', 42),
#  ('silverlight-5.0', 42),
#  ('.net-remoting', 42),
#  ('unsafe', 42),
#  ('webdeploy', 42),
#  ('tcpclient', 42),
#  ('il', 42),
#  ('plinq', 42),
#  ('vb.net-2010', 42),
#  ('testdriven.net', 42),
#  ('findcontrol', 42),
#  ('pixelsense', 41),
#  ('response.redirect', 41),
#  ('hierarchicaldatatemplate', 41),
#  ('wshttpbinding', 41),
#  ('savefiledialog', 41),
#  ('modularity', 41),
#  ('sqlcommand', 41),
#  ('microsoft-sync-framework', 41),
#  ('bindinglist', 41),
#  ('typeconverter', 41),
#  ('expander', 41),
#  ('object-initializers', 41),
#  ('dbnull', 40),
#  ('html-agility-pack', 40),
#  ('viewdata', 40),
#  ('prism-4', 40),
#  ('eventaggregator', 40),
#  ('channelfactory', 40),
#  ('web-application-project', 40),
#  ('partial-trust', 40),
#  ('msbuildcommunitytasks', 40),
#  ('solid-principles', 39),
#  ('service-locator', 39),
#  ('radiobuttonlist', 39),
#  ('autosize', 39),
#  ('servercontrols', 39),
#  ('object-model', 39),
#  ('llblgenpro', 39),
#  ('full-trust', 39),
#  ('contentcontrol', 39),
#  ('system.reflection', 39),
#  ('xsd.exe', 39),
#  ('boxing', 39),
#  ('html-encode', 39),
#  ('axapta', 39),
#  ('printers', 39),
#  ('c#-to-vb.net', 39),
#  ('adorner', 39),
#  ('collectionviewsource', 39),
#  ('mixed-mode', 39),
#  ('argumentexception', 38),
#  ('assemblyinfo', 38),
#  ('sql-server-ce-4', 38),
#  ('federated-identity', 38),
#  ('selectlist', 38),
#  ('sharepoint-designer', 38),
#  ('mspec', 38),
#  ('comexception', 38),
#  ('ref', 38),
#  ('ocx', 38),
#  ('ndepend', 38),
#  ('dataform', 38),
#  ('xml-documentation', 38),
#  ('intranet', 38),
#  ('aspxgridview', 38),
#  ('activator', 38),
#  ('fluentvalidation', 38),
#  ('richtext', 37),
#  ('actionresult', 37),
#  ('streamwriter', 37),
#  ('xamlparseexception', 37),
#  ('codeplex', 37),
#  ('devforce', 37),
#  ('silverlight-oob', 37),
#  ('azman', 37),
#  ('dynamic-proxy', 37),
#  ('side-by-side', 37),
#  ('sitefinity', 37),
#  ('sealed', 37),
#  ('single-responsibility-principle', 37),
#  ('merge-module', 37),
#  ('autopostback', 37),
#  ('code-duplication', 37),
#  ('asp.net-dynamic-data', 37),
#  ('routed-events', 37),
#  ('caml', 37),
#  ('application-design', 36),
#  ('net.tcp', 36),
#  ('type-inference', 36),
#  ('vs-extensibility', 36),
#  ('linkbutton', 36),
#  ('xap', 36),
#  ('asp.net-profiles', 36),
#  ('icommand', 36),
#  ('validationsummary', 36),
#  ('idictionary', 36),
#  ('circular-reference', 36),
#  ('commandbinding', 36),
#  ('dcom', 36),
#  ('javascriptserializer', 35),
#  ('linq-expressions', 35),
#  ('sta', 35),
#  ('icollection', 35),
#  ('client-side-validation', 35),
#  ('smtpclient', 35),
#  ('bll', 35),
#  ('system-tray', 35),
#  ('datapager', 35),
#  ('windows-runtime', 35),
#  ('customvalidator', 35),
#  ('chm', 35),
#  ('region', 35),
#  ('prerequisites', 35),
#  ('late-binding', 35),
#  ('adfs2.0', 35),
#  ('nerddinner', 35),
#  ('actualwidth', 35),
#  ('componentone', 35),
#  ('routed-commands', 35),
#  ('regasm', 35),
#  ('boo', 35),
#  ('xunit', 35),
#  ('delphi-prism', 34),
#  ('objectdisposedexception', 34),
#  ('autocad', 34),
#  ('telerik-mvc', 34),
#  ('shortcuts', 34),
#  ('xna-4.0', 34),
#  ('valueconverter', 34),
#  ('tabitem', 34),
#  ('azure-web-roles', 34),
#  ('envdte', 34),
#  ('multibinding', 34),
#  ('begininvoke', 34),
#  ('nunit-2.5', 34),
#  ('wcf-web-api', 34),
#  ('navigation-properties', 34),
#  ('custom-errors', 34),
#  ('actionlink', 33),
#  ('maf', 33),
#  ('iprincipal', 33),
#  ('networkstream', 33),
#  ('specflow', 33),
#  ('windows-mobile-6', 33),
#  ('dockpanel', 33),
#  ('pagemethods', 33),
#  ('windows-identity', 33),
#  ('vsix', 33),
#  ('satellite-assembly', 33),
#  ('reportviewer2008', 33),
#  ('xtragrid', 33),
#  ('csc', 33),
#  ('trust', 33),
#  ('sharp-architecture', 33),
#  ('exchange-server-2007', 33),
#  ('mscorlib', 33),
#  ('visualstatemanager', 33),
#  ('t4mvc', 33),
#  ('pex-and-moles', 33),
#  ('dynamics-ax-2009', 33),
#  ('staticresource', 33),
#  ('appdata', 32),
#  ('aero', 32),
#  ('pex', 32),
#  ('requiredfieldvalidator', 32),
#  ('episerver', 32),
#  ('visual-studio-2012', 32),
#  ('post-build-event', 32),
#  ('xamlreader', 32),
#  ('system.componentmodel', 32),
#  ('solution-explorer', 32),
#  ('unity3d', 32),
#  ('webtest', 32),
#  ('selectedindex', 32),
#  ('automapping', 32),
#  ('cascadingdropdown', 32),
#  ('adobe-reader', 32),
#  ('treeviewitem', 31),
#  ('azure-table-storage', 31),
#  ('was', 31),
#  ('ncover', 31),
#  ('finalizer', 31),
#  ('typemock', 31),
#  ('savechanges', 31),
#  ('linq-to-dataset', 31),
#  ('radgridview', 31),
#  ('numericupdown', 31),
#  ('system.web', 31),
#  ('dbcontext', 31),
#  ('msbuild-4.0', 31),
#  ('directoryinfo', 31),
#  ('dbf', 31),
#  ('xval', 31),
#  ('excel-interop', 31),
#  ('citrix', 31),
#  ('asp.net-1.1', 31),
#  ('specification-pattern', 31),
#  ('dataadapter', 31),
#  ('linqdatasource', 31),
#  ('gethashcode', 31),
#  ('toolstrip', 31),
#  ('unauthorized', 30),
#  ('command-pattern', 30),
#  ('web-reference', 30),
#  ('w3wp', 30),
#  ('windows-mobile-6.5', 30),
#  ('app-code', 30),
#  ('icomparable', 30),
#  ('typeloadexception', 30),
#  ('async-ctp', 30),
#  ('system.data', 30),
#  ('datagridtemplatecolumn', 30),
#  ('maskedtextbox', 30),
#  ('special-folders', 30),
#  ('microsoft-metro', 30),
#  ('biztalk2006r2', 30),
#  ('groupbox', 30),
#  ('out-of-browser', 30),
#  ('design-principles', 30),
#  ('strategy-pattern', 30),
#  ('renderaction', 30),
#  ('mshtml', 30),
#  ('sts-securitytokenservice', 30),
#  ('eventtrigger', 30),
#  ('npgsql', 29),
#  ('throttling', 29),
#  ('sqlclient', 29),
#  ('nuget-package', 29),
#  ('internalsvisibleto', 29),
#  ('markup-extensions', 29),
#  ('expandoobject', 29),
#  ('sqldataadapter', 29),
#  ('frameworkelement', 29),
#  ('windows-server', 29),
#  ('servicebus', 29),
#  ('ikvm', 29),
#  ('asp.net-controls', 29),
#  ('undo-redo', 29),
#  ('machine.config', 29),
#  ('process.start', 29),
#  ('badimageformatexception', 29),
#  ('change-tracking', 29),
#  ('.nettiers', 29),
#  ('ajax.net', 29),
#  ('sharepoint-api', 29),
#  ('imaging', 29),
#  ('parallel-extensions', 29),
#  ('wia', 28),
#  ('yield-return', 28),
#  ('wse', 28),
#  ('windows-server-2000', 28),
#  ('entitydatasource', 28),
#  ('httplistener', 28),
#  ('azure-worker-roles', 28),
#  ('crystal-reports-2008', 28),
#  ('iequalitycomparer', 28),
#  ('openrasta', 28),
#  ('dotnetnuke-5', 28),
#  ('microsoft-dynamics', 28),
#  ('windowsformshost', 28),
#  ('wspbuilder', 28),
#  ('nlb', 28),
#  ('reference-type', 28),
#  ('downgrade', 28),
#  ('servicehost', 28),
#  ('nopcommerce', 28),
#  ('vspackage', 28),
#  ('fileinfo', 28),
#  ('cls-compliant', 28),
#  ('mmc', 27),
#  ('windows-media-player', 27),
#  ('ghostscript', 27),
#  ('pocketpc', 27),
#  ('visual-studio-designer', 27),
#  ('adam', 27),
#  ('missingmethodexception', 27),
#  ('checkedlistbox', 27),
#  ('health-monitoring', 27),
#  ('activereports', 27),
#  ('biztalk-2010', 27),
#  ('equivalent', 27),
#  ('gacutil', 27),
#  ('html.dropdownlistfor', 27),
#  ('aggregateroot', 27),
#  ('submitchanges', 27),
#  ('z-order', 27),
#  ('acs', 26),
#  ('ftpwebrequest', 26),
#  ('smartclient', 26),
#  ('string.format', 26),
#  ('queryover', 26),
#  ('sitemapprovider', 26),
#  ('point-of-sale', 26),
#  ('code-metrics', 26),
#  ('postscript', 26),
#  ('application-start', 26),
#  ('worker-process', 26),
#  ('documentviewer', 26),
#  ('validation-application-bl', 26),
#  ('dotfuscator', 26),
#  ('html.actionlink', 26),
#  ('static-classes', 26),
#  ('adsi', 26),
#  ('oledbconnection', 26),
#  ('notifyicon', 26),
#  ('self-hosting', 26),
#  ('.net-cf-3.5', 26),
#  ('virtualpathprovider', 26),
#  ('build-server', 26),
#  ('sharepoint-workflow', 26),
#  ('integrated-pipeline-mode', 26),
#  ('windows-applications', 26),
#  ('validationattribute', 26),
#  ('ienumerator', 26),
#  ('visual-c#-express-2010', 26),
#  ('bing', 26),
#  ('currentculture', 26),
#  ('system.net.mail', 26),
#  ('ixmlserializable', 25),
#  ('facade', 25),
#  ('readonly-collection', 25),
#  ('visual-studio-extensions', 25),
#  ('tcplistener', 25),
#  ('ngen', 25),
#  ('ultrawingrid', 25),
#  ('biztalk-2009', 25),
#  ('dapper', 25),
#  ('wcf-configuration', 25),
#  ('sqlmetal', 25),
#  ('integrated-security', 25),
#  ('system.net', 25),
#  ('composite-controls', 25),
#  ('xbox360', 25),
#  ('contravariance', 25),
#  ('mvc-editor-templates', 25),
#  ('dependencyobject', 25),
#  ('visual-studio-templates', 25),
#  ('workflow-activity', 25),
#  ('jscript.net', 25),
#  ('c#-to-f#', 25),
#  ('dynamicresource', 25),
#  ('objectdataprovider', 25),
#  ('asp.net-mvc-2-validation', 25),
#  ('fusion', 25),
#  ('codesmith', 25),
#  ('mtom', 25),
#  ('design-by-contract', 25),
#  ('pdfsharp', 25),
#  ('gzipstream', 25),
#  ('.net-4.0-beta-2', 25),
#  ('license-key', 25),
#  ('value-objects', 25),
#  ('delayed-execution', 25),
#  ('iasyncresult', 25),
#  ('mono.cecil', 25),
#  ('autocompletebox', 25),
#  ('elementhost', 24),
#  ('workflowservice', 24),
#  ('icollectionview', 24),
#  ('gtk#', 24),
#  ('gridsplitter', 24),
#  ('out', 24),
#  ('wsp', 24),
#  ('resourcemanager', 24),
#  ('vs-unit-testing-framework', 24),
#  ('httpapplication', 24),
#  ('project-template', 24),
#  ('contextmenustrip', 24),
#  ('intptr', 24),
#  ('binary-serialization', 24),
#  ('object-reference', 24),
#  ('resharper-5.0', 24),
#  ('.net-client-profile', 24),
#  ('asp.net-roles', 24),
#  ('tempdata', 24),
#  ('dotconnect', 24),
#  ('activesync', 24),
#  ('zebra-printers', 24),
#  ('duck-typing', 24),
#  ('sendkeys', 24),
#  ('settings.settings', 23),
#  ('routedevent', 23),
#  ('blogengine.net', 23),
#  ('partcover', 23),
#  ('base-class-library', 23),
#  ('notimplementedexception', 23),
#  ('wcf-endpoint', 23),
#  ('defaultmodelbinder', 23),
#  ('webdev.webserver', 23),
#  ('coderush', 23),
#  ('appharbor', 23),
#  ('rad-controls', 23),
#  ('user32', 23),
#  ('sqldependency', 23),
#  ('devart', 23),
#  ('drawstring', 23),
#  ('wse3.0', 23),
#  ('selectedindexchanged', 23),
#  ('f#-interactive', 23),
#  ('regfreecom', 23),
#  ('async-await', 23),
#  ('sqlparameter', 23),
#  ('iequatable', 23),
#  ('n-layer', 23),
#  ('windows-mobile-5.0', 23),
#  ('opennetcf', 23),
#  ('file-conversion', 23),
#  ('global-assembly-cache', 23),
#  ('system.net.webexception', 23),
#  ('telerik-reporting', 23),
#  ('sketchflow', 22),
#  ('infopath-2007', 22),
#  ('assemblybinding', 22),
#  ('unboxing', 22),
#  ...]

# %%
f = open("../filter/final_categories.txt", "r")
categories = f.read().split(", ")
categories
# Out:
# ['component',
#  'database',
#  'extension',
#  'environment',
#  'language',
#  'library',
#  'platform',
#  'subsystem',
#  'framework',
#  'ide',
#  'tool',
#  'toolkit',
#  'utility',
#  'system']

# %%
for a, b in sorted(G_1.degree, key=lambda x: x[1], reverse=True):
    if str(G.nodes[a]['root']) != "nan" and str(G.nodes[a]['root']) in categories:
        print(a + "," + str(b) + "," + G.nodes[a]['root'] + "," + node_attr[a]["Body"])
    #else:
    #    print(a + " " + str(b))
# Out:
# c#,2395,language,c# (pronounced "see sharp") is a high level statically typed multi-paradigm programming language developed by microsoft.
# .net,2097,framework,the .net framework is a software framework designed mainly for the microsoft windows operating system.
# asp.net,1478,framework,asp.net is a microsoft web application development framework that allows programmers to build dynamic web sites web applications and web services.
# vb.net,1081,language,visual basic.net (vb.net) is a multi-paradigm managed type-safe object-oriented computer programming language.
# wpf,951,subsystem,windows presentation foundation or wpf is a subsystem for rendering user interfaces in windows-based applications.
# visual-studio-2010,892,environment,visual studio 2010 is an integrated development environment (ide) from microsoft.
# asp.net-mvc,881,framework,the asp.net mvc framework is an open source web application framework and tooling that implements a version of the model-view-controller (mvc) pattern tailored towards web applications and built upon an asp.
# web-services,617,system,a "web service" is a software system designed to support interoperable machine-to-machine interaction over the world wide web.
# linq,558,component,language integrated query (linq) is a microsoft .net framework component that adds native data querying capabilities to .net languages.
# sharepoint,428,platform,microsoft sharepoint is a platform and a family of software products developed by microsoft for collaboration and web publishing.
# linq-to-sql,409,component,linq to sql is a component of .net framework version 3.5 that provides a run-time infrastructure for managing relational data as objects stored in microsoft sql server.
# xaml,388,language,extensible application markup language (xaml) is a declarative xml-based language used for  initializing structured values and objects in various frameworks.
# windows-phone-7,361,system,windows phone is microsoft's now deprecated mobile operating system and software development platform.
# azure,295,platform,microsoft azure is a platform as a service and infrastructure as a service cloud computing platform.
# f#,282,language,f# is a succinct expressive and efficient functional and object-oriented language for .net which helps you write simple code to solve complex problems.
# razor,222,language,razor is a template language used by asp.
# clr,196,component,the common language runtime (clr) is a core component of microsoft's .net initiative.
# ninject,184,framework,ninject is a dependency injection framework for .net applications.
# mef,182,component,the managed extensibility framework (mef) simplifies the design of extensible and modular applications and is a standard component of microsoft .net 4.0 and silverlight 4.0
# resharper,176,extension,resharper is a refactoring and productivity extension by jetbrains that extends native functionality of microsoft visual studio versions since 2003.
# prism,174,framework,prism is a framework for building loosely coupled maintainable and testable xaml applications in wpf windows 10 uwp and xamarin forms.
# moq,173,framework,moq is a strongly typed and minimalistic mocking framework for .net.
# viewmodel,172,framework,a view model or viewpoints framework is a framework which defines a coherent set of views to be used in the construction of an architecture.
# sql-server-ce,172,database,microsoft sql server compact is a free sql server embedded database ideal for building standalone and occasionally connected applications for mobile devices desktops and web clients.
# log4net,171,tool,the apache log4net library is a tool to help the programmer output log statements to a variety of output targets.
# activex,162,framework,activex is a microsoft-proprietary framework for defining and accessing interfaces to system resources in a programming-language independent way.
# forms-authentication,150,system,forms authentication is a built-in and extensible system for authenticating users in an asp.
# xna,147,framework,xna is a cross-platform framework originally from microsoft that facilitates game development with .net. supports: windows xbox 360 windows phone (natively) silverlight (via silversprite or exen) iphone/ipad android mac os x linux and others (via monogame).
# timer,145,component,timer is a component that has the functionality to trigger a user defined action at regular intervals as configured by the user.
# wsdl,139,language,web service description language (wsdl) is an xml based human- and machine-readable language used to describe a web service.
# nant,138,tool,nant is a build tool for .net aiming to support all the various versions of the .net framework including all versions of microsoft .net compact framework and silverlight mono and moonlight.
# appdomain,138,environment,an application domain is an isolated environment in which microsoft .net assemblies can be sandboxed granted specific permissions or permissionsets and executed.
# windows-server-2003,130,system,windows server 2003 (sometimes referred to as win2k3) is a server operating system produced by microsoft introduced on 24 april 2003.
# t4,128,framework,t4 stands for text template transformation toolkit and is microsoft's free and open-source template-based text generation framework included with visual studio.
# rhino-mocks,128,framework,rhino.mocks is a dynamic mock object framework for the .net platform.
# cruisecontrol.net,118,framework,cruisecontrol.net is a .net-based framework for supporting a continuous build process.
# windows-ce,114,system,microsoft windows ce (now officially known as windows embedded compact and previously also known as windows embedded ce and sometimes abbreviated wince) is an operating system developed by microsoft for embedded systems.
# wcf-binding,114,system,this tag is for both the default system-provided bindings and custom bindings.
# expression-blend,105,tool,expression blend is a visual design tool used to create wpf silverlight and windows phone 7 application user interfaces.
# workflow-foundation-4,104,framework,windows workflow 4 is microsoft's framework for declarative composable business logic for .net.
# spring.net,101,framework,spring.net is an open source application framework for developing .net enterprise applications.
# monodevelop,100,ide,monodevelop is an ide focusing on developing desktop mobile and web applications using c# and other .net languages.
# windows-server-2008-r2,96,system,windows server 2008 r2 is a server operating system produced by microsoft.
# umbraco,90,platform,umbraco is an open-source content management system platform for publishing content on the world wide web and intranets.
# json.net,85,framework,json.net (also known as newtonsoft.json) is a popular high-performance json framework for .net.
# silverlight-2.0,85,framework,microsoft silverlight is an application framework for writing and running rich internet applications with features and purposes similar to those of adobe flash.
# nuget,85,system,nuget is a free open source developer focused package management system for the .net platform.
# installshield,79,tool,installshield (not including limited edition) is a software tool for creating msi installers or software packages.
# nlog,77,platform,nlog is a free logging platform for .net
# itextsharp,75,library,itextsharp is a .net open source library for pdf generation and manipulation.
# codedom,72,framework,codedom is a framework which can be used to create an (abstract) expression tree representing real code structures (for example classes statements etc.) in a language-independent way.
# wif,71,library,the windows identity foundation is a free microsoft library that enables claims based authentication and use federated identity/single sign-on in their applications.
# cil,70,language,common intermediate language is the object-oriented assembly language used by the .net framework .net core and mono.
# inno-setup,70,tool,inno setup is a tool to create setup programs with an embedded pascal-derived scripting language.
# azure-sql-database,70,database,azure sql database is a relational paas database hosted in microsoft azure.
# postsharp,68,extension,postsharp is a pattern-aware extension to c# and vb reducing boilerplate code involved in implementing design patterns.
# dotnetopenauth,65,library,dotnetopenauth is an open source library for openid 1.1 and 2.0 supporting oauth 1.0 1.1 2.0 as consumer and service provider.
# infopath,60,component,infopath is a component of the microsoft office suite of applications that allows for the creation of xml based form templates and the collection of structured data.
# orchardcms,59,system,orchard is a free open source community-focused content management system built on the asp.
# cab,58,extension,cab is the file extension for the cabinet archive format used in microsoft windows.
# xunit.net,57,tool,xunit.net is a unit testing tool for the .net framework.
# ilmerge,56,utility,ilmerge is a utility for merging multiple .net assemblies into a single .net assembly.
# azure-storage,53,platform,microsoft azure storage is a highly-scalable durable cloud-based storage platform providing four core services: blobs tables queues and azure drives.
# visual-web-developer,53,tool,visual web developer express is a freeware web development tool with the role of former asp.
# foxpro,52,language,foxpro is a programming language and dbms originally created by fox software and later sold to microsoft.
# db4o,50,database,db4o is an open source embeddable object database for java and .net.
# mbunit,50,framework,mbunit is a generative unit test framework for the .net framework.
# sharpdevelop,50,ide,sharpdevelop (also styled as #develop) is a free and open source integrated development environment ide for the microsoft .net mono gtk# and glade# platforms and supports development in c# visual basic .net boo f# ironpython and ironruby programming languages.
# ravendb,50,database,ravendb is an open source document database for the .net core platform (windows macos linux).
# blend,48,tool,microsoft blend for visual studio (formerly microsoft expression blend) is a user interface design tool developed and sold by microsoft for creating graphical interfaces for web and desktop applications that blend the features of these two types of applications.
# documentation-generation,48,tool,a documentation generator is a programming tool that generates documentation intended for programmers (api documentation) or end users (end-user guide) or both from a set of specially commented source code files and in some cases binary files.
# reflector,47,utility,.net reflector® is a proprietary software utility for microsoft .net combining class browsing static analysis and decompilation originally written by lutz roeder.
# castle-dynamicproxy,46,library,castle dynamicproxy is a library for generating lightweight .net proxies on the fly at runtime.
# dynamic-linq,45,library,dynamic linq is a small library on top of the .net framework 3.5 or later which allows to build string based query expressions.
# modelstate,45,component,the modelstate ( system.web.mvc.modelstate ) is a component in the asp.
# duplex,44,system,a duplex communication system is a point-to-point system composed of two connected parties or devices that can communicate with one another in both directions simultaneously.
# sitecore6,44,system,sitecore is a web content management system built on microsoft asp.net.
# castle-monorail,44,framework,castle monorail is a mvc web framework for .net
# ws-security,43,extension,ws-security is an extension to soap for applying security to web-services through xml signature and xml encryption.
# gallio,43,platform,gallio is an automation platform for .net
# visual-studio-lightswitch,43,tool,microsoft visual studio lightswitch is a rapid application development tool for creating data centric silverlight or html5 applications.
# webdeploy,42,tool,the web deployment tool (web deploy) is a command-line tool from microsoft that is used for synchronizing web site code and content with web servers—and particularly iis.
# pixelsense,41,platform,microsoft pixelsense is a large-touchscreen computer platform released by microsoft in 2008.
# servercontrols,39,component,net is a component that dynamically renders a segment of markup to the client.
# sql-server-ce-4,38,database,microsoft sql server compact version 4 is a sql server embedded database for building standalone and occasionally connected applications for mobile devices desktops and web clients.
# mspec,38,framework,specifications is a context/specification framework for c#. not to be confused with the mspec ruby framework (tag [mspec-ruby]) used in rubyspecs.
# ndepend,38,tool,ndepend is a static analysis tool for .net managed code that focuses on code dependencies and quality.
# dataform,38,platform,dataform is a platform for analysts to manage sql data workflows in cloud data warehouses such as google bigquery amazon redshift or snowflake.
# fluentvalidation,38,framework,fluent validation is an asp.net mvc integrated validation framework that allows the developer to set validation rules using expressions.
# devforce,37,framework,devforce is a framework for building and operating rich internet applications (rias).
# caml,37,language,caml (collaborative application markup language) is an xml based markup language used with the family of microsoft sharepoint technologies (windows sharepoint services and office sharepoint server).
# xap,36,framework,xap is an xml-based declarative framework for building deploying and maintaining rich interactive ajax powered web applications.
# regasm,35,tool,regasm is an assembly registration tool that reads the metadata within an assembly and adds the necessary entries to the registry which allows com clients to create .net framework classes transparently.
# delphi-prism,34,tool,delphi prism is a rapid application development tool for the microsoft .net framework and mono developed by remobjects software and distributed by embarcadero technologies.
# envdte,34,library,envdte is an assembly-wrapped com library containing the objects and members for visual studio core automation.
# specflow,33,tool,specflow  is a behavior-driven development (bdd) tool for .net.
# t4mvc,33,utility,t4mvc is an open source utility for microsoft asp.
# pex-and-moles,33,tool,pex being an exploration tool explores and provides random inputs to the method in test to go in every branch of that code.
# episerver,32,system,episerver is a web content management system and e-commerce platform based on asp.net.
# ncover,31,tool,`ncover` is the original `.net` code coverage tool.
# typemock,31,framework,typemock isolator is a mocking framework used in unit testing .net and unmanaged c and c++ code.
# linq-to-dataset,31,component,linq to dataset is a component of language integrated query (linq) that provides sql-style query capabilities against ado.
# xval,31,framework,xval is a validation framework for asp.
# windows-mobile-6.5,30,system,windows mobile 6.5 is an operating system for pdas and smartphones developed by microsoft.
# nuget-package,29,extension,nuget is a visual studio extension that makes it easy to install and update open source libraries and tools in visual studio.
# parallel-extensions,29,library,parallel extensions is a managed concurrency library included in the .net 4.0 release.
# wia,28,platform,windows image acquisition (wia) is the still image acquisition platform in the windows family of operating systems starting with windows millennium edition (windows me) and windows xp.
# windows-server-2000,28,system,microsoft windows 2000 server is an operating system for use on server computers.
# openrasta,28,framework,openrasta is an open-source mvc framework that can run on .net 2.0 and above built from the ground-up to enable restful scenarios.
# wspbuilder,28,tool,wspbuilder is a sharepoint solution package (wsp) creation tool for wss 3.0 & moss 2007.
# mmc,27,component,the microsoft management console (mmc) is a component of windows that provides an administrative interface for system configuration.
# activereports,27,framework,activereports is a reporting framework for visual studio programmers designed and marketed by  grapecity.
# postscript,26,language,postscript is a turing-complete page description programming language designed and developed by adobe.
# ultrawingrid,25,component,wingrid™ is a component of the infragistics netadvantage suite.
# jscript.net,25,language,jscript.net is a .net programming language developed by microsoft.
# mono.cecil,25,library,mono.cecil is a library to generate and inspect programs and libraries in the ecma cil form.
# partcover,23,tool,partcover is an open source code coverage tool for .net
# coderush,23,tool,coderush is a productivity tool by devexpress that extends the functionality of microsoft visual studio 2010 2012 and 2013.
# appharbor,23,platform,appharbor is a cloud application platform for .net.
# windows-mobile-5.0,23,system,windows mobile 5 was microsoft's latest operating system for handheld devices in 2005 which replaced windows mobile 2003.
# infopath-2007,22,tool,infopath 2007 is a microsoft form builder tool used to create forms for sharepoint.
# dbase,22,system,dbase ii was the first widely used database management system (dbms) for microcomputers.
# vdproj,22,extension,vdproj is the build file extension for microsoft visual studio .net applications.
# log4net-configuration,22,tool,the apache log4net library is a tool to help the programmer output log statements to a variety of output targets.
# tlbimp,22,tool,the type library importer is a microsoft tool that converts the type definitions found within a com type library into equivalent definitions in a common language runtime assembly.
# x++,22,language,x++ is the development language used by microsoft dynamics ax.
# intermediate-language,22,language,an intermediate language in compiler design is a low-level language that typically resembles an idealized assembly language often a textual representation of bytecode for a virtual machine.
# opentk,21,library,the open toolkit is an advanced low-level c# library that wraps opengl opencl and openal.
# mvcsitemapprovider,20,tool,mvcsitemapprovider is a tool that provides flexible menus breadcrumb trails and seo features for the asp.
# ext.net,20,framework,ext.net is an asp.net component framework that integrates the sencha ext js javascript framework.
# wcsf,20,framework,the microsoft web client software factory is a framework that allows creating asp.
# xtrareport,19,tool,xtrareports is a reporting tool made by devexpress for winforms asp.
# three-tier,19,framework,the three-tier architecture model is a framework for logical design model; it segments an application's components into three tiers of services that correspond to logical layers of the application.
# wcftestclient,19,tool,windows communication foundation (wcf) test client (wcftestclient.exe) is a gui tool that enables users to input test parameters submit that input to the service and view the response that the service sends back.
# expression-blend-4,19,tool,microsoft expression blend is a user interface design tool developed and sold by microsoft for creating graphical interfaces for web and desktop applications that blend the features of these two types of applications.
# ibatis.net,19,framework,ibatis is a simple but complete framework that makes it easy to map objects to sql statements or stored procedures.
# sdf,19,database,sqlce database file (.sdf) is a database created and accessed by sql server compact edition.
# orca,19,tool,the orca msi editor is a table-editing tool that can be used to edit .msi files.
# nemerle,19,language,nemerle is a general-purpose multi-paradigm programming language for the .net platform.
# web-platform-installer,19,tool,microsoft web platform installer is a tool for automating the installation of products pertaining to the microsoft web platform.
# datacontractjsonserializer,18,component,datacontractjsonserializer is a .net component that makes it possible to directly serialize .net objects into json data and to deserialize such data back into instances of .net types.
# abcpdf,18,component,abcpdf is websupergoo's software component for generating and manipulating pdf documents dynamically on windows based systems supporting the microsoft .net framework and asp/com.
# n2,18,system,n2 is a lightweight open source content management system that runs on top of asp.net.
# nhibernate-validator,18,framework,nhibernate validator is a powerful and extensible framework to validate objects using the .net platform.
# j#,18,language,j# programming language is a discontinued transitional language for programmers of java and visual j++ languages so they may use their existing knowledge and applications on .net framework.
# microsoft-bits,18,component,background intelligent transfer service (bits) is a component of microsoft windows xp and later operating systems that facilitates prioritized throttled and asynchronous transfer of files between machines using idle network bandwidth.
# sharpziplib,18,library,#ziplib (sharpziplib) is a zip gzip tar and bzip2 library written entirely in c# for the .net platform.
# naudio,18,library,naudio is an open source audio library for .net supporting audio playback recording and sample manipulation as well as reading and writing various audio file formats.
# oxygene,18,language,oxygene is a general-purpose object-oriented programming language based on pascal.
# installscript,18,language,installscript is the official language for scripting installations in installshield and related products.
# bits-service,17,component,background intelligent transfer service (bits) is a component of microsoft windows xp and later operating systems that facilitates prioritized throttled and asynchronous transfer of files between machines using idle network bandwidth.
# heat,17,tool,heat is a harvesting tool that creates .wxs files that can be used to create an installer.
# metabase,17,tool,metabase is an open source browser based analytics/data visualization tool.
# rhino-security,17,framework,rhino security is a row level security framework for nhibernate.
# filehelpers,17,library,filehelpers is a .net utility library to help applications manage flat file input and output.
# tweetsharp,17,library,tweetsharp is a twitter api library for adding twitter to web and mobile applications.
# installutil,17,utility,the installer tool is a command-line utility that allows you to install and uninstall server resources by executing the installer components in specified assemblies.
# monomac,16,library,monomac is an open source library for building cocoa applications on mac os x using mono.
# fubumvc,16,framework,fubumvc is an open source front controller-style mvc framework designed primarily for web applications built on asp.net.
# microsoft-web-deploy,16,tool,microsoft web deploy is a tool to simplify the migration management and deployment of iis web servers applications and sites.
# aspnet-regiis.exe,16,tool,aspnet_regiis.exe is the asp.net iis registration tool.
# expression-encoder,15,tool,microsoft expression encoder sdk is a tool which allows to record from the window screen audio devices and/or video devices to computer or stream over the net.
# n2cms,15,system,n2cms is a lightweight open source content management system that runs on top of asp.net.
# xpo,15,library,xpo is a devexpress orm library for .net.
# nhibernate.search,14,extension,search is an extension to nhibernate that allows you to utilize lucene.
# asp.net-web-api,14,framework,asp.net web api is a framework for building http services for clients like browsers and mobile devices.
# kentico,14,system,kentico is a content management system (cms) for building websites online stores intranets and web 2.0 community sites.
# script#,14,tool,script# is a free tool that generates javascript by compiling c# source code.
# nmock,14,framework,nmock is a mocking framework for .net 3.5 and 4.0. it supports lambda expressions for member matching.
# gendarme,13,tool,gendarme is a tool to find defects inside .net (ecma cil) applications and libraries.
# webformsmvp,13,framework,webformsmvp is an open-source framework which supports the model-view-presenter (mvp) pattern on traditional webform-based asp.
# revit,13,tool,revit is a bim (building information modeling) software tool used by architects engineers etc.
# autofixture,13,library,autofixture is an open source library for .net designed to minimize the 'arrange' phase of your unit tests.
# justmock,13,framework,justmock is a mocking framework for unit testing .net code.
# winnovative,13,library,the html to pdf converter for .net is a library that can be used in any type of .net application either asp.
# radwindow,13,component,radwindow is telerik component for creating child and dialog windows and customize their appearance and content.
# tlbexp,12,tool,the type library exporter (tlbexp.exe) is a tool automatically installed with visual studio which generates a type library that describes the types defined in a common language runtime assembly.
# cqlinq,12,language,cqlinq is a linq-like query language used by ndepend to reflectively analyze .net source code using the ndepend tool.
# castle-validators,12,framework,castle validator component is an open source validation framework that uses property attribute to specify validation rules on class.
# ghostdoc,12,extension,ghostdoc is a visual studio extension that automatically generates xml documentation comments for methods and properties based on their type parameters name and other contextual information.
# dotnetnuke-module,12,system,dotnetnuke is a web content management system based on microsoft .net.
# ribboncontrolslibrary,12,library,the ribboncontrolslibrary.dll is a wpf ribbon library.
# nancy,12,framework,nancy is a lightweight web framework for the .net platform inspired by sinatra.
# visual-assist,12,extension,visual assist is a commercial visual studio extension that enhances overall code editing.
# dxcore,12,tool,dxcore is the refactoring and productivity tool by devexpress to extend visual studio
# rapi,11,library,rapi (remote api) is an official library that enables applications running on a windows-based desktop to perform actions on a remote windows mobile device.
# openaccess,11,tool,telerik openaccess orm is a tool that supports development of data-oriented software applications.
# aforge,11,framework,aforge.net is a c# framework for computer vision and artificial intelligence.
# cal,11,library,cal is the composite application library the previous name for the prism guidance for wpf and silverlight.
# k2,10,platform,k2 is a windows server platform that allows the creation and management of business workflows that consume data from a variety of data sources; on top of the .net platform.
# community-server,10,platform,community server is a social software platform developed by telligent.
# cups,10,system,cups is the standards-based open source printing system for mac os x and other unix®-like operating systems.
# avalonedit,10,component,avalonedit is a .net wpf-based source code editor component developed for sharpdevelop 4.0 "mirador".
# dotcover,10,tool,dotcover is a tool for code coverage and continuous testing of .net code.
# fluent-ribbon,10,library,"fluent.ribbon is a library that implements an office-like user interface for the windows presentation foundation (wpf).
# texttemplate,10,library,text::template is a perl library that allows to generate text from text containing perl code that is evaluated.
# telerik-open-access,10,framework,telerik's object-relational mapper is a powerful framework for mapping the objects in your object-oriented domain model to your relational database tables views and/or stored procedures.
# krypton-toolkit,10,library,krypton toolkit is a free .net library of user interface controls and components.
# expression-web,10,tool,microsoft expression web is a professional development and design tool to create modern standards-based web sites that use php html/xhtml css javascript asp.net or asp.net ajax.
# asp.net-webpages,10,framework,asp.net web pages is a page-centric lightweight development framework from microsoft for building dynamic web sites.
# installshield-2011,10,tool,installshield is a software tool by flexera software for creating installers or software packages.
# net-reactor,10,system,.net reactor is a powerful code protection and software licensing system for software written for the .net framework and supports all languages that generate .net assemblies
# opencover,10,tool,opencover is a code coverage tool for .net and currently supports .net 2 3 and 4
# azure-queues,9,platform,microsoft azure (formerly windows azure before march 25 2014) is a cloud computing platform and infrastructure created by microsoft for building deploying and managing applications and services through a global network of microsoft-managed data centers.
# unidata,9,database,unidata is an extended relational database and integrated development environment.
# peverify,9,tool,peverify is a tool that checks if .net assemblies meet type safety requirements.
# ws-reliablemessaging,9,extension,ws-reliablemessaging is an extension to soap that allows messages to be reliably delivered to web-services between distributed applications.
# platform-builder,9,tool,platform builder is a programming tool that allows building a customized version of windows ce (windows embedded ce/windows embedded compact) or windows mobile.
# isolation-frameworks,9,framework,an isolation framework is a unit testing framework with a special ability to isolate the dependent code.
# xamarin,9,platform,xamarin is a platform consisting of xamarin.ios xamarin.android xamarin.mac and xamarin test cloud.
# signalr,9,library,asp.net signalr is a library for asp.
# ndbunit,9,library,ndbunit is a .net library that can be used to manage database state during unit testing.
# business-connector,9,component,.net business connector is a microsoft dynamics ax component that enables you to integrate with microsoft dynamics ax from a .net-connected application.
# flying-saucer,9,library,flying saucer (also called xhtml renderer) is a pure java library for rendering xml xhtml and css 2.1 content.
# dynamics-nav,9,platform,dynamics nav formerly navision is an enterprise resource planning (erp) development platform produced by microsoft.
# objectbuilder,9,framework,objectbuilder is microsoft's first .net dependency injection framework.
# reactiveui,9,framework,reactiveui is a mvvm framework that integrates with the reactive extensions
# urlrewriting.net,8,component,urlrewritingnet.urlrewrite is an open source component for easy and reliable rewriting urls with asp.net
# advanced-installer,8,tool,advanced installer is a setup authoring tool which is primarily used to creates windows installer msi packages.
# neventstore,8,library,neventstore (aka joliver eventstore to disambiguate it from github.com/eventstore) is a persistence library used to abstract different storage implementations when using event sourcing as a storage mechanism.
# groupwise,8,platform,groupwise is a messaging and collaborative software platform from novell that supports email calendaring personal information management and instant messaging.
# skype4com,8,component,skype4com is an activex component that represents the skype api as objects with properties commands events and notifications.
# dockpanel-suite,8,library,the weifenluo dockpanel suite is an open source library that extends the .net winforms api to support forms that can be interactively docked by a user to customise their application ui layout.
# epplus,8,library,epplus is a .net library that reads and writes excel files using the office open xml format (xlsx) without the need of interop.
# scintilla,8,component,scintilla is a free source code editing component.
# radscheduler,8,library,radscheduler is a rich scheduling ui library sold by telerik for the asp.net environment.
# zpl,8,language,zpl stands for the "zebra programming language" and is a proprietary programming language used to communicate to zebra branded printers.
# nhydrate,8,tool,nhydrate is a model driven development tool for visual studio.
# performance-monitor,8,tool,performance monitor is a microsoft windows tool that examines how programs you run affect your computer's performance.
# wsse,8,extension,ws-security or web service security is a soap extension which provides eg signing of soap messages.
# crystal-reports-8.5,8,tool,crystal reports 8.5 is a reporting tool released in 2001 by crystal decisions.
# luainterface,8,library,luainterface is a library for integration between the lua language and microsoft .net platform's common language runtime (clr).
# appdomainsetup,7,environment,appdomainsetup provides configuration information for a new application domain which is an isolated environment in which microsoft .net assemblies can be sandboxed granted specific permissions or permissionsets and executed.
# ultrawebgrid,7,component,ultrawebgrid is an asp.net data grid ui component developed by infragistics.
# guidance-automation-tool,7,extension,the guidance automation toolkit (gat) is a visual studio extension that helps build guidance packages which empower software teams to automate key development tasks (like custom templates wizards and code generation) inside visual studio.
# linfu,7,framework,linfu is a framework that adds mixins inversion of control dbc and other language features to the common language runtime.
# unity-interception,7,framework,unity is an ioc/di framework from the microsoft enterprise patterns and practices library.
# ranorex,7,framework,ranorex is a commercial ui test automation framework for testing many different application types including web 2.0 wpf flash/flex silverlight qt .net and java.
# migradoc,7,library,migradoc foundation is an open source .net library that easily creates documents based on an object model with paragraphs tables styles etc. and renders them into pdf or rtf.
# maml,7,language,maml is an xml markup language used to write windows help files.
# jespa,7,library,jespa is a java software library that provides advanced integration between microsoft active directory and java applications.
# edmx-designer,7,tool,the edmx designer is a tool that enables point-and-click modification of an .edmx file representing a conceptual/storage model defined using microsoft entity framework.
# spec#,6,language,spec# is a formal language for api contracts (influenced by jml asml and eiffel) which extends c# with constructs for non-null types preconditions postconditions and object invariants.
# dataobjects.net,6,framework,dataobjects.net is an orm and business logic layer development framework.
# sharppcap,6,framework,sharppcap is a cross-platform packet capture framework for the .net environment based on the famous pcap / winpcap libraries.
# html-help,6,system,microsoft html help is a help system to use compiled html web content (in ".chm" files) for help topics.
# nsubstitute,6,framework,nsubstitute is a .net mocking framework.
# fluent-migrator,6,framework,fluentmigrator is a migration framework for the .net platform that lets you easily create migration-steps that fit very nicely into an automated deployment scenario.
# ironpython-studio,6,ide,ironpython studio is a free full ide (integrated development environment) for the python programming language.
# eiffel,6,language,eiffel is a statically typed object-oriented programming language closely related with the programming method of the same name.
# taglib-sharp,6,library,taglib# (or taglib-sharp) is a c# library for reading and writing most common formats of metadata (both "tags" and media properties) for audio video and picture formats.
# squishit,6,library,squishit is a free library to compress and minify css and javascript dynamically in asp.net and asp.
# monotouch.dialog,6,framework,monotouch.dialog is a monotouch framework for ios for ios developers to create dialog boxes and show table-based information without having to write dozens of delegates and controllers for the user interface.
# zpl-ii,6,language,zpl-ii stands for the "zebra programming language v ii" and is a proprietary programming language used to communicate to zebra branded printers
# qbasic,6,language,qbasic is a general-purpose interpreted programming language derived from quickbasic 4.5. qbasic replaced gwbasic starting from msdos 5. it became popular because it had a quite advanced ide with a debugger and was delivered free with msdos windows 95 and 98.
# justcode,6,extension,justcode is a visual studio extension that provides on-the-spot .net code analysis and error checking smart navigation and refactoring.
# mts,6,system,microsoft transaction server (mts) was a com-based transaction processing system for developing deploying and managing network applications.
# clrprofiler,6,tool,clrprofiler is a free profiler tool from microsoft for profiling .net framework applications.
# teamsite,5,system,hp/autonmy teamsite is an enterprise web content management (wcm) system with demands—content authoring multichannel delivery site design and layout multivariate testing content targeting rich media management advanced analytics social content management workflow and approval and archiving.
# form-control,5,component,form control is the main component of windows forms ui framework.
# axshockwaveflash,5,component,axshockwaveflash is a .net wrapper component for loading flash movies (swf) on a windows form.
# pdfkit,5,library,pdfkit is a pdf document generation library built on top of wkhtmltopdf to convert html+css to pdf using webkit.
# linfu-dynamicproxy,5,library,linfu dynamicproxy is a library for generating proxies on the fly at runtime.
# xaf,5,framework,the devexpress expressapp framework (xaf) is a modern and flexible .net application framework that allows you to create powerful line-of-business applications that simultaneously target windows and the web.
# clarion,5,language,clarion is a commercial 4gl programming language and integrated development environment from softvelocity used to program database applications.
# imageresizer,5,library,imageresizer is a general-purpose .net image processing library designed for server-side use and focusing on scalability safety and image quality.
# installshield-2008,5,tool,installshield is a software tool for creating installers or software packages.
# dataflex,5,tool,dataflex is a database rad tool for developing windows and web applications.
# monotorrent,5,library,monotorrent is a cross-platform library implementing the bittorrent protocol.
# simple.data,5,framework,simple.data is a lightweight framework that uses the dynamic features of .net 4 to provide an expressive orm-ish way of accessing and manipulating data without any of the code pre-generation and boilerplate required by other frameworks.
# jquery-globalization,5,library,jquery/globalize (former jquery-global) is a library for the globalization of strings dates and numbers/currencies formatting and parsing for different cultures in javascript.
# mojoportal,5,system,mojoportal is an open source content management system (cms) and web site framework for .net plateform on windows or mono on linux.
# nbug,5,library,nbug is a .net library created to automate the bug reporting process for wpf winforms and console applications.
# suo,5,extension,suo is the file extension for the solution user options file for visual studio.
# windows-7-embedded,5,system,windows 7 embedded is an operating system designed to bring windows 7 features to embedded devices.
# sharpssh,5,library,sharpssh is a .net framework library for connecting to and retrieving files from an ssh/sftp server.
# emitmapper,5,library,emit mapper is a .net library for mapping entities such as objects datareaders or sql commands.
# system.io.packaging,5,system,system.io.packaging is microsoft's system for creating and packaging complex multi-part documents.
# xmlpoke,4,tool,xml poke is a tool to make some pokes in xml files with msbuild.
# radpanelbar,4,component,telerik's radpanelbar is a versatile component allowing you to build different navigation systems such as left/right side menus and outlook style panels.
# sterling-db,4,database,sterling is a lightweight nosql object-oriented database for .net 4.0 silverlight 4 and 5 and windows phone 7 with linq to object support.
# pjl,4,extension,the printer job language(pjl) is an extension to the printer control language(pcl) that provides a protocol for communication between a printer and a print server or remote computer.
# asp.net-core,4,framework,asp.net core is a lean composable and cross-platform framework for building web and cloud applications.
# poppler,4,library,poppler is a gpl'd pdf rendering library based on the xpdf-3.0 code base.
# j-interop,4,library,j-interop is a java open source library (under lgpl) that implements the dcom wire protocol (msrpc) to enable development of pure bi-directional non-native java applications which can interoperate with any com component.
# primavera,4,system,primavera project management or p6 is a project scheduling system.
# simple-injector,4,library,simple injector is an dependency injection library for microsoft .net .net core .net standard windows phone windows store apps and mono.
# .net-bcl,4,library,the base class library is a library of functionality available to all languages using the .net framework.
# type-providers,4,component,an f# type provider is a component that provides types properties and methods for use in your program.
# libharu,4,library,libharu is a free cross platform open source library for generating pdf files.
# netduino,4,platform,netduino is an open-source electronics platform using the .net micro framework.
# checklistbox,4,library,a checkboxlist is a multi selection checkbox group that is in the system.web.ui.webcontrols library of asp.net webforms.
# unityscript,4,language,unityscript is a separate language and should be used only on questions explicitly using that language.
# robohelp,4,tool,robohelp is a help authoring tool (hat) created by ehelp corporation (formerly named blue sky software) acquired by macromedia which itself was then acquired by adobe systems.
# coolstorage,4,library,vici coolstorage is a fully typed object relational mapping library for .net 3.5 windows phone and monotouch.
# cctray,4,utility,cctray is an optional utility for use with the cruisecontrol.
# axum,4,language,axum is a domain specific concurrent programming language based on the actor model being developed by microsoft.
# tpl-dataflow,4,library,tpl dataflow (tdf) is a .net library for building concurrent applications.
# opensaml,4,library,opensaml is a java and c++ library that provides low level handling of saml messages
# azure-web-app-service,4,platform,azure app service is a cloud-based platform for hosting web applications rest apis and mobile back ends.
# microsoft.build,3,platform,msbuild is a microsoft build platform typically used in conjunction with visual studio.
# asp.net-web-api2,3,framework,asp.net web api 2 is a framework for building http services for clients like browsers and mobile devices.
# home-automation,3,extension,home automation is the residential extension of "building automation".
# odata4j,3,toolkit,odata4j is a new open-source toolkit for building first-class odata producers and first-class odata consumers in java.
# fscheck,3,framework,fscheck is a framework for random testing of .net programs.
# ms-solver-foundation,3,framework,microsoft solver foundation (msf) is a framework for modeling optimization problems.
# litjson,3,library,litjson is a small and fast library for handling data in the json format.
# monocross,3,framework,monocross is open-source cross-platform mobile framework using c# .net and mono framework.
# uniquery,3,language,uniquery is the database query language supported by unidata.
# lidgren,3,library,network is an open source networking library for .net framework with a simple api used mainly in client/server games.
# f#-unquote,3,library,unquote is a library for writing unit test assertions as f# quoted expressions.
# sharpmap,3,library,sharpmap is an easy-to-use mapping library for use in web and desktop applications.
# azure-service-fabric,3,platform,azure service fabric is a distributed systems platform used to build scalable reliable and easily-managed applications for the cloud.
# f#-charting,3,library,the f# charting library (fsharp.charting.dll) is a compositional library for creating charts from f#.
# snoop,3,utility,snoop is the open source wpf spying utility.
# .net-gadgeteer,3,toolkit,microsoft .net gadgeteer is an open-source toolkit for building small electronic devices using the .net micro framework and visual studio or visual c# express.
# slimtune,3,tool,slimtune is a free and open-source profiling and performance tuning tool for .net applications
# moq-3,3,framework,moq (pronounced "mock-you" or just "mock") is a mocking framework for .net that makes heavy use of lambdas and linq expression trees.
# rxjs,3,library,rxjs is a library for reactive programming using observables to make it easier to compose asynchronous or callback-based code.
# clay,3,library,clay is a c# library that implements a dynamic typing system similar to javascript using c# `dynamic` types.
# windows-store,3,platform,the windows store is a digital distribution platform for windows applications.
# visualj#,3,language,j# programming language is a discontinued transitional language for programmers of java and visual j++ languages so they may use their existing knowledge and applications on .net framework.
# gameobject,3,component,gameobject is a key component of the unity3d engine.
# ocean,3,platform,ocean is a development platform for the oil & gas industry to create plug-ins to extend the capabilities of the petrel software.
# ncron,3,library,ncron is a light-weight library for building and deploying scheduled background jobs on the .net server platform.
# imapi,3,component,the image mastering application programming interface or imapi is a component of microsoft windows operating system used for cd and dvd authoring and recording.
# mo+,2,language,mo+ is a model oriented programming language
# sgmlreader,2,library,sgmlreader is a .net library for parsing html/sgml files using the xmlreader api
# dotnetnuke-6,2,system,dotnetnuke version 6. it is an open source content management system(cms) based on .net language.
# c1-cms,2,system,orckestra c1 is a free open source content management system (cms).
# hp-idol-ondemand,2,platform,hpe haven ondemand is a platform for building cognitive computing solutions and data rich applications using text analysis speech recognition image analysis indexing and search apis.
# csvhelper,2,library,the csvhelper library is a .net library that allows for easy reading and writing of comma-separated values (csv) files.
# spotfire,2,environment,tibco spotfire is a flexible environment for analyzing business and technical data.
# winjs,2,library,the windows library for javascript (winjs) is a javascript library that can be used with any html css and javascript project on any platform including web sites native apps and hybrid apps.
# datajs,2,library,datajs is a cross-browser javascript library that enables data-centric web applications by leveraging modern protocols such as json and odata and html5-enabled browser features.
# shell32.dll,2,library,shell32.dll is a library which contains windows shell api functions.
# ais,2,system,the automatic identification system (ais) is an automatic tracking system used on ships and by vessel traffic services (vts) for identifying and locating vessels by electronically exchanging data with other nearby ships ais base stations and satellites.
# cordys-opentext,2,platform,cordys - opentext is a business operations platform.
# erpconnect,2,library,erpconnect is a library to connect to sap.
# scene7,2,environment,adobe scene7 platform is an integrated rich media management publishing and serving environment.
# hp-haven,2,platform,hp haven was a big data platform by hewlett-packard available on-premise or in the cloud.
# msnpsharp,2,library,msnpsharp is a .net library that implements the msn protocol.
# ncrunch,2,tool,ncrunch is a continuous testing tool for visual studio .net.
# mobile-os,2,system,a mobile operating system also called a mobile os is an operating system that is specifically designed to run on mobile devices such as mobile phones smartphones pdas tablet computers and other handheld devices.
# netweaver,2,platform,sap netweaver is a service-oriented application and integration platform.
# mt4,2,platform,metatrader 4 is a software platform for manual and automatic trading including free clients (end-user terminals) for windows iphone and android as well as server-side modules for processing trade transactions storing and distributing history of quotes proxy-servers and administration tools (for brokers).
# listlabel,2,tool,list & label is a reporting tool for developers to enable the design and print of reports in microsoft windows applications.
# m,2,component,the m modelling language was a component of microsoft's "oslo" project later known as sql server modeling ctp.
# vsvim,2,extension,vsvim is a free visual studio extension that makes the code editor a vim emulator.
# visual-studio-mac,2,ide,visual studio for mac is an ide from microsoft for mac users.
# retlang,2,library,retlang is a high performance c# threading library (like jetlang in java).
# iggrid,2,component,iggrid is a feature rich jquery/html5 grid component provided by infragistics in their ignite ui toolbox.
# sitecore5.2,2,system,sitecore is a web content management system (cms) built on microsoft asp.net.
# nodatime,2,library,noda time is a .net library designed to simplify the correct handling of dates and times in the .net environment.
# sharpgl,2,library,sharpgl is a c# library that allows you to use opengl in your .net framework based application with ease!
# cosmos,2,system,cosmos is an operating system "construction kit".
# biztalk-bam,2,tool,microsoft bam is a real-time data monitoring tool for microsoft biztalk server.
# pokein,1,library,pokein is a reverse ajax and websocket library for .net framework and mono developers
# liblas,1,library,liblas is a c/c++ library for reading and writing the very common las lidar format.
# umbraco-ucommerce,1,platform,umbraco is a fully-featured open source content management system ucommerce is a feature-rich e-commerce platform that can be implemented into umbraco solutions to add a fully featured e-commerce solution.
# impromptu-interface,1,framework,impromptuinterface is a framework for .net that uses the dlr's api normally hidden by the compiler for meta programming purposes such as adding interfaces at runtime.
# testbed,1,platform,a testbed is a platform for experimentation of large development projects.
# togaf,1,platform,the open group architecture framework (togaf) is a vendor-neutral platform for developing and implementing enterprise architectures.
# approval-tests,1,library,approvaltests is an open source library written for several languages (.net java php more) which has been designed to support unit testing based on the idea of a golden master.
# issuu,1,platform,issuu is a free electronic publishing platform for magazines catalogs newspapers and more.
# skype4java,1,library,skype4java is a wrapper library of skype api for java developers.
# archimate,1,language,the archimate® enterprise architecture modeling language is an open and independent modeling language for enterprise architecture
# sharppdf,1,library,sharppdf is a .net 1.1 library for simple pdf document creation.
# staff-wsf,1,framework,wsf staff is web service framework for c++ ajax and j2me that is based on apache axis2/c.
# waffle,1,framework,waffle is a windows authentication framework for java and c#.
# alglib,1,library,alglib is a portable library for numerical analysis and data processing.
