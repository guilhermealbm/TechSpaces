# %%
import pandas as pd

# %%
top_tags = pd.read_csv("top_tags.csv")

# %%
top_tags = top_tags[:100]

# %%
top_tags
# Out:
#     questions         TagName
# 0     3631335      javascript
# 1     2958910            java
# 2     2696097          python
# 3     2487571              c#
# 4     2287367             php
# ..        ...             ...
# 95     118493           swing
# 96     117636          matlab
# 97     117246        for-loop
# 98     117062       hibernate
# 99     116946  android-studio
#
# [100 rows x 2 columns]

# %%
df = pd.read_csv("../tags_with_wiki_and_category.csv")

# %%
df
# Out:
#                       TagName  \
# 0                        java
# 1                       regex
# 2                         xml
# 3                       mysql
# 4                        nant
# ...                       ...
# 41778            minimal-apis
# 41779                  ix.net
# 41780        amazon-memory-db
# 41781           decomposition
# 41782  dasync.asyncenumerator
#
#                                                     Body      root
# 0      java is a high-level object oriented programmi...  language
# 1      Regular expressions provide a declarative lang...       NaN
# 2      xml (extensible markup language) is a structur...    format
# 3      mysql is a free open source relational databas...    system
# 4      nant is a build tool for .net aiming to suppor...      tool
# ...                                                  ...       ...
# 41778  Minimal APIs were introduced in ASP.NET Core 6...       NaN
# 41779  the interactive extensions (ix) is a .net libr...   library
# 41780  memorydb for redis is an in-memory database se...   service
# 41781  Decomposition might refer to Time Series Decom...       NaN
# 41782  dasync.asyncenumerator is a c# library that pr...   library
#
# [41783 rows x 3 columns]

# %%
df = df[df.TagName.isin(top_tags.TagName)]

# %%
df
# Out:
#             TagName                                               Body  \
# 0              java  java is a high-level object oriented programmi...
# 1             regex  Regular expressions provide a declarative lang...
# 2               xml  xml (extensible markup language) is a structur...
# 3             mysql  mysql is a free open source relational databas...
# 8               wpf  windows presentation foundation or wpf is a su...
# ...             ...                                                ...
# 18277   spring-boot  spring boot is a framework that allows to easi...
# 22533         swift  swift is a general-purpose programming languag...
# 26499  react-native  react native is a javascript library used to b...
# 29241       flutter  flutter is an open-source ui software developm...
# 33648       angular  Questions about Angular (not to be confused wi...
#
#             root
# 0       language
# 1            NaN
# 2         format
# 3         system
# 8      subsystem
# ...          ...
# 18277  framework
# 22533   language
# 26499    library
# 29241        kit
# 33648        NaN
#
# [100 rows x 3 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df)
# Out:
#                    TagName                                               Body  \
# 0                     java  java is a high-level object oriented programmi...
# 1                    regex  Regular expressions provide a declarative lang...
# 2                      xml  xml (extensible markup language) is a structur...
# 3                    mysql  mysql is a free open source relational databas...
# 8                      wpf  windows presentation foundation or wpf is a su...
# 14                selenium  selenium is a popular open-source tool for aut...
# 20                 android  android is google's mobile operating system us...
# 23                     vba  visual basic for applications (vba) is an even...
# 35            unit-testing  unit testing is a method by which individual u...
# 44        entity-framework  entity framework is a linq-based object-databa...
# 47                   swing  swing is a user-interface toolkit in java and ...
# 52                  python  python is a multi-paradigm dynamically typed m...
# 53                    ruby  ruby is a multi-platform open-source dynamic o...
# 54                     c++     c++ is a general-purpose programming language.
# 55                      c#  c# (pronounced "see sharp") is a high level st...
# 56                       c  c is a general-purpose programming language us...
# 57              javascript           note javascript is not the same as java!
# 58                    .net  the .net framework is a software framework des...
# 59                     php  php is a widely used open source general-purpo...
# 60               hibernate  hibernate is an object-relational mapping (orm...
# 73                   scala  scala is a general-purpose programming languag...
# 91           ruby-on-rails  ruby on rails is an open source full-stack web...
# 98                   linux  NOTICE: All Linux questions must be related to...
# 106            objective-c  This tag should be used only on questions that...
# 149                    sql  structured query language (sql) is a language ...
# 151                 vb.net  visual basic.net (vb.net) is a multi-paradigm ...
# 152                eclipse  eclipse is an open source ide and platform for...
# 153                windows  writing software specific to the microsoft win...
# 154             sql-server  microsoft sql server is a relational database ...
# 155                asp.net  asp.net is a microsoft web application develop...
# 157                    git  git is an open-source distributed version cont...
# 158                 sqlite  sqlite is a software library that implements a...
# 163                 iphone  more tags to consider are [xcode] (but only if...
# 164                 oracle  oracle database is a multi-model database mana...
# 166                 django  django is an open-source server-side web appli...
# 167              algorithm  an algorithm is a sequence of well-defined ste...
# 168             postgresql  postgresql is an open-source relational databa...
# 173            asp.net-mvc  the asp.net mvc framework is an open source we...
# 176                  excel  general help regarding excel for single worksh...
# 177             powershell  powershell is a cross-platform command line an...
# 180                   perl  perl is a procedural high-level general-purpos...
# 182                 jquery  jquery is a javascript library consider also a...
# 184                 matlab  matlab is a high-level language and interactiv...
# 191                  xcode  xcode is apple's integrated development enviro...
# 219                 spring  the spring framework is an open source framewo...
# 220                      r  r is a free open-source programming language &...
# 226          visual-studio  Use this tag if you have a specific question a...
# 241               winforms  winforms is the informal name given to windows...
# 269                   html  html (hypertext markup language) is the markup...
# 283                    css  css (cascading style sheets) is a representati...
# 291                  numpy  numpy is an extension of the python language t...
# 339                   ajax  ajax (asynchronous javascript and xml) is a te...
# 343              wordpress  this tag is for programming-specific questions...
# 422                node.js  node.js is an event-based non-blocking asynchr...
# 463                    ios  ios is the mobile operating system running on ...
# 467                mongodb  mongodb is a scalable high-performance open so...
# 471             python-3.x     use only if your question is version-specific.
# 524                   tsql  t-sql (transact structured query language) is ...
# 559                 string  a string is a finite sequence of symbols commo...
# 565                   json  json (javascript object notation) is a seriali...
# 572                   linq  language integrated query (linq) is a microsof...
# 633                    oop  object-oriented programming is a programming p...
# 641                    csv  comma-separated values or character-separated ...
# 643               function  a function (also called a procedure method sub...
# 660                  azure  microsoft azure is a platform as a service and...
# 681               for-loop  A for loop is a control structure used by many...
# 691         multithreading  For questions regarding multi-threading, the a...
# 736                  shell  The term 'shell' refers to a general class of ...
# 757                 arrays  an array is an ordered linear data structure c...
# 771               database     a database is an organized collection of data.
# 785                  macos  macos (formerly known as os x or mac os x) is ...
# 878                   date  a date is a reference to a particular day repr...
# 893                sorting  Sorting is the process of applying some order ...
# 970                  image  the image tag is for questions related to the ...
# 971            performance  For questions pertaining to the measurement or...
# 1001   amazon-web-services  amazon web services (aws) is a public-cloud: i...
# 1046                  bash  this tag is for questions about scripts writte...
# 1074                 loops  loops are a type of control flow structure in ...
# 1336                 class  A template for creating new objects that descr...
# 1422                  file  files are available to computer programs and a...
# 1638                  list  The list tag may refer to: a linked list (an o...
# 2133              datetime  A DateTime object in many programming language...
# 2137                 forms  a form is essentially a container that can be ...
# 3199            dictionary  A dictionary maps keys to values allowing effi...
# 3649                pandas  pandas is a python library for data manipulati...
# 4378             dataframe       a data frame is a 2d tabular data structure.
# 4608     twitter-bootstrap  bootstrap is a frontend framework designed to ...
# 5908            python-2.7  python 2.7 is the last major version in the 2....
# 6179               laravel  the laravel framework is an open-sourced php w...
# 7956             angularjs  Use for questions about AngularJS (1.x), the o...
# 8959              firebase  firebase is a serverless platform for unified ...
# 11766           typescript  typescript is a typed superset of javascript t...
# 15512               docker      docker is a tool to build and run containers.
# 16397       android-studio  Use for questions about using Android Studio, ...
# 16685              reactjs  React is a JavaScript library for building use...
# 18277          spring-boot  spring boot is a framework that allows to easi...
# 22533                swift  swift is a general-purpose programming languag...
# 26499         react-native  react native is a javascript library used to b...
# 29241              flutter  flutter is an open-source ui software developm...
# 33648              angular  Questions about Angular (not to be confused wi...
#
#                    root
# 0              language
# 1                   NaN
# 2                format
# 3                system
# 8             subsystem
# 14                 tool
# 20               system
# 23             language
# 35               method
# 44               mapper
# 47              toolkit
# 52             language
# 53             language
# 54             language
# 55             language
# 56             language
# 57                 same
# 58            framework
# 59       multi-paradigm
# 60              library
# 73             language
# 91            framework
# 98                  NaN
# 106                 NaN
# 149            language
# 151            language
# 152                 ide
# 153           off-topic
# 154              system
# 155           framework
# 157              system
# 158             library
# 163                 ide
# 164              system
# 166           framework
# 167            sequence
# 168              system
# 173           framework
# 176           available
# 177             utility
# 180            language
# 182             library
# 184            language
# 191         environment
# 219           framework
# 220         environment
# 226                 NaN
# 241                name
# 269            language
# 283            language
# 291           extension
# 339           technique
# 343         programming
# 422             runtime
# 463              system
# 467            database
# 471    version-specific
# 524           extension
# 559            sequence
# 565             machine
# 572           component
# 633            paradigm
# 641            database
# 643             portion
# 660            platform
# 681                 NaN
# 691                 NaN
# 736                 NaN
# 757           structure
# 771          collection
# 785              system
# 878           reference
# 893                 NaN
# 970           questions
# 971                 NaN
# 1001       public-cloud
# 1046          questions
# 1074               type
# 1336                NaN
# 1422          available
# 1638                NaN
# 2133                NaN
# 2137          container
# 3199                NaN
# 3649            library
# 4378          structure
# 4608          framework
# 5908            version
# 6179          framework
# 7956                NaN
# 8959           platform
# 11766          superset
# 15512              tool
# 16397               NaN
# 16685               NaN
# 18277         framework
# 22533          language
# 26499           library
# 29241               kit
# 33648               NaN

# %%
df = df.astype(str)

# %%
df[df.root == "nan"]
# Out:
#               TagName                                               Body root
# 1               regex  Regular expressions provide a declarative lang...  nan
# 98              linux  NOTICE: All Linux questions must be related to...  nan
# 106       objective-c  This tag should be used only on questions that...  nan
# 226     visual-studio  Use this tag if you have a specific question a...  nan
# 681          for-loop  A for loop is a control structure used by many...  nan
# 691    multithreading  For questions regarding multi-threading, the a...  nan
# 736             shell  The term 'shell' refers to a general class of ...  nan
# 893           sorting  Sorting is the process of applying some order ...  nan
# 971       performance  For questions pertaining to the measurement or...  nan
# 1336            class  A template for creating new objects that descr...  nan
# 1638             list  The list tag may refer to: a linked list (an o...  nan
# 2133         datetime  A DateTime object in many programming language...  nan
# 3199       dictionary  A dictionary maps keys to values allowing effi...  nan
# 7956        angularjs  Use for questions about AngularJS (1.x), the o...  nan
# 16397  android-studio  Use for questions about using Android Studio, ...  nan
# 16685         reactjs  React is a JavaScript library for building use...  nan
# 33648         angular  Questions about Angular (not to be confused wi...  nan

# %%
df = df[df.root != "nan"]

# %%
gdf = df.groupby("root")

# %%
gdf.first()
# Out:
#                               TagName  \
# root
# available                       excel
# collection                   database
# component                        linq
# container                       forms
# database                      mongodb
# environment                     xcode
# extension                       numpy
# format                            xml
# framework                        .net
# ide                           eclipse
# kit                           flutter
# language                         java
# library                     hibernate
# machine                          json
# mapper               entity-framework
# method                   unit-testing
# multi-paradigm                    php
# name                         winforms
# off-topic                     windows
# paradigm                          oop
# platform                        azure
# portion                      function
# programming                 wordpress
# public-cloud      amazon-web-services
# questions                       image
# reference                        date
# runtime                       node.js
# same                       javascript
# sequence                    algorithm
# structure                      arrays
# subsystem                         wpf
# superset                   typescript
# system                          mysql
# technique                        ajax
# tool                         selenium
# toolkit                         swing
# type                            loops
# utility                    powershell
# version                    python-2.7
# version-specific           python-3.x
#
#                                                                Body
# root
# available         general help regarding excel for single worksh...
# collection           a database is an organized collection of data.
# component         language integrated query (linq) is a microsof...
# container         a form is essentially a container that can be ...
# database          mongodb is a scalable high-performance open so...
# environment       xcode is apple's integrated development enviro...
# extension         numpy is an extension of the python language t...
# format            xml (extensible markup language) is a structur...
# framework         the .net framework is a software framework des...
# ide               eclipse is an open source ide and platform for...
# kit               flutter is an open-source ui software developm...
# language          java is a high-level object oriented programmi...
# library           hibernate is an object-relational mapping (orm...
# machine           json (javascript object notation) is a seriali...
# mapper            entity framework is a linq-based object-databa...
# method            unit testing is a method by which individual u...
# multi-paradigm    php is a widely used open source general-purpo...
# name              winforms is the informal name given to windows...
# off-topic         writing software specific to the microsoft win...
# paradigm          object-oriented programming is a programming p...
# platform          microsoft azure is a platform as a service and...
# portion           a function (also called a procedure method sub...
# programming       this tag is for programming-specific questions...
# public-cloud      amazon web services (aws) is a public-cloud: i...
# questions         the image tag is for questions related to the ...
# reference         a date is a reference to a particular day repr...
# runtime           node.js is an event-based non-blocking asynchr...
# same                       note javascript is not the same as java!
# sequence          an algorithm is a sequence of well-defined ste...
# structure         an array is an ordered linear data structure c...
# subsystem         windows presentation foundation or wpf is a su...
# superset          typescript is a typed superset of javascript t...
# system            mysql is a free open source relational databas...
# technique         ajax (asynchronous javascript and xml) is a te...
# tool              selenium is a popular open-source tool for aut...
# toolkit           swing is a user-interface toolkit in java and ...
# type              loops are a type of control flow structure in ...
# utility           powershell is a cross-platform command line an...
# version           python 2.7 is the last major version in the 2....
# version-specific     use only if your question is version-specific.

# %%
gdf.get_group("component")
# Out:
#     TagName                                               Body       root
# 572    linq  language integrated query (linq) is a microsof...  component
